# %% [markdown]
# ### Import Libraries

# %%
# ===== Auto Reload =====
# %load_ext autoreload
# %autoreload 2

# ===== Standard Libraries =====
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import random

# ===== PyTorch =====
import torch
import torch.nn as nn
from torchdiffeq import odeint

# torchdiffeq 버전 확인
import torchdiffeq
print(f"torchdiffeq version: {torchdiffeq.__version__}")
print("")

# ===== Check Installation =====
print("="*50)
print("Environment Check")
print("="*50)
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA device: {torch.cuda.get_device_name(0)}")
print(f"CUDA available: {torch.cuda.is_available()}")
print("="*50)
print("")


# ===== Your Custom Module =====
# Import from battery_ode_wrapper
from battery_ode_wrapper import*
from utils import*

print("="*50)
print("✓ All modules loaded!")
print("="*50)
# Out:
# torchdiffeq version: 0.2.5
#
# ==================================================
# Environment Check
# ==================================================
# PyTorch version: 2.5.1
# CUDA device: NVIDIA RTX 3500 Ada Generation Laptop GPU
# CUDA available: True
# ==================================================
#
# ==================================================
# ✓ All modules loaded!
# ==================================================

# %% [markdown]
# ### Data Import

# %%
import scipy.io
import os
import numpy as np
import re


# MATLAB 데이터 디렉토리 경로
data_dir = r"C:\Users\ljw76\Documents\MATLAB\LFP_SAFT\data\learning_data"

# ===== 온도 필터 설정 =====
target_temps = [25]  # 원하는 온도 리스트 (예: [25, 35] 또는 [] 이면 모든 온도)

# 디렉토리 내 모든 .mat 파일 목록 가져오기
mat_files = [f for f in os.listdir(data_dir) if f.endswith('.mat')]
print(f"Found {len(mat_files)} .mat files:")
for file in mat_files:
    print(f"  - {file}")

# 모든 파일 로드
print(f"\nLoading files with temperature filter: {target_temps if target_temps else 'All'}")
all_loaded_data = {}

for i, file in enumerate(mat_files):
    file_path = os.path.join(data_dir, file)
    print(f"Loading {i+1}/{len(mat_files)}: {file}")
    
    try:
        mat_data = scipy.io.loadmat(file_path)
        
        # 온도 추출 (파일명에서, 대문자 C만 찾기)
        temp_match = re.search(r'_(\d+)C_', file)
        file_temp = int(temp_match.group(1)) if temp_match else None
        
        # 온도 필터링
        if target_temps and (file_temp is None or file_temp not in target_temps):
            print(f"  ⚠ Skipped (temp: {file_temp}°C)")
            continue
        
        # 파일명에서 확장자 제거하여 키로 사용
        file_key = file.replace('.mat', '')
        
        # 메타데이터 키 제외한 실제 데이터만 저장
        data_keys = [key for key in mat_data.keys() if not key.startswith('__')]
        all_loaded_data[file_key] = {}
        
        for key in data_keys:
            all_loaded_data[file_key][key] = mat_data[key]
        
        print(f"  ✓ Loaded (temp: {file_temp}°C) - {len(data_keys)} data keys: {data_keys}")
        
    except Exception as e:
        print(f"  ✗ Failed to load {file}: {e}")

print(f"\nAll files loaded!")
print(f"Successfully loaded {len(all_loaded_data)} files:")
for file_key, data_dict in all_loaded_data.items():
    print(f"  {file_key}: {list(data_dict.keys())}")

# 첫 번째 파일의 데이터 구조 상세 확인
if all_loaded_data:
    first_file_key = list(all_loaded_data.keys())[0]
    first_data_key = list(all_loaded_data[first_file_key].keys())[0]
    sample_data = all_loaded_data[first_file_key][first_data_key]

    print(f"\nSample data structure from {first_file_key}[{first_data_key}]:")
    print(f"  Shape: {sample_data.shape}")
    print(f"  Type: {type(sample_data)}")
    if hasattr(sample_data, 'dtype'):
        print(f"  Dtype: {sample_data.dtype}")
        if hasattr(sample_data.dtype, 'names') and sample_data.dtype.names:
            print(f"  Field names: {sample_data.dtype.names}")
# Out:
# Found 151 .mat files:
#   - gitt_restonly_25C_SOC_10.mat
#   - gitt_restonly_25C_SOC_100.mat
#   - gitt_restonly_25C_SOC_11.mat
#   - gitt_restonly_25C_SOC_12.mat
#   - gitt_restonly_25C_SOC_13.mat
#   - gitt_restonly_25C_SOC_14.mat
#   - gitt_restonly_25C_SOC_15.mat
#   - gitt_restonly_25C_SOC_16.mat
#   - gitt_restonly_25C_SOC_17.mat
#   - gitt_restonly_25C_SOC_18.mat
#   - gitt_restonly_25C_SOC_19.mat
#   - gitt_restonly_25C_SOC_2.mat
#   - gitt_restonly_25C_SOC_20.mat
#   - gitt_restonly_25C_SOC_21.mat
#   - gitt_restonly_25C_SOC_22.mat
#   - gitt_restonly_25C_SOC_23.mat
#   - gitt_restonly_25C_SOC_25.mat
#   - gitt_restonly_25C_SOC_26.mat
#   - gitt_restonly_25C_SOC_27.mat
#   - gitt_restonly_25C_SOC_28.mat
#   - gitt_restonly_25C_SOC_29.mat
#   - gitt_restonly_25C_SOC_3.mat
#   - gitt_restonly_25C_SOC_30.mat
#   - gitt_restonly_25C_SOC_31.mat
#   - gitt_restonly_25C_SOC_32.mat
#   - gitt_restonly_25C_SOC_33.mat
#   - gitt_restonly_25C_SOC_34.mat
#   - gitt_restonly_25C_SOC_35.mat
#   - gitt_restonly_25C_SOC_36.mat
#   - gitt_restonly_25C_SOC_37.mat
#   - gitt_restonly_25C_SOC_38.mat
#   - gitt_restonly_25C_SOC_39.mat
#   - gitt_restonly_25C_SOC_4.mat
#   - gitt_restonly_25C_SOC_40.mat
#   - gitt_restonly_25C_SOC_41.mat
#   - gitt_restonly_25C_SOC_42.mat
#   - gitt_restonly_25C_SOC_43.mat
#   - gitt_restonly_25C_SOC_44.mat
#   - gitt_restonly_25C_SOC_45.mat
#   - gitt_restonly_25C_SOC_46.mat
#   - gitt_restonly_25C_SOC_47.mat
#   - gitt_restonly_25C_SOC_48.mat
#   - gitt_restonly_25C_SOC_49.mat
#   - gitt_restonly_25C_SOC_5.mat
#   - gitt_restonly_25C_SOC_50.mat
#   - gitt_restonly_25C_SOC_51.mat
#   - gitt_restonly_25C_SOC_52.mat
#   - gitt_restonly_25C_SOC_53.mat
#   - gitt_restonly_25C_SOC_55.mat
#   - gitt_restonly_25C_SOC_56.mat
#   - gitt_restonly_25C_SOC_57.mat
#   - gitt_restonly_25C_SOC_58.mat
#   - gitt_restonly_25C_SOC_59.mat
#   - gitt_restonly_25C_SOC_6.mat
#   - gitt_restonly_25C_SOC_60.mat
#   - gitt_restonly_25C_SOC_61.mat
#   - gitt_restonly_25C_SOC_62.mat
#   - gitt_restonly_25C_SOC_63.mat
mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
# Loading 149/151: udds7_1c_norest_35C_struct.mat
#   ⚠ Skipped (temp: 35°C)
# Loading 150/151: udds7_1c_norest_45C_struct.mat
#   ⚠ Skipped (temp: 45°C)
# Loading 151/151: udds8_1c_norest_25C_struct.mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
#
# All files loaded!
# Successfully loaded 145 files:
#   gitt_restonly_25C_SOC_10: ['spme_struct']
#   gitt_restonly_25C_SOC_100: ['spme_struct']
#   gitt_restonly_25C_SOC_11: ['spme_struct']
#   gitt_restonly_25C_SOC_12: ['spme_struct']
#   gitt_restonly_25C_SOC_13: ['spme_struct']
#   gitt_restonly_25C_SOC_14: ['spme_struct']
#   gitt_restonly_25C_SOC_15: ['spme_struct']
#   gitt_restonly_25C_SOC_16: ['spme_struct']
#   gitt_restonly_25C_SOC_17: ['spme_struct']
#   gitt_restonly_25C_SOC_18: ['spme_struct']
#   gitt_restonly_25C_SOC_19: ['spme_struct']
#   gitt_restonly_25C_SOC_2: ['spme_struct']
#   gitt_restonly_25C_SOC_20: ['spme_struct']
#   gitt_restonly_25C_SOC_21: ['spme_struct']
#   gitt_restonly_25C_SOC_22: ['spme_struct']
#   gitt_restonly_25C_SOC_23: ['spme_struct']
#   gitt_restonly_25C_SOC_25: ['spme_struct']
#   gitt_restonly_25C_SOC_26: ['spme_struct']
#   gitt_restonly_25C_SOC_27: ['spme_struct']
#   gitt_restonly_25C_SOC_28: ['spme_struct']
#   gitt_restonly_25C_SOC_29: ['spme_struct']
#   gitt_restonly_25C_SOC_3: ['spme_struct']
#   gitt_restonly_25C_SOC_30: ['spme_struct']
#   gitt_restonly_25C_SOC_31: ['spme_struct']
#   gitt_restonly_25C_SOC_32: ['spme_struct']
#   gitt_restonly_25C_SOC_33: ['spme_struct']
#   gitt_restonly_25C_SOC_34: ['spme_struct']
#   gitt_restonly_25C_SOC_35: ['spme_struct']
#   gitt_restonly_25C_SOC_36: ['spme_struct']
#   gitt_restonly_25C_SOC_37: ['spme_struct']
#   gitt_restonly_25C_SOC_38: ['spme_struct']
#   gitt_restonly_25C_SOC_39: ['spme_struct']
#   gitt_restonly_25C_SOC_4: ['spme_struct']
#   gitt_restonly_25C_SOC_40: ['spme_struct']
#   gitt_restonly_25C_SOC_41: ['spme_struct']
#   gitt_restonly_25C_SOC_42: ['spme_struct']
#   gitt_restonly_25C_SOC_43: ['spme_struct']
#   gitt_restonly_25C_SOC_44: ['spme_struct']
#   gitt_restonly_25C_SOC_45: ['spme_struct']
#   gitt_restonly_25C_SOC_46: ['spme_struct']
#   gitt_restonly_25C_SOC_47: ['spme_struct']
#   gitt_restonly_25C_SOC_48: ['spme_struct']
#   gitt_restonly_25C_SOC_49: ['spme_struct']
#   gitt_restonly_25C_SOC_5: ['spme_struct']
#   gitt_restonly_25C_SOC_50: ['spme_struct']
#   gitt_restonly_25C_SOC_51: ['spme_struct']
#   gitt_restonly_25C_SOC_52: ['spme_struct']
#   gitt_restonly_25C_SOC_53: ['spme_struct']
#   gitt_restonly_25C_SOC_55: ['spme_struct']
#   gitt_restonly_25C_SOC_56: ['spme_struct']
#   gitt_restonly_25C_SOC_57: ['spme_struct']
#   gitt_restonly_25C_SOC_58: ['spme_struct']
#   gitt_restonly_25C_SOC_59: ['spme_struct']
#   gitt_restonly_25C_SOC_6: ['spme_struct']
#   gitt_restonly_25C_SOC_60: ['spme_struct']
#   gitt_restonly_25C_SOC_61: ['spme_struct']
#   gitt_restonly_25C_SOC_62: ['spme_struct']
#   gitt_restonly_25C_SOC_63: ['spme_struct']
#   gitt_restonly_25C_SOC_64: ['spme_struct']
#   gitt_restonly_25C_SOC_65: ['spme_struct']
#   gitt_restonly_25C_SOC_66: ['spme_struct']
#   gitt_restonly_25C_SOC_67: ['spme_struct']
#   gitt_restonly_25C_SOC_68: ['spme_struct']
#   gitt_restonly_25C_SOC_69: ['spme_struct']
#   gitt_restonly_25C_SOC_7: ['spme_struct']
#   gitt_restonly_25C_SOC_70: ['spme_struct']
#   gitt_restonly_25C_SOC_71: ['spme_struct']
#   gitt_restonly_25C_SOC_72: ['spme_struct']
#   gitt_restonly_25C_SOC_73: ['spme_struct']
#   gitt_restonly_25C_SOC_74: ['spme_struct']
#   gitt_restonly_25C_SOC_75: ['spme_struct']
#   gitt_restonly_25C_SOC_76: ['spme_struct']
#   gitt_restonly_25C_SOC_77: ['spme_struct']
#   gitt_restonly_25C_SOC_78: ['spme_struct']
#   gitt_restonly_25C_SOC_79: ['spme_struct']
#   gitt_restonly_25C_SOC_8: ['spme_struct']
#   gitt_restonly_25C_SOC_80: ['spme_struct']
#   gitt_restonly_25C_SOC_81: ['spme_struct']
#   gitt_restonly_25C_SOC_82: ['spme_struct']
#   gitt_restonly_25C_SOC_83: ['spme_struct']
#   gitt_restonly_25C_SOC_84: ['spme_struct']
#   gitt_restonly_25C_SOC_86: ['spme_struct']
#   gitt_restonly_25C_SOC_87: ['spme_struct']
#   gitt_restonly_25C_SOC_88: ['spme_struct']
#   gitt_restonly_25C_SOC_89: ['spme_struct']
#   gitt_restonly_25C_SOC_9: ['spme_struct']
#   gitt_restonly_25C_SOC_90: ['spme_struct']
#   gitt_restonly_25C_SOC_91: ['spme_struct']
#   gitt_restonly_25C_SOC_92: ['spme_struct']
#   gitt_restonly_25C_SOC_93: ['spme_struct']
#   gitt_restonly_25C_SOC_94: ['spme_struct']
#   gitt_restonly_25C_SOC_95: ['spme_struct']
#   gitt_restonly_25C_SOC_96: ['spme_struct']
#   gitt_restonly_25C_SOC_97: ['spme_struct']
#   gitt_restonly_25C_SOC_98: ['spme_struct']
#   gitt_restonly_25C_SOC_99: ['spme_struct']
#   udds1_1c_norest_25C_struct: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_100: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_11: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_16: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_21: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_25: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_30: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_35: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_39: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_44: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_49: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_53: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_58: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_63: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_67: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_7: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_72: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_77: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_81: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_86: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_91: ['spme_struct']
#   udds2_1c_norest_25C_struct: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_100: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_11: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_16: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_21: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_25: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_30: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_35: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_39: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_44: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_49: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_53: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_58: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_63: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_67: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_7: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_72: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_77: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_81: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_86: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_91: ['spme_struct']
#   udds2_1c_rest_25C_struct: ['spme_struct']
#   udds3_1c_norest_25C_struct: ['results_with_corr']
#   udds4_1c_norest_25C_struct: ['results_with_corr']
#   udds5_1c_norest_25C_struct: ['results_with_corr']
#   udds6_1c_norest_25C_struct: ['spme_struct']
#   udds7_1c_norest_25C_struct: ['spme_struct']
#   udds8_1c_norest_25C_struct: ['spme_struct']
#
# Sample data structure from gitt_restonly_25C_SOC_10[spme_struct]:
#   Shape: (1, 1)
#   Type: <class 'numpy.ndarray'>
#   Dtype: [('time', 'O'), ('current', 'O'), ('temperature', 'O'), ('Vout', 'O'), ('Ve', 'O'), ('Vcond', 'O'), ('eta_p', 'O'), ('eta_n', 'O'), ('Un', 'O'), ('Up', 'O'), ('ocp', 'O'), ('soc_n', 'O'), ('soc_p', 'O'), ('c_s_p_surf', 'O'), ('c_s_n_surf', 'O'), ('c_s_p_bulk', 'O'), ('c_s_n_bulk', 'O'), ('i0p', 'O'), ('k_cs', 'O'), ('alpha_cs', 'O'), ('tau_cs', 'O'), ('c_s_p_surf_tilde', 'O'), ('Dsn_eff', 'O'), ('Dsp_eff', 'O'), ('Vspme', 'O'), ('Vref', 'O')]
#   Field names: ('time', 'current', 'temperature', 'Vout', 'Ve', 'Vcond', 'eta_p', 'eta_n', 'Un', 'Up', 'ocp', 'soc_n', 'soc_p', 'c_s_p_surf', 'c_s_n_surf', 'c_s_p_bulk', 'c_s_n_bulk', 'i0p', 'k_cs', 'alpha_cs', 'tau_cs', 'c_s_p_surf_tilde', 'Dsn_eff', 'Dsp_eff', 'Vspme', 'Vref')

# %%
# ===== Key 선택 =====
target_keys = ["time", "Vref", "Vspme", "current", "temperature", "c_s_n_bulk", "soc_n", "ocp"]

# ===== 모든 파일 처리 =====
extracted_data = {}  # Dictionary로 저장

excluded_target = []
excluded_data = {}
# extracted_data는 excluded_target에 들어있지 않은 것만, excluded_data는 target에 들어있는 것만 저장하도록 아래 for문 수정

print("="*60)
print("Converting all structs to DataFrames")
print("="*60)

for file_key, data_dict in all_loaded_data.items():
    print(f"\nProcessing: {file_key}")
    
    # struct 추출 (첫 번째 key)
    struct_key = list(data_dict.keys())[0]
    struct_data = data_dict[struct_key]
    
    # DataFrame 변환
    df = struct_to_dataframe(struct_data, selected_keys=target_keys)

    # 저장: excluded_target 리스트에 있으면 excluded_data에, 아니면 extracted_data에
    if file_key in excluded_target:
        excluded_data[file_key] = df
        print(f"  ✓ DataFrame created (EXCLUDED): {df.shape}")
    else:
        extracted_data[file_key] = df
        print(f"  ✓ DataFrame created: {df.shape}")
    print(f"  Columns: {list(df.columns)}")

print("\n" + "="*60)
print(f"✓ Total {len(extracted_data)} DataFrames created!")
print(f"✓ Total {len(excluded_data)} EXCLUDED DataFrames created!")
print("="*60)

# 요약
for name, df in extracted_data.items():
    print(f"  {name}: {df.shape}")

for name, df in excluded_data.items():
    print(f"  (EXCLUDED) {name}: {df.shape}")
# extracted_data는 excluded_target에 들어있지 않은 것만 들어가게끔 for문에서 처리 (아래 for문 참고!)
# Out:
# ============================================================
# Converting all structs to DataFrames
# ============================================================
#
# Processing: gitt_restonly_25C_SOC_10
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_100
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_11
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3600, 1)       → 3600 points
#   ✓ Vref                : shape (3600, 1)       → 3600 points
#   ✓ Vspme               : shape (3600, 1)       → 3600 points
#   ✓ current             : shape (3600, 1)       → 3600 points
#   ✓ temperature         : shape (3600, 1)       → 3600 points
#   ✓ c_s_n_bulk          : shape (3600, 1)       → 3600 points
#   ✓ soc_n               : shape (3600, 1)       → 3600 points
#   ✓ ocp                 : shape (3600, 1)       → 3600 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3600 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3600, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_12
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_13
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_14
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_15
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_16
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_17
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_18
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_19
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_2
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_20
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_21
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_22
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_23
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_25
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_26
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_27
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3600, 1)       → 3600 points
#   ✓ Vref                : shape (3600, 1)       → 3600 points
#   ✓ Vspme               : shape (3600, 1)       → 3600 points
#   ✓ current             : shape (3600, 1)       → 3600 points
#   ✓ temperature         : shape (3600, 1)       → 3600 points
#   ✓ c_s_n_bulk          : shape (3600, 1)       → 3600 points
#   ✓ soc_n               : shape (3600, 1)       → 3600 points
#   ✓ ocp                 : shape (3600, 1)       → 3600 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3600 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3600, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_28
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_29
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_3
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_30
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_31
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_32
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_33
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_34
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_35
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
# ...
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (42754, 1)      → 42754 points
#   ✓ Vref                : shape (42754, 1)      → 42754 points
#   ✓ Vspme               : shape (42754, 1)      → 42754 points
#   ✓ current             : shape (42754, 1)      → 42754 points
#   ✓ temperature         : shape (42754, 1)      → 42754 points
#   ✓ c_s_n_bulk          : shape (42754, 1)      → 42754 points
#   ✓ soc_n               : shape (42754, 1)      → 42754 points
#   ✓ ocp                 : shape (42754, 1)      → 42754 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 42754 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (42754, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds4_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (68411, 1)      → 68411 points
#   ✓ Vref                : shape (68411, 1)      → 68411 points
#   ✓ Vspme               : shape (68411, 1)      → 68411 points
#   ✓ current             : shape (68411, 1)      → 68411 points
#   ✓ temperature         : shape (68411, 1)      → 68411 points
#   ✓ c_s_n_bulk          : shape (68411, 1)      → 68411 points
#   ✓ soc_n               : shape (68411, 1)      → 68411 points
#   ✓ ocp                 : shape (68411, 1)      → 68411 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 68411 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (68411, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds5_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (77084, 1)      → 77084 points
#   ✓ Vref                : shape (77084, 1)      → 77084 points
#   ✓ Vspme               : shape (77084, 1)      → 77084 points
#   ✓ current             : shape (77084, 1)      → 77084 points
#   ✓ temperature         : shape (77084, 1)      → 77084 points
#   ✓ c_s_n_bulk          : shape (77084, 1)      → 77084 points
#   ✓ soc_n               : shape (77084, 1)      → 77084 points
#   ✓ ocp                 : shape (77084, 1)      → 77084 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 77084 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (77084, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds6_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (30309, 1)      → 30309 points
#   ✓ Vref                : shape (30309, 1)      → 30309 points
#   ✓ Vspme               : shape (30309, 1)      → 30309 points
#   ✓ current             : shape (30309, 1)      → 30309 points
#   ✓ temperature         : shape (30309, 1)      → 30309 points
#   ✓ c_s_n_bulk          : shape (30309, 1)      → 30309 points
#   ✓ soc_n               : shape (30309, 1)      → 30309 points
#   ✓ ocp                 : shape (30309, 1)      → 30309 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 30309 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (30309, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds7_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (33596, 1)      → 33596 points
#   ✓ Vref                : shape (33596, 1)      → 33596 points
#   ✓ Vspme               : shape (33596, 1)      → 33596 points
#   ✓ current             : shape (33596, 1)      → 33596 points
#   ✓ temperature         : shape (33596, 1)      → 33596 points
#   ✓ c_s_n_bulk          : shape (33596, 1)      → 33596 points
#   ✓ soc_n               : shape (33596, 1)      → 33596 points
#   ✓ ocp                 : shape (33596, 1)      → 33596 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 33596 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (33596, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds8_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (30939, 1)      → 30939 points
#   ✓ Vref                : shape (30939, 1)      → 30939 points
#   ✓ Vspme               : shape (30939, 1)      → 30939 points
#   ✓ current             : shape (30939, 1)      → 30939 points
#   ✓ temperature         : shape (30939, 1)      → 30939 points
#   ✓ c_s_n_bulk          : shape (30939, 1)      → 30939 points
#   ✓ soc_n               : shape (30939, 1)      → 30939 points
#   ✓ ocp                 : shape (30939, 1)      → 30939 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 30939 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (30939, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# ============================================================
# ✓ Total 145 DataFrames created!
# ✓ Total 0 EXCLUDED DataFrames created!
# ============================================================
#   gitt_restonly_25C_SOC_10: (3601, 9)
#   gitt_restonly_25C_SOC_100: (3601, 9)
#   gitt_restonly_25C_SOC_11: (3600, 9)
#   gitt_restonly_25C_SOC_12: (3601, 9)
#   gitt_restonly_25C_SOC_13: (3601, 9)
#   gitt_restonly_25C_SOC_14: (3601, 9)
#   gitt_restonly_25C_SOC_15: (3601, 9)
#   gitt_restonly_25C_SOC_16: (3601, 9)
#   gitt_restonly_25C_SOC_17: (3601, 9)
#   gitt_restonly_25C_SOC_18: (3601, 9)
#   gitt_restonly_25C_SOC_19: (3601, 9)
#   gitt_restonly_25C_SOC_2: (3601, 9)
#   gitt_restonly_25C_SOC_20: (3601, 9)
#   gitt_restonly_25C_SOC_21: (3601, 9)
#   gitt_restonly_25C_SOC_22: (3601, 9)
#   gitt_restonly_25C_SOC_23: (3601, 9)
#   gitt_restonly_25C_SOC_25: (3601, 9)
#   gitt_restonly_25C_SOC_26: (3601, 9)
#   gitt_restonly_25C_SOC_27: (3600, 9)
#   gitt_restonly_25C_SOC_28: (3601, 9)
#   gitt_restonly_25C_SOC_29: (3601, 9)
#   gitt_restonly_25C_SOC_3: (3601, 9)
#   gitt_restonly_25C_SOC_30: (3601, 9)
#   gitt_restonly_25C_SOC_31: (3601, 9)
#   gitt_restonly_25C_SOC_32: (3601, 9)
#   gitt_restonly_25C_SOC_33: (3601, 9)
#   gitt_restonly_25C_SOC_34: (3601, 9)
#   gitt_restonly_25C_SOC_35: (3601, 9)
#   gitt_restonly_25C_SOC_36: (3600, 9)
#   gitt_restonly_25C_SOC_37: (3601, 9)
#   gitt_restonly_25C_SOC_38: (3601, 9)
#   gitt_restonly_25C_SOC_39: (3601, 9)
#   gitt_restonly_25C_SOC_4: (3601, 9)
#   gitt_restonly_25C_SOC_40: (3601, 9)
#   gitt_restonly_25C_SOC_41: (3601, 9)
#   gitt_restonly_25C_SOC_42: (3601, 9)
#   gitt_restonly_25C_SOC_43: (3601, 9)
#   gitt_restonly_25C_SOC_44: (3601, 9)
#   gitt_restonly_25C_SOC_45: (3601, 9)
#   gitt_restonly_25C_SOC_46: (3601, 9)
#   gitt_restonly_25C_SOC_47: (3601, 9)
#   gitt_restonly_25C_SOC_48: (3601, 9)
#   gitt_restonly_25C_SOC_49: (3601, 9)
#   gitt_restonly_25C_SOC_5: (3601, 9)
#   gitt_restonly_25C_SOC_50: (3600, 9)
#   gitt_restonly_25C_SOC_51: (3601, 9)
#   gitt_restonly_25C_SOC_52: (3601, 9)
#   gitt_restonly_25C_SOC_53: (3601, 9)
#   gitt_restonly_25C_SOC_55: (3601, 9)
#   gitt_restonly_25C_SOC_56: (3601, 9)
#   gitt_restonly_25C_SOC_57: (3601, 9)
#   gitt_restonly_25C_SOC_58: (3601, 9)
#   gitt_restonly_25C_SOC_59: (3601, 9)
#   gitt_restonly_25C_SOC_6: (3601, 9)
#   gitt_restonly_25C_SOC_60: (3601, 9)
#   gitt_restonly_25C_SOC_61: (3601, 9)
#   gitt_restonly_25C_SOC_62: (3601, 9)
#   gitt_restonly_25C_SOC_63: (3601, 9)
#   gitt_restonly_25C_SOC_64: (3601, 9)
#   gitt_restonly_25C_SOC_65: (3600, 9)
#   gitt_restonly_25C_SOC_66: (3601, 9)
#   gitt_restonly_25C_SOC_67: (3601, 9)
#   gitt_restonly_25C_SOC_68: (3601, 9)
#   gitt_restonly_25C_SOC_69: (3601, 9)
#   gitt_restonly_25C_SOC_7: (3601, 9)
#   gitt_restonly_25C_SOC_70: (3601, 9)
#   gitt_restonly_25C_SOC_71: (3601, 9)
#   gitt_restonly_25C_SOC_72: (3601, 9)
#   gitt_restonly_25C_SOC_73: (3601, 9)
#   gitt_restonly_25C_SOC_74: (3601, 9)
#   gitt_restonly_25C_SOC_75: (3601, 9)
#   gitt_restonly_25C_SOC_76: (3600, 9)
#   gitt_restonly_25C_SOC_77: (3601, 9)
#   gitt_restonly_25C_SOC_78: (3601, 9)
#   gitt_restonly_25C_SOC_79: (3601, 9)
#   gitt_restonly_25C_SOC_8: (3601, 9)
#   gitt_restonly_25C_SOC_80: (3601, 9)
#   gitt_restonly_25C_SOC_81: (3601, 9)
#   gitt_restonly_25C_SOC_82: (3601, 9)
#   gitt_restonly_25C_SOC_83: (3601, 9)
#   gitt_restonly_25C_SOC_84: (3601, 9)
#   gitt_restonly_25C_SOC_86: (3601, 9)
#   gitt_restonly_25C_SOC_87: (3601, 9)
#   gitt_restonly_25C_SOC_88: (3601, 9)
#   gitt_restonly_25C_SOC_89: (3601, 9)
#   gitt_restonly_25C_SOC_9: (3601, 9)
#   gitt_restonly_25C_SOC_90: (3601, 9)
#   gitt_restonly_25C_SOC_91: (3601, 9)
#   gitt_restonly_25C_SOC_92: (3601, 9)
#   gitt_restonly_25C_SOC_93: (3601, 9)
#   gitt_restonly_25C_SOC_94: (3601, 9)
#   gitt_restonly_25C_SOC_95: (3601, 9)
#   gitt_restonly_25C_SOC_96: (3601, 9)
#   gitt_restonly_25C_SOC_97: (3601, 9)
#   gitt_restonly_25C_SOC_98: (3601, 9)
#   gitt_restonly_25C_SOC_99: (3601, 9)
#   udds1_1c_norest_25C_struct: (41150, 9)
#   udds2_1c_drivingonly_25C_SOC_100: (721, 9)
#   udds2_1c_drivingonly_25C_SOC_11: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_16: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_21: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_25: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_30: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_35: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_39: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_44: (1800, 9)
#   udds2_1c_drivingonly_25C_SOC_49: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_53: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_58: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_63: (1800, 9)
#   udds2_1c_drivingonly_25C_SOC_67: (1800, 9)
#   udds2_1c_drivingonly_25C_SOC_7: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_72: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_77: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_81: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_86: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_91: (1801, 9)
#   udds2_1c_norest_25C_struct: (36681, 9)
#   udds2_1c_restonly_25C_SOC_100: (10801, 9)
#   udds2_1c_restonly_25C_SOC_11: (10800, 9)
#   udds2_1c_restonly_25C_SOC_16: (10800, 9)
#   udds2_1c_restonly_25C_SOC_21: (10800, 9)
#   udds2_1c_restonly_25C_SOC_25: (10800, 9)
#   udds2_1c_restonly_25C_SOC_30: (10801, 9)
#   udds2_1c_restonly_25C_SOC_35: (10801, 9)
#   udds2_1c_restonly_25C_SOC_39: (10800, 9)
#   udds2_1c_restonly_25C_SOC_44: (10800, 9)
#   udds2_1c_restonly_25C_SOC_49: (10800, 9)
#   udds2_1c_restonly_25C_SOC_53: (10800, 9)
#   udds2_1c_restonly_25C_SOC_58: (10800, 9)
#   udds2_1c_restonly_25C_SOC_63: (10801, 9)
#   udds2_1c_restonly_25C_SOC_67: (10801, 9)
#   udds2_1c_restonly_25C_SOC_7: (10800, 9)
#   udds2_1c_restonly_25C_SOC_72: (10801, 9)
#   udds2_1c_restonly_25C_SOC_77: (10801, 9)
#   udds2_1c_restonly_25C_SOC_81: (10801, 9)
#   udds2_1c_restonly_25C_SOC_86: (10801, 9)
#   udds2_1c_restonly_25C_SOC_91: (10801, 9)
#   udds2_1c_rest_25C_struct: (273245, 9)
#   udds3_1c_norest_25C_struct: (42754, 9)
#   udds4_1c_norest_25C_struct: (68411, 9)
#   udds5_1c_norest_25C_struct: (77084, 9)
#   udds6_1c_norest_25C_struct: (30309, 9)
#   udds7_1c_norest_25C_struct: (33596, 9)
#   udds8_1c_norest_25C_struct: (30939, 9)

# %%
import matplotlib.pyplot as plt

df = extracted_data['udds2_1c_rest_25C_struct']

fig, ax1 = plt.subplots(figsize=(12,6))

# Left y-axis: Vout (Vref) and Vspme
ax1.plot(df['time'], df['Vref'], label='Vout (Vref)', color='C0')
ax1.plot(df['time'], df['Vspme'], label='Vspme', color='C1')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Voltage (V)')
ax1.set_ylim([2.5, 3.6])
ax1.set_title('Vout (Vref) and Vspme vs Time, with Vcorr')
ax1.grid(True)

# Right y-axis: Vcorr = Vout - Vspme
ax2 = ax1.twinx()
Vcorr = df['Vref'] - df['Vspme']
ax2.plot(df['time'], Vcorr, label='Vcorr = Vout - Vspme', color='C2')
ax2.set_ylabel('Vcorr (V)')
# Optionally, you may want to set Vcorr y-limits, e.g.:
# ax2.set_ylim([Vcorr.min(), Vcorr.max()])

# Legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assume df_sampled is already defined just as in the next cell (sampled first 10% of data)
df_vis = df

fig, axs = plt.subplots(4, 1, figsize=(14, 18), sharex=True)

# 1. csn_bulk
axs[0].plot(df_vis["time"], df_vis["c_s_n_bulk"], color="blue")
axs[0].set_ylabel("csn_bulk")
axs[0].set_title("csn_bulk vs Time")
axs[0].grid(True)

# 2. I (Current)
axs[1].plot(df_vis["time"], df_vis["current"], color="red")
axs[1].set_ylabel("Current (A)")
axs[1].set_title("Current vs Time")
axs[1].grid(True)

# 3. Temperature (T)
axs[2].plot(df_vis["time"], df_vis["temperature"], color="orange")
axs[2].set_ylabel("Temperature (°C)")
axs[2].set_title("Temperature vs Time")
axs[2].grid(True)

# 4. Vout, Vspme (left) and Vcorr (right)
ax4 = axs[3]
ax4.plot(df_vis["time"], df_vis["Vref"], label="Vout (Vref)", color="C0")
ax4.plot(df_vis["time"], df_vis["Vspme"], label="Vspme", color="C1")
ax4.set_ylabel("Voltage (V)")
ax4.set_title("Vout, Vspme, and Vcorr (Vout - Vspme) vs Time")
ax4.set_ylim([2.5, 3.6])  # Set voltage axis limits as requested
ax4.grid(True)

ax4r = ax4.twinx()
Vcorr = df_vis["Vref"] - df_vis["Vspme"]
ax4r.plot(df_vis["time"], Vcorr, label="Vcorr = Vout - Vspme", color="C2")
ax4r.set_ylabel("Vcorr (V)")

# Combine legends from both y-axes
lines1, labels1 = ax4.get_legend_handles_labels()
lines2, labels2 = ax4r.get_legend_handles_labels()
ax4.legend(lines1 + lines2, labels1 + labels2, loc="upper right")

axs[3].set_xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %%
# Import the NEW clean implementation
from battery_ode_wrapper import train_battery_neural_ode
import pandas as pd
import re


# 'soc_n' 값이 0.96 ~ 0.12 (96% ~ 12%) 사이인 데이터만 target_data에 저장
# target_data를 리스트(list)로 저장 (DataFrame만 담김, key는 저장하지 않음)
target_keyword = ['restonly']
target_list = []
plt.figure(figsize=(12, 5))

# '정확히 들어있는' key만 골라야 한다.
# 즉, partial match는 안 되고, 부분 단어 단위(예: 'rest')가 key 중 'norest' 등에도 들어가 있으면 제외해야 한다.
# → "정확히 포함" = 'rest'라는 단어가 key에 있는데 앞뒤에 다른 알파벳(예: norest, unrest) 등이 붙어있으면 "rest"만 들어간 것이 아님 → 패턴 분리 필요
# 가장 명확한 건 '_'(언더바) 등으로 단어 구분된 구조에서 "단어 경계" 기준 매칭이다.
# 정규표현식으로 '[^a-zA-Z0-9]' + word + '[^a-zA-Z0-9]' 또는 key.split('_') 등으로 토큰화하여 비교



def match_exact_keywords(key, keywords):
    """
    key가 예: 'udds2_1c_rest_25C_struct' 같이 _로 나눠진 경우,
    keywords 중 하나라도 정확히 단어로써(key의 토큰) 포함되어야 True.
    """
    # 언더스코어 단위 분할
    tokens = re.split(r'[_\s]', key)
    # 모든 keywords가 이 토큰 list에 "정확히 단어로써" 존재하는가?
    return any(word in tokens for word in keywords)

target_list = []
print("extracted_data keys:")
for k in extracted_data.keys():
    print(" -", k)

found_any = False
for k, v in extracted_data.items():
    # 정확히 해당 단어가 분리된 토큰으로 존재하는지 확인
    keyword_match = match_exact_keywords(k, target_keyword)
    print(f"Key: {k}, keyword_match: {keyword_match}, type: {type(v)}")
    if keyword_match:
        if isinstance(v, dict):
            print("  Skipped (dict)")
            continue
        if hasattr(v, "columns") and ("soc_n" in v.columns) and ("Vref" in v.columns):
            mask = (v["soc_n"] >= 0.11) & (v["soc_n"] <= 0.96) & (v["Vref"] >= 2.5)
            filtered_df = v[mask].reset_index(drop=True)
            print(f"  Added! Rows: {len(filtered_df)}")
            target_list.append(filtered_df)
            found_any = True
        else:
            print("  Columns missing, skipped")
print(f"최종 target_list length: {len(target_list)}")
if not found_any:
    print("⚠️ 조건에 맞는 DataFrame이 없습니다. (key 토큰, 컬럼, 타입, 마스킹 등 모두 점검)")




rest_list = remove_duplicates(target_list)

rest_list_smooth = smooth_Vcorr(rest_list, 201) # de-noise data after downsampling

# rest_list_ds = downsample_df(rest_list_smooth, downsample_rate=1)   

rest_list_split = split_df(rest_list_smooth, window_minutes=20, time_col='time', random_seed=42)

rest_dict_list = df2dict(rest_list_split)

# 80:20 split for training and test
training_dict_list, test_dict_list = split_train_test(rest_dict_list, 0.8)
# Out:
# extracted_data keys:
#  - gitt_restonly_25C_SOC_10
#  - gitt_restonly_25C_SOC_100
#  - gitt_restonly_25C_SOC_11
#  - gitt_restonly_25C_SOC_12
#  - gitt_restonly_25C_SOC_13
#  - gitt_restonly_25C_SOC_14
#  - gitt_restonly_25C_SOC_15
#  - gitt_restonly_25C_SOC_16
#  - gitt_restonly_25C_SOC_17
#  - gitt_restonly_25C_SOC_18
#  - gitt_restonly_25C_SOC_19
#  - gitt_restonly_25C_SOC_2
#  - gitt_restonly_25C_SOC_20
#  - gitt_restonly_25C_SOC_21
#  - gitt_restonly_25C_SOC_22
#  - gitt_restonly_25C_SOC_23
#  - gitt_restonly_25C_SOC_25
#  - gitt_restonly_25C_SOC_26
#  - gitt_restonly_25C_SOC_27
#  - gitt_restonly_25C_SOC_28
#  - gitt_restonly_25C_SOC_29
#  - gitt_restonly_25C_SOC_3
#  - gitt_restonly_25C_SOC_30
#  - gitt_restonly_25C_SOC_31
#  - gitt_restonly_25C_SOC_32
#  - gitt_restonly_25C_SOC_33
#  - gitt_restonly_25C_SOC_34
#  - gitt_restonly_25C_SOC_35
#  - gitt_restonly_25C_SOC_36
#  - gitt_restonly_25C_SOC_37
#  - gitt_restonly_25C_SOC_38
#  - gitt_restonly_25C_SOC_39
#  - gitt_restonly_25C_SOC_4
#  - gitt_restonly_25C_SOC_40
#  - gitt_restonly_25C_SOC_41
#  - gitt_restonly_25C_SOC_42
#  - gitt_restonly_25C_SOC_43
#  - gitt_restonly_25C_SOC_44
#  - gitt_restonly_25C_SOC_45
#  - gitt_restonly_25C_SOC_46
#  - gitt_restonly_25C_SOC_47
#  - gitt_restonly_25C_SOC_48
#  - gitt_restonly_25C_SOC_49
#  - gitt_restonly_25C_SOC_5
#  - gitt_restonly_25C_SOC_50
#  - gitt_restonly_25C_SOC_51
#  - gitt_restonly_25C_SOC_52
#  - gitt_restonly_25C_SOC_53
#  - gitt_restonly_25C_SOC_55
#  - gitt_restonly_25C_SOC_56
#  - gitt_restonly_25C_SOC_57
#  - gitt_restonly_25C_SOC_58
#  - gitt_restonly_25C_SOC_59
#  - gitt_restonly_25C_SOC_6
#  - gitt_restonly_25C_SOC_60
#  - gitt_restonly_25C_SOC_61
#  - gitt_restonly_25C_SOC_62
#  - gitt_restonly_25C_SOC_63
#  - gitt_restonly_25C_SOC_64
#  - gitt_restonly_25C_SOC_65
#  - gitt_restonly_25C_SOC_66
#  - gitt_restonly_25C_SOC_67
#  - gitt_restonly_25C_SOC_68
#  - gitt_restonly_25C_SOC_69
#  - gitt_restonly_25C_SOC_7
#  - gitt_restonly_25C_SOC_70
#  - gitt_restonly_25C_SOC_71
#  - gitt_restonly_25C_SOC_72
# Warning: Data length is less than window_size, skipping smoothing. window_size: 201, data length: 0
# - df65: 0 -> 0 (smoothing done)
# - df66: 3601 -> 3601 (smoothing done)
# - df67: 3601 -> 3601 (smoothing done)
# - df68: 3601 -> 3601 (smoothing done)
# - df69: 3601 -> 3601 (smoothing done)
# - df70: 3601 -> 3601 (smoothing done)
# - df71: 3601 -> 3601 (smoothing done)
# - df72: 3600 -> 3600 (smoothing done)
# - df73: 3601 -> 3601 (smoothing done)
# - df74: 3601 -> 3601 (smoothing done)
# - df75: 3601 -> 3601 (smoothing done)
# Warning: Data length is less than window_size, skipping smoothing. window_size: 201, data length: 0
# - df76: 0 -> 0 (smoothing done)
# - df77: 3601 -> 3601 (smoothing done)
# - df78: 3601 -> 3601 (smoothing done)
# - df79: 3601 -> 3601 (smoothing done)
# - df80: 3601 -> 3601 (smoothing done)
# - df81: 3601 -> 3601 (smoothing done)
# - df82: 3600 -> 3600 (smoothing done)
# - df83: 3601 -> 3601 (smoothing done)
# - df84: 3601 -> 3601 (smoothing done)
# - df85: 3600 -> 3600 (smoothing done)
# Warning: Data length is less than window_size, skipping smoothing. window_size: 201, data length: 0
# - df86: 0 -> 0 (smoothing done)
# - df87: 3601 -> 3601 (smoothing done)
# - df88: 3601 -> 3601 (smoothing done)
# - df89: 3601 -> 3601 (smoothing done)
# - df90: 3601 -> 3601 (smoothing done)
# - df91: 3601 -> 3601 (smoothing done)
# - df92: 3601 -> 3601 (smoothing done)
# - df93: 3601 -> 3601 (smoothing done)
# - df94: 3601 -> 3601 (smoothing done)
# Warning: Data length is less than window_size, skipping smoothing. window_size: 201, data length: 0
# - df95: 0 -> 0 (smoothing done)
# Warning: Data length is less than window_size, skipping smoothing. window_size: 201, data length: 0
# - df96: 0 -> 0 (smoothing done)
# - df97: 10800 -> 10800 (smoothing done)
# Warning: Data length is less than window_size, skipping smoothing. window_size: 201, data length: 0
# - df98: 0 -> 0 (smoothing done)
# - df99: 10800 -> 10800 (smoothing done)
# - df100: 10800 -> 10800 (smoothing done)
# - df101: 10800 -> 10800 (smoothing done)
# - df102: 10801 -> 10801 (smoothing done)
# - df103: 10801 -> 10801 (smoothing done)
# - df104: 10800 -> 10800 (smoothing done)
# - df105: 10800 -> 10800 (smoothing done)
# - df106: 10800 -> 10800 (smoothing done)
# - df107: 10800 -> 10800 (smoothing done)
# - df108: 10800 -> 10800 (smoothing done)
# - df109: 10801 -> 10801 (smoothing done)
# - df110: 10800 -> 10800 (smoothing done)
# Warning: Data length is less than window_size, skipping smoothing. window_size: 201, data length: 0
# - df111: 0 -> 0 (smoothing done)
# - df112: 10800 -> 10800 (smoothing done)
# - df113: 10801 -> 10801 (smoothing done)
# - df114: 10801 -> 10801 (smoothing done)
# - df115: 10801 -> 10801 (smoothing done)
# - df116: 10801 -> 10801 (smoothing done)
# smooth_Vcorr() completed
# ==================================================
# ==================================================
# Starting 'split_df()'
# Number of df in the list : 116
# Total time in the list: 493099.05 sec
# window_minutes: 20 min
# Final number of df: 411
# split_df() completed
# ==================================================
# ==================================================
# Starting 'df2dict()'
# Total number of df in the list: 411
# Number of converted df: 411
# df2dict() completed
# ==================================================
# ==================================================
# Starting 'split_train_test()'
# Total length of dict: 411
# Number of train dict: 328 (79.8%)
# Number of test dict: 83 (20.2%)
# split_train_test() completed
# ==================================================

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
for i, df in enumerate(rest_list_smooth):
    plt.plot(df['time'], df['Vref'], label=f'Profile {i+1}', alpha=0.7)
plt.xlabel('Time')
plt.ylabel('V_ref')
plt.title('V_ref vs Time for each DataFrame in rest_list_smooth')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1197.0s', '1198.0s', '1199.0s', '1199.0s', '1200.0s', '1200.0s', '1197.0s', '1199.0s', '1199.0s', '1196.0s', '1200.0s', '1199.0s', '1195.0s', '1200.0s', '1199.0s', '1200.0s', '1200.0s', '1197.0s', '1195.0s', '1200.0s', '1200.0s', '1200.0s', '1198.0s', '1199.0s', '1197.0s', '1200.0s', '1200.0s', '1199.0s', '1200.0s', '1197.0s', '1197.0s', '1199.0s', '1199.0s', '1198.0s', '1200.0s', '1200.0s', '1200.0s', '1199.0s', '1200.0s', '1200.0s', '1200.0s', '1199.0s', '1200.0s', '1198.0s', '1197.0s', '1200.0s', '1198.0s', '1199.0s', '1200.0s', '1199.0s', '1198.0s', '1200.0s', '1198.0s', '1200.0s', '1197.0s', '1199.0s', '1199.0s', '1200.0s', '1197.0s', '1200.0s', '1197.0s', '1200.0s', '1200.0s', '1200.0s', '1197.0s', '1199.0s', '1200.0s', '1200.0s', '1200.0s', '1200.0s', '1200.0s', '1198.0s', '1199.0s', '1198.0s', '1200.0s', '1200.0s', '1199.0s', '1200.0s', '1199.0s', '1200.0s', '1199.0s', '1200.0s', '1200.0s', '1200.0s', '1200.0s', '1198.0s', '1199.0s', '1197.0s', '1199.0s', '1198.0s', '1199.0s', '1199.0s', '1198.0s', '1193.0s', '1199.0s', '1200.0s', '1198.0s', '1199.0s', '1200.0s', '1200.0s', '1199.0s', '1200.0s', '1199.0s', '1199.0s', '1197.0s', '1197.0s', '1200.0s', '1200.0s', '1198.0s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1200.0s', '1200.0s', '1198.0s']
# Common time vector: [0, 1200.0] with 1201 points
# ✓ Batch inputs set: 328 profiles, 1201 time steps
#
# ============================================================
# Neural Network Architecture
# ============================================================
# Sequential(
#   (0): Linear(in_features=6, out_features=16, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=16, out_features=1, bias=True)
# )
# ============================================================
#
# ============================================================
# Training Settings
# ============================================================
# Total profiles: 328
# Training batch size: 328
# Common time points: 1201
# Max epochs: 3000
# Initial LR: 0.0005
# Device: cuda
# Patience: 10
# Alpha: 1.00, Beta: 0.00, Gamma: 0.00
# GPU: 210MB
# Grad clip max: 50
# Method: euler
# Verbose: True
# ============================================================
# Starting batch training...
# Targets shape: torch.Size([328, 1201])
# Target range: -6.699 ~ 4.787
# ✅ Best RMSE: 10.64mV at Epoch 1
# Epoch   1/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 10.64mV | loss_V: 7.0734 | loss_dVdt: 4.35e-04 | Steps: 1200 | Grad: 69.45 → 50.00
# ✅ Best RMSE: 10.46mV at Epoch 2
# Epoch   2/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 10.46mV | loss_V: 6.8441 | loss_dVdt: 4.32e-04 | Steps: 1200 | Grad: 65.87 → 50.00
# ✅ Best RMSE: 10.30mV at Epoch 3
# Epoch   3/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 10.30mV | loss_V: 6.6275 | loss_dVdt: 4.30e-04 | Steps: 1200 | Grad: 62.56 → 50.00
# ✅ Best RMSE: 10.14mV at Epoch 4
# Epoch   4/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 10.14mV | loss_V: 6.4228 | loss_dVdt: 4.28e-04 | Steps: 1200 | Grad: 59.51 → 50.00
# ✅ Best RMSE: 9.98mV at Epoch 5
# Epoch   5/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.98mV | loss_V: 6.2292 | loss_dVdt: 4.26e-04 | Steps: 1200 | Grad: 56.70 → 50.00
# ✅ Best RMSE: 9.84mV at Epoch 6
# Epoch   6/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.84mV | loss_V: 6.0460 | loss_dVdt: 4.25e-04 | Steps: 1200 | Grad: 54.11 → 50.00
# ✅ Best RMSE: 9.69mV at Epoch 7
# Epoch   7/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.69mV | loss_V: 5.8725 | loss_dVdt: 4.23e-04 | Steps: 1200 | Grad: 51.73 → 50.00
# ✅ Best RMSE: 9.56mV at Epoch 8
# Epoch   8/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.56mV | loss_V: 5.7078 | loss_dVdt: 4.22e-04 | Steps: 1200 | Grad: 49.54 → 49.54
# ✅ Best RMSE: 9.42mV at Epoch 9
# Epoch   9/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.42mV | loss_V: 5.5514 | loss_dVdt: 4.20e-04 | Steps: 1200 | Grad: 47.54 → 47.54
# ✅ Best RMSE: 9.30mV at Epoch 10
# Epoch  10/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.30mV | loss_V: 5.4027 | loss_dVdt: 4.18e-04 | Steps: 1200 | Grad: 45.71 → 45.71
# ✅ Best RMSE: 9.17mV at Epoch 11
# Epoch  11/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.17mV | loss_V: 5.2613 | loss_dVdt: 4.16e-04 | Steps: 1200 | Grad: 44.03 → 44.03
# ✅ Best RMSE: 9.06mV at Epoch 12
# Epoch  12/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 9.06mV | loss_V: 5.1266 | loss_dVdt: 4.14e-04 | Steps: 1200 | Grad: 42.50 → 42.50
# ✅ Best RMSE: 8.94mV at Epoch 13
# Epoch  13/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.94mV | loss_V: 4.9982 | loss_dVdt: 4.12e-04 | Steps: 1200 | Grad: 41.11 → 41.11
# ✅ Best RMSE: 8.83mV at Epoch 14
# Epoch  14/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.83mV | loss_V: 4.8754 | loss_dVdt: 4.10e-04 | Steps: 1200 | Grad: 39.82 → 39.82
# ✅ Best RMSE: 8.73mV at Epoch 15
# Epoch  15/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.73mV | loss_V: 4.7580 | loss_dVdt: 4.07e-04 | Steps: 1200 | Grad: 38.65 → 38.65
# ✅ Best RMSE: 8.62mV at Epoch 16
# Epoch  16/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.62mV | loss_V: 4.6453 | loss_dVdt: 4.04e-04 | Steps: 1200 | Grad: 37.57 → 37.57
# ✅ Best RMSE: 8.52mV at Epoch 17
# Epoch  17/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.52mV | loss_V: 4.5370 | loss_dVdt: 4.01e-04 | Steps: 1200 | Grad: 36.58 → 36.58
# ✅ Best RMSE: 8.42mV at Epoch 18
# Epoch  18/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.42mV | loss_V: 4.4327 | loss_dVdt: 3.98e-04 | Steps: 1200 | Grad: 35.66 → 35.66
# ✅ Best RMSE: 8.33mV at Epoch 19
# Epoch  19/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.33mV | loss_V: 4.3319 | loss_dVdt: 3.95e-04 | Steps: 1200 | Grad: 34.82 → 34.82
# ✅ Best RMSE: 8.23mV at Epoch 20
# Epoch  20/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.23mV | loss_V: 4.2343 | loss_dVdt: 3.91e-04 | Steps: 1200 | Grad: 34.04 → 34.04
# ✅ Best RMSE: 8.14mV at Epoch 21
# Epoch  21/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.14mV | loss_V: 4.1396 | loss_dVdt: 3.87e-04 | Steps: 1200 | Grad: 33.32 → 33.32
# ✅ Best RMSE: 8.05mV at Epoch 22
# Epoch  22/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 8.05mV | loss_V: 4.0475 | loss_dVdt: 3.83e-04 | Steps: 1200 | Grad: 32.64 → 32.64
# ✅ Best RMSE: 7.96mV at Epoch 23
# Epoch  23/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.96mV | loss_V: 3.9576 | loss_dVdt: 3.79e-04 | Steps: 1200 | Grad: 32.02 → 32.02
# ✅ Best RMSE: 7.87mV at Epoch 24
# Epoch  24/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.87mV | loss_V: 3.8699 | loss_dVdt: 3.75e-04 | Steps: 1200 | Grad: 31.43 → 31.43
# ✅ Best RMSE: 7.78mV at Epoch 25
# Epoch  25/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.78mV | loss_V: 3.7839 | loss_dVdt: 3.70e-04 | Steps: 1200 | Grad: 30.88 → 30.88
# ✅ Best RMSE: 7.69mV at Epoch 26
# Epoch  26/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.69mV | loss_V: 3.6997 | loss_dVdt: 3.65e-04 | Steps: 1200 | Grad: 30.35 → 30.35
# ✅ Best RMSE: 7.61mV at Epoch 27
# Epoch  27/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.61mV | loss_V: 3.6169 | loss_dVdt: 3.60e-04 | Steps: 1200 | Grad: 29.85 → 29.85
# ✅ Best RMSE: 7.52mV at Epoch 28
# Epoch  28/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.52mV | loss_V: 3.5356 | loss_dVdt: 3.55e-04 | Steps: 1200 | Grad: 29.38 → 29.38
# ✅ Best RMSE: 7.44mV at Epoch 29
# Epoch  29/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.44mV | loss_V: 3.4555 | loss_dVdt: 3.49e-04 | Steps: 1200 | Grad: 28.92 → 28.92
# ✅ Best RMSE: 7.35mV at Epoch 30
# Epoch  30/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.35mV | loss_V: 3.3766 | loss_dVdt: 3.44e-04 | Steps: 1200 | Grad: 28.47 → 28.47
# ✅ Best RMSE: 7.27mV at Epoch 31
# Epoch  31/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.27mV | loss_V: 3.2988 | loss_dVdt: 3.38e-04 | Steps: 1200 | Grad: 28.03 → 28.03
# ✅ Best RMSE: 7.18mV at Epoch 32
# Epoch  32/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.18mV | loss_V: 3.2221 | loss_dVdt: 3.32e-04 | Steps: 1200 | Grad: 27.60 → 27.60
# ✅ Best RMSE: 7.10mV at Epoch 33
# Epoch  33/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.10mV | loss_V: 3.1465 | loss_dVdt: 3.26e-04 | Steps: 1200 | Grad: 27.17 → 27.17
# ✅ Best RMSE: 7.01mV at Epoch 34
# Epoch  34/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 7.01mV | loss_V: 3.0719 | loss_dVdt: 3.20e-04 | Steps: 1200 | Grad: 26.74 → 26.74
# ✅ Best RMSE: 6.93mV at Epoch 35
# Epoch  35/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.93mV | loss_V: 2.9984 | loss_dVdt: 3.14e-04 | Steps: 1200 | Grad: 26.30 → 26.30
# ✅ Best RMSE: 6.84mV at Epoch 36
# Epoch  36/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.84mV | loss_V: 2.9260 | loss_dVdt: 3.08e-04 | Steps: 1200 | Grad: 25.86 → 25.86
# ✅ Best RMSE: 6.76mV at Epoch 37
# Epoch  37/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.76mV | loss_V: 2.8548 | loss_dVdt: 3.02e-04 | Steps: 1200 | Grad: 25.40 → 25.40
# ✅ Best RMSE: 6.68mV at Epoch 38
# Epoch  38/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.68mV | loss_V: 2.7847 | loss_dVdt: 2.96e-04 | Steps: 1200 | Grad: 24.93 → 24.93
# ✅ Best RMSE: 6.59mV at Epoch 39
# Epoch  39/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.59mV | loss_V: 2.7160 | loss_dVdt: 2.90e-04 | Steps: 1200 | Grad: 24.44 → 24.44
# ✅ Best RMSE: 6.51mV at Epoch 40
# Epoch  40/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.51mV | loss_V: 2.6486 | loss_dVdt: 2.84e-04 | Steps: 1200 | Grad: 23.92 → 23.92
# ✅ Best RMSE: 6.43mV at Epoch 41
# Epoch  41/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.43mV | loss_V: 2.5828 | loss_dVdt: 2.78e-04 | Steps: 1200 | Grad: 23.38 → 23.38
# ✅ Best RMSE: 6.35mV at Epoch 42
# Epoch  42/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.35mV | loss_V: 2.5185 | loss_dVdt: 2.72e-04 | Steps: 1200 | Grad: 22.80 → 22.80
# ✅ Best RMSE: 6.27mV at Epoch 43
# Epoch  43/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.27mV | loss_V: 2.4560 | loss_dVdt: 2.66e-04 | Steps: 1200 | Grad: 22.19 → 22.19
# ✅ Best RMSE: 6.19mV at Epoch 44
# Epoch  44/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.19mV | loss_V: 2.3955 | loss_dVdt: 2.60e-04 | Steps: 1200 | Grad: 21.54 → 21.54
# ✅ Best RMSE: 6.11mV at Epoch 45
# Epoch  45/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.11mV | loss_V: 2.3370 | loss_dVdt: 2.54e-04 | Steps: 1200 | Grad: 20.84 → 20.84
# ✅ Best RMSE: 6.04mV at Epoch 46
# Epoch  46/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.04mV | loss_V: 2.2807 | loss_dVdt: 2.48e-04 | Steps: 1200 | Grad: 20.10 → 20.10
# ✅ Best RMSE: 5.97mV at Epoch 47
# Epoch  47/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.97mV | loss_V: 2.2269 | loss_dVdt: 2.43e-04 | Steps: 1200 | Grad: 19.31 → 19.31
# ✅ Best RMSE: 5.90mV at Epoch 48
# Epoch  48/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.90mV | loss_V: 2.1757 | loss_dVdt: 2.37e-04 | Steps: 1200 | Grad: 18.46 → 18.46
# ✅ Best RMSE: 5.83mV at Epoch 49
# Epoch  49/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.83mV | loss_V: 2.1274 | loss_dVdt: 2.32e-04 | Steps: 1200 | Grad: 17.55 → 17.55
# ✅ Best RMSE: 5.77mV at Epoch 50
# Epoch  50/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.77mV | loss_V: 2.0820 | loss_dVdt: 2.27e-04 | Steps: 1200 | Grad: 16.59 → 16.59
# ✅ Best RMSE: 5.71mV at Epoch 51
# Epoch  51/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.71mV | loss_V: 2.0399 | loss_dVdt: 2.22e-04 | Steps: 1200 | Grad: 15.57 → 15.57
# ✅ Best RMSE: 5.66mV at Epoch 52
# Epoch  52/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.66mV | loss_V: 2.0013 | loss_dVdt: 2.17e-04 | Steps: 1200 | Grad: 14.49 → 14.49
# ✅ Best RMSE: 5.61mV at Epoch 53
# Epoch  53/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.61mV | loss_V: 1.9661 | loss_dVdt: 2.13e-04 | Steps: 1200 | Grad: 13.36 → 13.36
# ✅ Best RMSE: 5.56mV at Epoch 54
# Epoch  54/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.56mV | loss_V: 1.9347 | loss_dVdt: 2.08e-04 | Steps: 1200 | Grad: 12.18 → 12.18
# ✅ Best RMSE: 5.52mV at Epoch 55
# Epoch  55/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.52mV | loss_V: 1.9071 | loss_dVdt: 2.04e-04 | Steps: 1200 | Grad: 10.98 → 10.98
# ✅ Best RMSE: 5.49mV at Epoch 56
# Epoch  56/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.49mV | loss_V: 1.8833 | loss_dVdt: 2.00e-04 | Steps: 1200 | Grad: 9.76 → 9.76
# ✅ Best RMSE: 5.46mV at Epoch 57
# Epoch  57/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.46mV | loss_V: 1.8634 | loss_dVdt: 1.97e-04 | Steps: 1200 | Grad: 8.56 → 8.56
# ✅ Best RMSE: 5.44mV at Epoch 58
# Epoch  58/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.44mV | loss_V: 1.8472 | loss_dVdt: 1.93e-04 | Steps: 1200 | Grad: 7.43 → 7.43
# ✅ Best RMSE: 5.42mV at Epoch 59
# Epoch  59/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.42mV | loss_V: 1.8345 | loss_dVdt: 1.90e-04 | Steps: 1200 | Grad: 6.43 → 6.43
# ✅ Best RMSE: 5.40mV at Epoch 60
# Epoch  60/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.40mV | loss_V: 1.8250 | loss_dVdt: 1.88e-04 | Steps: 1200 | Grad: 5.65 → 5.65
# ✅ Best RMSE: 5.39mV at Epoch 61
# Epoch  61/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8186 | loss_dVdt: 1.85e-04 | Steps: 1200 | Grad: 5.21 → 5.21
# ✅ Best RMSE: 5.39mV at Epoch 62
# Epoch  62/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8146 | loss_dVdt: 1.83e-04 | Steps: 1200 | Grad: 5.15 → 5.15
# ✅ Best RMSE: 5.39mV at Epoch 63
# Epoch  63/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8125 | loss_dVdt: 1.81e-04 | Steps: 1200 | Grad: 5.43 → 5.43
# ✅ Best RMSE: 5.38mV at Epoch 64
# Epoch  64/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.38mV | loss_V: 1.8120 | loss_dVdt: 1.79e-04 | Steps: 1200 | Grad: 5.94 → 5.94
# Epoch  65/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.38mV | loss_V: 1.8123 | loss_dVdt: 1.78e-04 | Steps: 1200 | Grad: 6.54 → 6.54
# Epoch  66/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8131 | loss_dVdt: 1.77e-04 | Steps: 1200 | Grad: 7.14 → 7.14
# Epoch  67/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8138 | loss_dVdt: 1.76e-04 | Steps: 1200 | Grad: 7.65 → 7.65
# Epoch  68/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8140 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 8.04 → 8.04
# Epoch  69/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8136 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 8.29 → 8.29
# Epoch  70/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.39mV | loss_V: 1.8125 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 8.39 → 8.39
# ✅ Best RMSE: 5.38mV at Epoch 71
# Epoch  71/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.38mV | loss_V: 1.8105 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 8.34 → 8.34
# ✅ Best RMSE: 5.38mV at Epoch 72
# Epoch  72/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.38mV | loss_V: 1.8077 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 8.15 → 8.15
# ✅ Best RMSE: 5.37mV at Epoch 73
# Epoch  73/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.37mV | loss_V: 1.8043 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 7.85 → 7.85
# ✅ Best RMSE: 5.37mV at Epoch 74
# Epoch  74/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.37mV | loss_V: 1.8005 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 7.44 → 7.44
# ✅ Best RMSE: 5.36mV at Epoch 75
# Epoch  75/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.36mV | loss_V: 1.7964 | loss_dVdt: 1.76e-04 | Steps: 1200 | Grad: 6.97 → 6.97
# ✅ Best RMSE: 5.36mV at Epoch 76
# Epoch  76/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.36mV | loss_V: 1.7923 | loss_dVdt: 1.76e-04 | Steps: 1200 | Grad: 6.44 → 6.44
# ✅ Best RMSE: 5.35mV at Epoch 77
# Epoch  77/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.35mV | loss_V: 1.7882 | loss_dVdt: 1.77e-04 | Steps: 1200 | Grad: 5.88 → 5.88
# ✅ Best RMSE: 5.34mV at Epoch 78
# Epoch  78/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.34mV | loss_V: 1.7843 | loss_dVdt: 1.78e-04 | Steps: 1200 | Grad: 5.32 → 5.32
# ✅ Best RMSE: 5.34mV at Epoch 79
# Epoch  79/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.34mV | loss_V: 1.7808 | loss_dVdt: 1.78e-04 | Steps: 1200 | Grad: 4.78 → 4.78
# ✅ Best RMSE: 5.33mV at Epoch 80
# Epoch  80/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.33mV | loss_V: 1.7776 | loss_dVdt: 1.79e-04 | Steps: 1200 | Grad: 4.28 → 4.28
# ✅ Best RMSE: 5.33mV at Epoch 81
# Epoch  81/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.33mV | loss_V: 1.7747 | loss_dVdt: 1.80e-04 | Steps: 1200 | Grad: 3.83 → 3.83
# ✅ Best RMSE: 5.33mV at Epoch 82
# Epoch  82/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.33mV | loss_V: 1.7723 | loss_dVdt: 1.80e-04 | Steps: 1200 | Grad: 3.45 → 3.45
# ✅ Best RMSE: 5.32mV at Epoch 83
# Epoch  83/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.32mV | loss_V: 1.7702 | loss_dVdt: 1.81e-04 | Steps: 1200 | Grad: 3.16 → 3.16
# ✅ Best RMSE: 5.32mV at Epoch 84
# Epoch  84/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.32mV | loss_V: 1.7683 | loss_dVdt: 1.81e-04 | Steps: 1200 | Grad: 2.96 → 2.96
# ✅ Best RMSE: 5.32mV at Epoch 85
# Epoch  85/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.32mV | loss_V: 1.7668 | loss_dVdt: 1.82e-04 | Steps: 1200 | Grad: 2.84 → 2.84
# ✅ Best RMSE: 5.31mV at Epoch 86
# Epoch  86/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.31mV | loss_V: 1.7654 | loss_dVdt: 1.82e-04 | Steps: 1200 | Grad: 2.79 → 2.79
# ✅ Best RMSE: 5.31mV at Epoch 87
# Epoch  87/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.31mV | loss_V: 1.7641 | loss_dVdt: 1.82e-04 | Steps: 1200 | Grad: 2.80 → 2.80
# ✅ Best RMSE: 5.31mV at Epoch 88
# Epoch  88/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.31mV | loss_V: 1.7629 | loss_dVdt: 1.83e-04 | Steps: 1200 | Grad: 2.85 → 2.85
# ✅ Best RMSE: 5.31mV at Epoch 89
# Epoch  89/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.31mV | loss_V: 1.7618 | loss_dVdt: 1.83e-04 | Steps: 1200 | Grad: 2.92 → 2.92
# ✅ Best RMSE: 5.31mV at Epoch 90
# Epoch  90/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.31mV | loss_V: 1.7606 | loss_dVdt: 1.83e-04 | Steps: 1200 | Grad: 2.99 → 2.99
# ✅ Best RMSE: 5.31mV at Epoch 91
# Epoch  91/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.31mV | loss_V: 1.7594 | loss_dVdt: 1.82e-04 | Steps: 1200 | Grad: 3.06 → 3.06
# ✅ Best RMSE: 5.30mV at Epoch 92
# Epoch  92/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.30mV | loss_V: 1.7581 | loss_dVdt: 1.82e-04 | Steps: 1200 | Grad: 3.12 → 3.12
# ✅ Best RMSE: 5.30mV at Epoch 93
# Epoch  93/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.30mV | loss_V: 1.7567 | loss_dVdt: 1.82e-04 | Steps: 1200 | Grad: 3.16 → 3.16
# ✅ Best RMSE: 5.30mV at Epoch 94
# Epoch  94/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.30mV | loss_V: 1.7552 | loss_dVdt: 1.82e-04 | Steps: 1200 | Grad: 3.19 → 3.19
# ✅ Best RMSE: 5.30mV at Epoch 95
# Epoch  95/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.30mV | loss_V: 1.7537 | loss_dVdt: 1.81e-04 | Steps: 1200 | Grad: 3.20 → 3.20
# ✅ Best RMSE: 5.29mV at Epoch 96
# Epoch  96/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.29mV | loss_V: 1.7520 | loss_dVdt: 1.81e-04 | Steps: 1200 | Grad: 3.20 → 3.20
# ✅ Best RMSE: 5.29mV at Epoch 97
# Epoch  97/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.29mV | loss_V: 1.7503 | loss_dVdt: 1.80e-04 | Steps: 1200 | Grad: 3.18 → 3.18
# ✅ Best RMSE: 5.29mV at Epoch 98
# Epoch  98/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.29mV | loss_V: 1.7485 | loss_dVdt: 1.79e-04 | Steps: 1200 | Grad: 3.15 → 3.15
# ✅ Best RMSE: 5.29mV at Epoch 99
# Epoch  99/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.29mV | loss_V: 1.7466 | loss_dVdt: 1.79e-04 | Steps: 1200 | Grad: 3.12 → 3.12
# ✅ Best RMSE: 5.28mV at Epoch 100
# Epoch 100/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.28mV | loss_V: 1.7447 | loss_dVdt: 1.78e-04 | Steps: 1200 | Grad: 3.08 → 3.08
# ✅ Best RMSE: 5.28mV at Epoch 101
# Epoch 101/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.28mV | loss_V: 1.7427 | loss_dVdt: 1.77e-04 | Steps: 1200 | Grad: 3.03 → 3.03
# ✅ Best RMSE: 5.28mV at Epoch 102
# Epoch 102/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.28mV | loss_V: 1.7408 | loss_dVdt: 1.76e-04 | Steps: 1200 | Grad: 3.00 → 3.00
# ✅ Best RMSE: 5.27mV at Epoch 103
# Epoch 103/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.27mV | loss_V: 1.7388 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 2.96 → 2.96
# ✅ Best RMSE: 5.27mV at Epoch 104
# Epoch 104/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.27mV | loss_V: 1.7369 | loss_dVdt: 1.75e-04 | Steps: 1200 | Grad: 2.93 → 2.93
# ✅ Best RMSE: 5.27mV at Epoch 105
# Epoch 105/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.27mV | loss_V: 1.7349 | loss_dVdt: 1.74e-04 | Steps: 1200 | Grad: 2.91 → 2.91
# ✅ Best RMSE: 5.27mV at Epoch 106
# Epoch 106/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.27mV | loss_V: 1.7330 | loss_dVdt: 1.73e-04 | Steps: 1200 | Grad: 2.91 → 2.91
# ✅ Best RMSE: 5.26mV at Epoch 107
# Epoch 107/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.26mV | loss_V: 1.7311 | loss_dVdt: 1.72e-04 | Steps: 1200 | Grad: 2.91 → 2.91
# ✅ Best RMSE: 5.26mV at Epoch 108
# Epoch 108/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.26mV | loss_V: 1.7292 | loss_dVdt: 1.71e-04 | Steps: 1200 | Grad: 2.92 → 2.92
# ✅ Best RMSE: 5.26mV at Epoch 109
# Epoch 109/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.26mV | loss_V: 1.7273 | loss_dVdt: 1.70e-04 | Steps: 1200 | Grad: 2.94 → 2.94
# ✅ Best RMSE: 5.25mV at Epoch 110
# Epoch 110/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.25mV | loss_V: 1.7255 | loss_dVdt: 1.69e-04 | Steps: 1200 | Grad: 2.97 → 2.97
# ✅ Best RMSE: 5.25mV at Epoch 111
# Epoch 111/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.25mV | loss_V: 1.7236 | loss_dVdt: 1.69e-04 | Steps: 1200 | Grad: 3.00 → 3.00
# ✅ Best RMSE: 5.25mV at Epoch 112
# Epoch 112/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.25mV | loss_V: 1.7217 | loss_dVdt: 1.68e-04 | Steps: 1200 | Grad: 3.04 → 3.04
# ✅ Best RMSE: 5.25mV at Epoch 113
# Epoch 113/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.25mV | loss_V: 1.7198 | loss_dVdt: 1.67e-04 | Steps: 1200 | Grad: 3.07 → 3.07
# ✅ Best RMSE: 5.24mV at Epoch 114
# Epoch 114/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.24mV | loss_V: 1.7179 | loss_dVdt: 1.66e-04 | Steps: 1200 | Grad: 3.11 → 3.11
# ✅ Best RMSE: 5.24mV at Epoch 115
# Epoch 115/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.24mV | loss_V: 1.7160 | loss_dVdt: 1.65e-04 | Steps: 1200 | Grad: 3.14 → 3.14
# ✅ Best RMSE: 5.24mV at Epoch 116
# Epoch 116/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.24mV | loss_V: 1.7141 | loss_dVdt: 1.65e-04 | Steps: 1200 | Grad: 3.16 → 3.16
# ✅ Best RMSE: 5.23mV at Epoch 117
# Epoch 117/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.23mV | loss_V: 1.7121 | loss_dVdt: 1.64e-04 | Steps: 1200 | Grad: 3.18 → 3.18
# ✅ Best RMSE: 5.23mV at Epoch 118
# Epoch 118/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.23mV | loss_V: 1.7101 | loss_dVdt: 1.63e-04 | Steps: 1200 | Grad: 3.20 → 3.20
# ✅ Best RMSE: 5.23mV at Epoch 119
# Epoch 119/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.23mV | loss_V: 1.7081 | loss_dVdt: 1.63e-04 | Steps: 1200 | Grad: 3.21 → 3.21
# ✅ Best RMSE: 5.22mV at Epoch 120
# Epoch 120/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.22mV | loss_V: 1.7060 | loss_dVdt: 1.62e-04 | Steps: 1200 | Grad: 3.22 → 3.22
# ✅ Best RMSE: 5.22mV at Epoch 121
# Epoch 121/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.22mV | loss_V: 1.7040 | loss_dVdt: 1.62e-04 | Steps: 1200 | Grad: 3.22 → 3.22
# ✅ Best RMSE: 5.22mV at Epoch 122
# Epoch 122/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.22mV | loss_V: 1.7019 | loss_dVdt: 1.61e-04 | Steps: 1200 | Grad: 3.22 → 3.22
# ✅ Best RMSE: 5.22mV at Epoch 123
# Epoch 123/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.22mV | loss_V: 1.6998 | loss_dVdt: 1.60e-04 | Steps: 1200 | Grad: 3.22 → 3.22
# ✅ Best RMSE: 5.21mV at Epoch 124
# Epoch 124/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.21mV | loss_V: 1.6977 | loss_dVdt: 1.60e-04 | Steps: 1200 | Grad: 3.22 → 3.22
# ✅ Best RMSE: 5.21mV at Epoch 125
# Epoch 125/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.21mV | loss_V: 1.6955 | loss_dVdt: 1.59e-04 | Steps: 1200 | Grad: 3.21 → 3.21
# ✅ Best RMSE: 5.21mV at Epoch 126
# Epoch 126/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.21mV | loss_V: 1.6934 | loss_dVdt: 1.59e-04 | Steps: 1200 | Grad: 3.21 → 3.21
# ✅ Best RMSE: 5.20mV at Epoch 127
# Epoch 127/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.20mV | loss_V: 1.6912 | loss_dVdt: 1.58e-04 | Steps: 1200 | Grad: 3.21 → 3.21
# ✅ Best RMSE: 5.20mV at Epoch 128
# Epoch 128/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.20mV | loss_V: 1.6890 | loss_dVdt: 1.57e-04 | Steps: 1200 | Grad: 3.20 → 3.20
# ✅ Best RMSE: 5.20mV at Epoch 129
# Epoch 129/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.20mV | loss_V: 1.6868 | loss_dVdt: 1.57e-04 | Steps: 1200 | Grad: 3.20 → 3.20
# ✅ Best RMSE: 5.19mV at Epoch 130
# Epoch 130/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.19mV | loss_V: 1.6845 | loss_dVdt: 1.56e-04 | Steps: 1200 | Grad: 3.21 → 3.21
# ✅ Best RMSE: 5.19mV at Epoch 131
# Epoch 131/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.19mV | loss_V: 1.6823 | loss_dVdt: 1.55e-04 | Steps: 1200 | Grad: 3.21 → 3.21
# ✅ Best RMSE: 5.18mV at Epoch 132
# Epoch 132/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.18mV | loss_V: 1.6800 | loss_dVdt: 1.55e-04 | Steps: 1200 | Grad: 3.21 → 3.21
# ✅ Best RMSE: 5.18mV at Epoch 133
# Epoch 133/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.18mV | loss_V: 1.6777 | loss_dVdt: 1.54e-04 | Steps: 1200 | Grad: 3.22 → 3.22
# ✅ Best RMSE: 5.18mV at Epoch 134
# Epoch 134/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.18mV | loss_V: 1.6754 | loss_dVdt: 1.53e-04 | Steps: 1200 | Grad: 3.23 → 3.23
# ✅ Best RMSE: 5.17mV at Epoch 135
# Epoch 135/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.17mV | loss_V: 1.6731 | loss_dVdt: 1.53e-04 | Steps: 1200 | Grad: 3.24 → 3.24
# ✅ Best RMSE: 5.17mV at Epoch 136
# Epoch 136/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.17mV | loss_V: 1.6707 | loss_dVdt: 1.52e-04 | Steps: 1200 | Grad: 3.25 → 3.25
# ✅ Best RMSE: 5.17mV at Epoch 137
# Epoch 137/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.17mV | loss_V: 1.6683 | loss_dVdt: 1.51e-04 | Steps: 1200 | Grad: 3.26 → 3.26
# ✅ Best RMSE: 5.16mV at Epoch 138
# Epoch 138/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.16mV | loss_V: 1.6659 | loss_dVdt: 1.51e-04 | Steps: 1200 | Grad: 3.27 → 3.27
# ✅ Best RMSE: 5.16mV at Epoch 139
# Epoch 139/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.16mV | loss_V: 1.6635 | loss_dVdt: 1.50e-04 | Steps: 1200 | Grad: 3.28 → 3.28
# ✅ Best RMSE: 5.16mV at Epoch 140
# Epoch 140/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.16mV | loss_V: 1.6610 | loss_dVdt: 1.49e-04 | Steps: 1200 | Grad: 3.30 → 3.30
# ✅ Best RMSE: 5.15mV at Epoch 141
# Epoch 141/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.15mV | loss_V: 1.6585 | loss_dVdt: 1.48e-04 | Steps: 1200 | Grad: 3.31 → 3.31
# ✅ Best RMSE: 5.15mV at Epoch 142
# Epoch 142/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.15mV | loss_V: 1.6560 | loss_dVdt: 1.47e-04 | Steps: 1200 | Grad: 3.33 → 3.33
# ✅ Best RMSE: 5.14mV at Epoch 143
# Epoch 143/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.14mV | loss_V: 1.6535 | loss_dVdt: 1.47e-04 | Steps: 1200 | Grad: 3.34 → 3.34
# ✅ Best RMSE: 5.14mV at Epoch 144
# Epoch 144/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.14mV | loss_V: 1.6509 | loss_dVdt: 1.46e-04 | Steps: 1200 | Grad: 3.36 → 3.36
# ✅ Best RMSE: 5.14mV at Epoch 145
# Epoch 145/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.14mV | loss_V: 1.6483 | loss_dVdt: 1.45e-04 | Steps: 1200 | Grad: 3.38 → 3.38
# ✅ Best RMSE: 5.13mV at Epoch 146
# Epoch 146/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.13mV | loss_V: 1.6457 | loss_dVdt: 1.44e-04 | Steps: 1200 | Grad: 3.40 → 3.40
# ✅ Best RMSE: 5.13mV at Epoch 147
# Epoch 147/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.13mV | loss_V: 1.6430 | loss_dVdt: 1.43e-04 | Steps: 1200 | Grad: 3.41 → 3.41
# ✅ Best RMSE: 5.12mV at Epoch 148
# Epoch 148/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.12mV | loss_V: 1.6403 | loss_dVdt: 1.42e-04 | Steps: 1200 | Grad: 3.43 → 3.43
# ✅ Best RMSE: 5.12mV at Epoch 149
# Epoch 149/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.12mV | loss_V: 1.6376 | loss_dVdt: 1.42e-04 | Steps: 1200 | Grad: 3.45 → 3.45
# ✅ Best RMSE: 5.11mV at Epoch 150
# Epoch 150/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.11mV | loss_V: 1.6349 | loss_dVdt: 1.41e-04 | Steps: 1200 | Grad: 3.47 → 3.47
# ✅ Best RMSE: 5.11mV at Epoch 151
# Epoch 151/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.11mV | loss_V: 1.6321 | loss_dVdt: 1.40e-04 | Steps: 1200 | Grad: 3.49 → 3.49
# ✅ Best RMSE: 5.11mV at Epoch 152
# Epoch 152/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.11mV | loss_V: 1.6293 | loss_dVdt: 1.39e-04 | Steps: 1200 | Grad: 3.51 → 3.51
# ✅ Best RMSE: 5.10mV at Epoch 153
# Epoch 153/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.10mV | loss_V: 1.6264 | loss_dVdt: 1.38e-04 | Steps: 1200 | Grad: 3.53 → 3.53
# ✅ Best RMSE: 5.10mV at Epoch 154
# Epoch 154/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.10mV | loss_V: 1.6236 | loss_dVdt: 1.37e-04 | Steps: 1200 | Grad: 3.55 → 3.55
# ✅ Best RMSE: 5.09mV at Epoch 155
# Epoch 155/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.09mV | loss_V: 1.6207 | loss_dVdt: 1.36e-04 | Steps: 1200 | Grad: 3.57 → 3.57
# ✅ Best RMSE: 5.09mV at Epoch 156
# Epoch 156/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.09mV | loss_V: 1.6177 | loss_dVdt: 1.35e-04 | Steps: 1200 | Grad: 3.59 → 3.59
# ✅ Best RMSE: 5.08mV at Epoch 157
# Epoch 157/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.08mV | loss_V: 1.6147 | loss_dVdt: 1.34e-04 | Steps: 1200 | Grad: 3.61 → 3.61
# ✅ Best RMSE: 5.08mV at Epoch 158
# Epoch 158/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.08mV | loss_V: 1.6117 | loss_dVdt: 1.33e-04 | Steps: 1200 | Grad: 3.63 → 3.63
# ✅ Best RMSE: 5.07mV at Epoch 159
# Epoch 159/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.07mV | loss_V: 1.6087 | loss_dVdt: 1.33e-04 | Steps: 1200 | Grad: 3.65 → 3.65
# ✅ Best RMSE: 5.07mV at Epoch 160
# Epoch 160/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.07mV | loss_V: 1.6056 | loss_dVdt: 1.32e-04 | Steps: 1200 | Grad: 3.67 → 3.67
# ✅ Best RMSE: 5.06mV at Epoch 161
# Epoch 161/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.06mV | loss_V: 1.6024 | loss_dVdt: 1.31e-04 | Steps: 1200 | Grad: 3.69 → 3.69
# ✅ Best RMSE: 5.06mV at Epoch 162
# Epoch 162/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.06mV | loss_V: 1.5993 | loss_dVdt: 1.30e-04 | Steps: 1200 | Grad: 3.71 → 3.71
# ✅ Best RMSE: 5.05mV at Epoch 163
# Epoch 163/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.05mV | loss_V: 1.5960 | loss_dVdt: 1.29e-04 | Steps: 1200 | Grad: 3.72 → 3.72
# ✅ Best RMSE: 5.05mV at Epoch 164
# Epoch 164/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.05mV | loss_V: 1.5928 | loss_dVdt: 1.28e-04 | Steps: 1200 | Grad: 3.74 → 3.74
# ✅ Best RMSE: 5.04mV at Epoch 165
# Epoch 165/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.04mV | loss_V: 1.5895 | loss_dVdt: 1.27e-04 | Steps: 1200 | Grad: 3.76 → 3.76
# ✅ Best RMSE: 5.04mV at Epoch 166
# Epoch 166/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.04mV | loss_V: 1.5861 | loss_dVdt: 1.26e-04 | Steps: 1200 | Grad: 3.78 → 3.78
# ✅ Best RMSE: 5.03mV at Epoch 167
# Epoch 167/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.03mV | loss_V: 1.5828 | loss_dVdt: 1.25e-04 | Steps: 1200 | Grad: 3.80 → 3.80
# ✅ Best RMSE: 5.03mV at Epoch 168
# Epoch 168/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.03mV | loss_V: 1.5793 | loss_dVdt: 1.24e-04 | Steps: 1200 | Grad: 3.83 → 3.83
# ✅ Best RMSE: 5.02mV at Epoch 169
# Epoch 169/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.02mV | loss_V: 1.5758 | loss_dVdt: 1.23e-04 | Steps: 1200 | Grad: 3.85 → 3.85
# ✅ Best RMSE: 5.02mV at Epoch 170
# Epoch 170/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.02mV | loss_V: 1.5723 | loss_dVdt: 1.22e-04 | Steps: 1200 | Grad: 3.87 → 3.87
# ✅ Best RMSE: 5.01mV at Epoch 171
# Epoch 171/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.01mV | loss_V: 1.5687 | loss_dVdt: 1.21e-04 | Steps: 1200 | Grad: 3.89 → 3.89
# ✅ Best RMSE: 5.00mV at Epoch 172
# Epoch 172/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.00mV | loss_V: 1.5651 | loss_dVdt: 1.20e-04 | Steps: 1200 | Grad: 3.92 → 3.92
# ✅ Best RMSE: 5.00mV at Epoch 173
# Epoch 173/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 5.00mV | loss_V: 1.5614 | loss_dVdt: 1.19e-04 | Steps: 1200 | Grad: 3.94 → 3.94
# ✅ Best RMSE: 4.99mV at Epoch 174
# Epoch 174/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.99mV | loss_V: 1.5577 | loss_dVdt: 1.18e-04 | Steps: 1200 | Grad: 3.97 → 3.97
# ✅ Best RMSE: 4.99mV at Epoch 175
# Epoch 175/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.99mV | loss_V: 1.5539 | loss_dVdt: 1.17e-04 | Steps: 1200 | Grad: 4.00 → 4.00
# ✅ Best RMSE: 4.98mV at Epoch 176
# Epoch 176/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.98mV | loss_V: 1.5500 | loss_dVdt: 1.16e-04 | Steps: 1200 | Grad: 4.03 → 4.03
# ✅ Best RMSE: 4.97mV at Epoch 177
# Epoch 177/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.97mV | loss_V: 1.5461 | loss_dVdt: 1.15e-04 | Steps: 1200 | Grad: 4.06 → 4.06
# ✅ Best RMSE: 4.97mV at Epoch 178
# Epoch 178/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.97mV | loss_V: 1.5421 | loss_dVdt: 1.14e-04 | Steps: 1200 | Grad: 4.09 → 4.09
# ✅ Best RMSE: 4.96mV at Epoch 179
# Epoch 179/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.96mV | loss_V: 1.5381 | loss_dVdt: 1.12e-04 | Steps: 1200 | Grad: 4.12 → 4.12
# ✅ Best RMSE: 4.95mV at Epoch 180
# Epoch 180/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.95mV | loss_V: 1.5340 | loss_dVdt: 1.11e-04 | Steps: 1200 | Grad: 4.15 → 4.15
# ✅ Best RMSE: 4.95mV at Epoch 181
# Epoch 181/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.95mV | loss_V: 1.5298 | loss_dVdt: 1.10e-04 | Steps: 1200 | Grad: 4.18 → 4.18
# ✅ Best RMSE: 4.94mV at Epoch 182
# Epoch 182/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.94mV | loss_V: 1.5256 | loss_dVdt: 1.09e-04 | Steps: 1200 | Grad: 4.22 → 4.22
# ✅ Best RMSE: 4.93mV at Epoch 183
# Epoch 183/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.93mV | loss_V: 1.5213 | loss_dVdt: 1.08e-04 | Steps: 1200 | Grad: 4.25 → 4.25
# ✅ Best RMSE: 4.93mV at Epoch 184
# Epoch 184/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.93mV | loss_V: 1.5169 | loss_dVdt: 1.07e-04 | Steps: 1200 | Grad: 4.29 → 4.29
# ✅ Best RMSE: 4.92mV at Epoch 185
# Epoch 185/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.92mV | loss_V: 1.5125 | loss_dVdt: 1.05e-04 | Steps: 1200 | Grad: 4.33 → 4.33
# ✅ Best RMSE: 4.91mV at Epoch 186
# Epoch 186/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.91mV | loss_V: 1.5079 | loss_dVdt: 1.04e-04 | Steps: 1200 | Grad: 4.36 → 4.36
# ✅ Best RMSE: 4.90mV at Epoch 187
# Epoch 187/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.90mV | loss_V: 1.5033 | loss_dVdt: 1.03e-04 | Steps: 1200 | Grad: 4.40 → 4.40
# ✅ Best RMSE: 4.90mV at Epoch 188
# Epoch 188/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.90mV | loss_V: 1.4986 | loss_dVdt: 1.02e-04 | Steps: 1200 | Grad: 4.44 → 4.44
# ✅ Best RMSE: 4.89mV at Epoch 189
# Epoch 189/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.89mV | loss_V: 1.4939 | loss_dVdt: 1.01e-04 | Steps: 1200 | Grad: 4.48 → 4.48
# ✅ Best RMSE: 4.88mV at Epoch 190
# Epoch 190/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.88mV | loss_V: 1.4890 | loss_dVdt: 9.94e-05 | Steps: 1200 | Grad: 4.52 → 4.52
# ✅ Best RMSE: 4.87mV at Epoch 191
# Epoch 191/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.87mV | loss_V: 1.4841 | loss_dVdt: 9.82e-05 | Steps: 1200 | Grad: 4.57 → 4.57
# ✅ Best RMSE: 4.86mV at Epoch 192
# Epoch 192/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.86mV | loss_V: 1.4790 | loss_dVdt: 9.69e-05 | Steps: 1200 | Grad: 4.61 → 4.61
# ✅ Best RMSE: 4.86mV at Epoch 193
# Epoch 193/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.86mV | loss_V: 1.4739 | loss_dVdt: 9.56e-05 | Steps: 1200 | Grad: 4.65 → 4.65
# ✅ Best RMSE: 4.85mV at Epoch 194
# Epoch 194/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.85mV | loss_V: 1.4686 | loss_dVdt: 9.44e-05 | Steps: 1200 | Grad: 4.70 → 4.70
# ✅ Best RMSE: 4.84mV at Epoch 195
# Epoch 195/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.84mV | loss_V: 1.4633 | loss_dVdt: 9.31e-05 | Steps: 1200 | Grad: 4.74 → 4.74
# ✅ Best RMSE: 4.83mV at Epoch 196
# Epoch 196/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.83mV | loss_V: 1.4579 | loss_dVdt: 9.18e-05 | Steps: 1200 | Grad: 4.79 → 4.79
# ✅ Best RMSE: 4.82mV at Epoch 197
# Epoch 197/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.82mV | loss_V: 1.4523 | loss_dVdt: 9.04e-05 | Steps: 1200 | Grad: 4.84 → 4.84
# ✅ Best RMSE: 4.81mV at Epoch 198
# Epoch 198/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.81mV | loss_V: 1.4466 | loss_dVdt: 8.91e-05 | Steps: 1200 | Grad: 4.89 → 4.89
# ✅ Best RMSE: 4.80mV at Epoch 199
# Epoch 199/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.80mV | loss_V: 1.4408 | loss_dVdt: 8.78e-05 | Steps: 1200 | Grad: 4.94 → 4.94
# ✅ Best RMSE: 4.79mV at Epoch 200
# Epoch 200/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.79mV | loss_V: 1.4349 | loss_dVdt: 8.64e-05 | Steps: 1200 | Grad: 5.00 → 5.00
# ✅ Best RMSE: 4.78mV at Epoch 201
# Epoch 201/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.78mV | loss_V: 1.4289 | loss_dVdt: 8.50e-05 | Steps: 1200 | Grad: 5.05 → 5.05
# ✅ Best RMSE: 4.77mV at Epoch 202
# Epoch 202/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.77mV | loss_V: 1.4227 | loss_dVdt: 8.36e-05 | Steps: 1200 | Grad: 5.11 → 5.11
# ✅ Best RMSE: 4.76mV at Epoch 203
# Epoch 203/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.76mV | loss_V: 1.4164 | loss_dVdt: 8.22e-05 | Steps: 1200 | Grad: 5.17 → 5.17
# ✅ Best RMSE: 4.75mV at Epoch 204
# Epoch 204/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.75mV | loss_V: 1.4099 | loss_dVdt: 8.08e-05 | Steps: 1200 | Grad: 5.23 → 5.23
# ✅ Best RMSE: 4.74mV at Epoch 205
# Epoch 205/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.74mV | loss_V: 1.4033 | loss_dVdt: 7.94e-05 | Steps: 1200 | Grad: 5.30 → 5.30
# ✅ Best RMSE: 4.73mV at Epoch 206
# Epoch 206/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.73mV | loss_V: 1.3965 | loss_dVdt: 7.80e-05 | Steps: 1200 | Grad: 5.36 → 5.36
# ✅ Best RMSE: 4.72mV at Epoch 207
# Epoch 207/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.72mV | loss_V: 1.3896 | loss_dVdt: 7.65e-05 | Steps: 1200 | Grad: 5.43 → 5.43
# ✅ Best RMSE: 4.70mV at Epoch 208
# Epoch 208/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.70mV | loss_V: 1.3825 | loss_dVdt: 7.50e-05 | Steps: 1200 | Grad: 5.50 → 5.50
# ✅ Best RMSE: 4.69mV at Epoch 209
# Epoch 209/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.69mV | loss_V: 1.3752 | loss_dVdt: 7.35e-05 | Steps: 1200 | Grad: 5.58 → 5.58
# ✅ Best RMSE: 4.68mV at Epoch 210
# Epoch 210/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.68mV | loss_V: 1.3677 | loss_dVdt: 7.21e-05 | Steps: 1200 | Grad: 5.65 → 5.65
# ✅ Best RMSE: 4.66mV at Epoch 211
# Epoch 211/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.66mV | loss_V: 1.3601 | loss_dVdt: 7.05e-05 | Steps: 1200 | Grad: 5.73 → 5.73
# ✅ Best RMSE: 4.65mV at Epoch 212
# Epoch 212/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.65mV | loss_V: 1.3522 | loss_dVdt: 6.90e-05 | Steps: 1200 | Grad: 5.81 → 5.81
# ✅ Best RMSE: 4.64mV at Epoch 213
# Epoch 213/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.64mV | loss_V: 1.3441 | loss_dVdt: 6.75e-05 | Steps: 1200 | Grad: 5.90 → 5.90
# ✅ Best RMSE: 4.62mV at Epoch 214
# Epoch 214/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.62mV | loss_V: 1.3358 | loss_dVdt: 6.59e-05 | Steps: 1200 | Grad: 5.99 → 5.99
# ✅ Best RMSE: 4.61mV at Epoch 215
# Epoch 215/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.61mV | loss_V: 1.3273 | loss_dVdt: 6.44e-05 | Steps: 1200 | Grad: 6.08 → 6.08
# ✅ Best RMSE: 4.59mV at Epoch 216
# Epoch 216/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.59mV | loss_V: 1.3185 | loss_dVdt: 6.28e-05 | Steps: 1200 | Grad: 6.17 → 6.17
# ✅ Best RMSE: 4.58mV at Epoch 217
# Epoch 217/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.58mV | loss_V: 1.3095 | loss_dVdt: 6.12e-05 | Steps: 1200 | Grad: 6.27 → 6.27
# ✅ Best RMSE: 4.56mV at Epoch 218
# Epoch 218/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.56mV | loss_V: 1.3002 | loss_dVdt: 5.96e-05 | Steps: 1200 | Grad: 6.37 → 6.37
# ✅ Best RMSE: 4.54mV at Epoch 219
# Epoch 219/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.54mV | loss_V: 1.2906 | loss_dVdt: 5.80e-05 | Steps: 1200 | Grad: 6.48 → 6.48
# ✅ Best RMSE: 4.53mV at Epoch 220
# Epoch 220/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.53mV | loss_V: 1.2807 | loss_dVdt: 5.64e-05 | Steps: 1200 | Grad: 6.59 → 6.59
# ✅ Best RMSE: 4.51mV at Epoch 221
# Epoch 221/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.51mV | loss_V: 1.2705 | loss_dVdt: 5.48e-05 | Steps: 1200 | Grad: 6.71 → 6.71
# ✅ Best RMSE: 4.49mV at Epoch 222
# Epoch 222/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.49mV | loss_V: 1.2599 | loss_dVdt: 5.31e-05 | Steps: 1200 | Grad: 6.83 → 6.83
# ✅ Best RMSE: 4.47mV at Epoch 223
# Epoch 223/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.47mV | loss_V: 1.2491 | loss_dVdt: 5.15e-05 | Steps: 1200 | Grad: 6.96 → 6.96
# ✅ Best RMSE: 4.45mV at Epoch 224
# Epoch 224/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.45mV | loss_V: 1.2378 | loss_dVdt: 4.98e-05 | Steps: 1200 | Grad: 7.09 → 7.09
# ✅ Best RMSE: 4.43mV at Epoch 225
# Epoch 225/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.43mV | loss_V: 1.2261 | loss_dVdt: 4.81e-05 | Steps: 1200 | Grad: 7.23 → 7.23
# ✅ Best RMSE: 4.41mV at Epoch 226
# Epoch 226/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.41mV | loss_V: 1.2141 | loss_dVdt: 4.65e-05 | Steps: 1200 | Grad: 7.37 → 7.37
# ✅ Best RMSE: 4.38mV at Epoch 227
# Epoch 227/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.38mV | loss_V: 1.2016 | loss_dVdt: 4.48e-05 | Steps: 1200 | Grad: 7.52 → 7.52
# ✅ Best RMSE: 4.36mV at Epoch 228
# Epoch 228/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.36mV | loss_V: 1.1886 | loss_dVdt: 4.31e-05 | Steps: 1200 | Grad: 7.68 → 7.68
# ✅ Best RMSE: 4.34mV at Epoch 229
# Epoch 229/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.34mV | loss_V: 1.1751 | loss_dVdt: 4.14e-05 | Steps: 1200 | Grad: 7.85 → 7.85
# ✅ Best RMSE: 4.31mV at Epoch 230
# Epoch 230/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.31mV | loss_V: 1.1611 | loss_dVdt: 3.98e-05 | Steps: 1200 | Grad: 8.03 → 8.03
# ✅ Best RMSE: 4.28mV at Epoch 231
# Epoch 231/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.28mV | loss_V: 1.1466 | loss_dVdt: 3.81e-05 | Steps: 1200 | Grad: 8.21 → 8.21
# ✅ Best RMSE: 4.25mV at Epoch 232
# Epoch 232/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.25mV | loss_V: 1.1314 | loss_dVdt: 3.64e-05 | Steps: 1200 | Grad: 8.41 → 8.41
# ✅ Best RMSE: 4.22mV at Epoch 233
# Epoch 233/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.22mV | loss_V: 1.1156 | loss_dVdt: 3.48e-05 | Steps: 1200 | Grad: 8.61 → 8.61
# ✅ Best RMSE: 4.19mV at Epoch 234
# Epoch 234/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.19mV | loss_V: 1.0992 | loss_dVdt: 3.31e-05 | Steps: 1200 | Grad: 8.83 → 8.83
# ✅ Best RMSE: 4.16mV at Epoch 235
# Epoch 235/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.16mV | loss_V: 1.0820 | loss_dVdt: 3.15e-05 | Steps: 1200 | Grad: 9.05 → 9.05
# ✅ Best RMSE: 4.13mV at Epoch 236
# Epoch 236/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.13mV | loss_V: 1.0640 | loss_dVdt: 2.99e-05 | Steps: 1200 | Grad: 9.29 → 9.29
# ✅ Best RMSE: 4.09mV at Epoch 237
# Epoch 237/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.09mV | loss_V: 1.0452 | loss_dVdt: 2.83e-05 | Steps: 1200 | Grad: 9.54 → 9.54
# ✅ Best RMSE: 4.05mV at Epoch 238
# Epoch 238/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.05mV | loss_V: 1.0255 | loss_dVdt: 2.68e-05 | Steps: 1200 | Grad: 9.81 → 9.81
# ✅ Best RMSE: 4.01mV at Epoch 239
# Epoch 239/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.01mV | loss_V: 1.0048 | loss_dVdt: 2.53e-05 | Steps: 1200 | Grad: 10.09 → 10.09
# ✅ Best RMSE: 3.97mV at Epoch 240
# Epoch 240/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 3.97mV | loss_V: 0.9831 | loss_dVdt: 2.38e-05 | Steps: 1200 | Grad: 10.38 → 10.38
# ✅ Best RMSE: 3.92mV at Epoch 241
# Epoch 241/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 3.92mV | loss_V: 0.9603 | loss_dVdt: 2.24e-05 | Steps: 1200 | Grad: 10.69 → 10.69
# ✅ Best RMSE: 3.87mV at Epoch 242
# Epoch 242/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 3.87mV | loss_V: 0.9364 | loss_dVdt: 2.11e-05 | Steps: 1200 | Grad: 11.01 → 11.01
# ✅ Best RMSE: 3.82mV at Epoch 243
# Epoch 243/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 3.82mV | loss_V: 0.9112 | loss_dVdt: 1.99e-05 | Steps: 1200 | Grad: 11.35 → 11.35
# ✅ Best RMSE: 3.76mV at Epoch 244
# Epoch 244/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 3.76mV | loss_V: 0.8846 | loss_dVdt: 1.87e-05 | Steps: 1200 | Grad: 11.70 → 11.70
# ✅ Best RMSE: 3.70mV at Epoch 245
# Epoch 245/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 3.70mV | loss_V: 0.8567 | loss_dVdt: 1.77e-05 | Steps: 1200 | Grad: 12.06 → 12.06
# ✅ Best RMSE: 3.64mV at Epoch 246
# Epoch 246/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 3.64mV | loss_V: 0.8272 | loss_dVdt: 1.68e-05 | Steps: 1200 | Grad: 12.43 → 12.43
# ✅ Best RMSE: 3.57mV at Epoch 247
# ...
# ✅ Best RMSE: 0.58mV at Epoch 707
# Epoch 707/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.58mV | loss_V: 0.0207 | loss_dVdt: 6.81e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 708
# Epoch 708/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0207 | loss_dVdt: 6.81e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 709
# Epoch 709/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0206 | loss_dVdt: 6.81e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 710
# Epoch 710/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0206 | loss_dVdt: 6.81e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 711
# Epoch 711/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0206 | loss_dVdt: 6.81e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 712
# Epoch 712/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0206 | loss_dVdt: 6.80e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 713
# Epoch 713/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0205 | loss_dVdt: 6.80e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 714
# Epoch 714/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0205 | loss_dVdt: 6.80e-06 | Steps: 1200 | Grad: 0.17 → 0.17
# ✅ Best RMSE: 0.57mV at Epoch 715
# Epoch 715/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0205 | loss_dVdt: 6.80e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 716
# Epoch 716/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0205 | loss_dVdt: 6.80e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 717
# Epoch 717/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0204 | loss_dVdt: 6.79e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 718
# Epoch 718/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0204 | loss_dVdt: 6.79e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 719
# Epoch 719/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0204 | loss_dVdt: 6.79e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 720
# Epoch 720/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0204 | loss_dVdt: 6.79e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 721
# Epoch 721/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0204 | loss_dVdt: 6.79e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 722
# Epoch 722/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0203 | loss_dVdt: 6.78e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 723
# Epoch 723/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0203 | loss_dVdt: 6.78e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 724
# Epoch 724/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0203 | loss_dVdt: 6.78e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 725
# Epoch 725/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0203 | loss_dVdt: 6.78e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 726
# Epoch 726/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0202 | loss_dVdt: 6.78e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 727
# Epoch 727/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0202 | loss_dVdt: 6.78e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 728
# Epoch 728/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0202 | loss_dVdt: 6.77e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 729
# Epoch 729/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0202 | loss_dVdt: 6.77e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 730
# Epoch 730/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0202 | loss_dVdt: 6.77e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 731
# Epoch 731/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0201 | loss_dVdt: 6.77e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 732
# Epoch 732/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0201 | loss_dVdt: 6.77e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 733
# Epoch 733/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0201 | loss_dVdt: 6.77e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 734
# Epoch 734/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0201 | loss_dVdt: 6.76e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 735
# Epoch 735/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0200 | loss_dVdt: 6.76e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 736
# Epoch 736/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0200 | loss_dVdt: 6.76e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 737
# Epoch 737/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0200 | loss_dVdt: 6.76e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 738
# Epoch 738/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0200 | loss_dVdt: 6.76e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.57mV at Epoch 739
# Epoch 739/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.57mV | loss_V: 0.0200 | loss_dVdt: 6.76e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.56mV at Epoch 740
# Epoch 740/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0199 | loss_dVdt: 6.76e-06 | Steps: 1200 | Grad: 0.16 → 0.16
# ✅ Best RMSE: 0.56mV at Epoch 741
# Epoch 741/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0199 | loss_dVdt: 6.75e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 742
# Epoch 742/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0199 | loss_dVdt: 6.75e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 743
# Epoch 743/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0199 | loss_dVdt: 6.75e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 744
# Epoch 744/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0199 | loss_dVdt: 6.75e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 745
# Epoch 745/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0198 | loss_dVdt: 6.75e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 746
# Epoch 746/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0198 | loss_dVdt: 6.75e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 747
# Epoch 747/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0198 | loss_dVdt: 6.75e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 748
# Epoch 748/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0198 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 749
# Epoch 749/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0197 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 750
# Epoch 750/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0197 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 751
# Epoch 751/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0197 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 752
# Epoch 752/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0197 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 753
# Epoch 753/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0197 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 754
# Epoch 754/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0196 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 755
# Epoch 755/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0196 | loss_dVdt: 6.74e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 756
# Epoch 756/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0196 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 757
# Epoch 757/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0196 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 758
# Epoch 758/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0196 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 759
# Epoch 759/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0195 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 760
# Epoch 760/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0195 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 761
# Epoch 761/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0195 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 762
# Epoch 762/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0195 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 763
# Epoch 763/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0195 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 764
# Epoch 764/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0194 | loss_dVdt: 6.73e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 765
# Epoch 765/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0194 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 766
# Epoch 766/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0194 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 767
# Epoch 767/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0194 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 768
# Epoch 768/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0194 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 769
# Epoch 769/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0193 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 770
# Epoch 770/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0193 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.15 → 0.15
# ✅ Best RMSE: 0.56mV at Epoch 771
# Epoch 771/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0193 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.56mV at Epoch 772
# Epoch 772/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0193 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.56mV at Epoch 773
# Epoch 773/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0193 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.56mV at Epoch 774
# Epoch 774/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.56mV | loss_V: 0.0193 | loss_dVdt: 6.72e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 775
# Epoch 775/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0192 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 776
# Epoch 776/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0192 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 777
# Epoch 777/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0192 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 778
# Epoch 778/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0192 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 779
# Epoch 779/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0192 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 780
# Epoch 780/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0191 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 781
# Epoch 781/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0191 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 782
# Epoch 782/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0191 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 783
# Epoch 783/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0191 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 784
# Epoch 784/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0191 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 785
# Epoch 785/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0190 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 786
# Epoch 786/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0190 | loss_dVdt: 6.71e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 787
# Epoch 787/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0190 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 788
# Epoch 788/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0190 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 789
# Epoch 789/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0190 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 790
# Epoch 790/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0190 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 791
# Epoch 791/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0189 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 792
# Epoch 792/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0189 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 793
# Epoch 793/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0189 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 794
# Epoch 794/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0189 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 795
# Epoch 795/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0189 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 796
# Epoch 796/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0188 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 797
# Epoch 797/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0188 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 798
# Epoch 798/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0188 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# ✅ Best RMSE: 0.55mV at Epoch 799
# Epoch 799/3000 | Method: euler  | LR: 5.00e-04 | RMSE: 0.55mV | loss_V: 0.0188 | loss_dVdt: 6.70e-06 | Steps: 1200 | Grad: 0.14 → 0.14
# Window range <= 0.005 mV → stop
#
# ============================================================
# Training Complete!
# Loaded best model from epoch 799/3000
# Best RMSE: 0.55mV
# Best model saved to: best_model_batch_rmse0.55mV.pth
# Total training time: 00:21:19 (1279.9 seconds)
# ============================================================

# %%
import torch
import numpy as np
import pandas as pd
from torchdiffeq import odeint
from battery_ode_wrapper import BatteryODEWrapper

# Load the trained model checkpoint
model_path = 'best_model_batch_rmse0.30mV.pth'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate model (BatteryODEWrapper only takes device parameter)
ode_wrapper_test = BatteryODEWrapper(device=device)
checkpoint = torch.load(model_path, map_location=device, weights_only=False)
if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
    ode_wrapper_test.load_state_dict(checkpoint['model_state_dict'], strict=False)
else:
    ode_wrapper_test.load_state_dict(checkpoint, strict=False)
ode_wrapper_test.to(device)
ode_wrapper_test.eval()

# Run simulation on test data
test_results = []

for test_idx, test_data in enumerate(test_final_dict_list):
    # Set inputs for the wrapper
    ode_wrapper_test.set_inputs(test_data)
    
    # Prepare time and initial condition
    t = np.array(test_data['time'])
    t_tensor = torch.tensor(t, dtype=torch.float32, device=device)
    x0 = torch.tensor([[test_data['Y'][0]]], dtype=torch.float32, device=device)
    
    # Run simulation using odeint (NOT model.ode_solve)
    with torch.no_grad():
        sol = odeint(ode_wrapper_test, x0, t_tensor, method='euler')
        Vcorr_pred_norm = sol[:, 0, 0].cpu().numpy()
    
    # Denormalize Vcorr if needed
    if 'Y_std' in test_data and 'Y_mean' in test_data:
        Vcorr_pred = Vcorr_pred_norm * test_data['Y_std'] + test_data['Y_mean']
        Vcorr_true = np.array(test_data['Y']) * test_data['Y_std'] + test_data['Y_mean']
    else:
        Vcorr_pred = Vcorr_pred_norm
        Vcorr_true = np.array(test_data['Y'])
    
    test_results.append({
        'profile': test_idx,
        'time': t,
        'Vcorr_pred': Vcorr_pred,
        'Vcorr_true': Vcorr_true,
    })

# Display results
import matplotlib.pyplot as plt

for result in test_results:
    plt.figure(figsize=(10, 4))
    plt.plot(result['time'], result['Vcorr_true'], label='True Vcorr')
    plt.plot(result['time'], result['Vcorr_pred'], label='Predicted Vcorr', linestyle='--')
    plt.title(f"Test Profile {result['profile']+1}: Vcorr Prediction")
    plt.xlabel("Time (s)")
    plt.ylabel("Vcorr (V)")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# ===== Load checkpoint and run simulation with best_model_batch_rmse1.70mV.pth =====
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchdiffeq import odeint
from battery_ode_wrapper import BatteryODEWrapper
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Normalization params (from utils.py lines 265-275)
csn_bulk_norm = 30555
current_norm = 0.1
temperature_norm = 10
temperature_mean = 298.15
Y_mean = -0.015
Y_std = 0.004
ocv_mean = 3.28  # 96 - 12 % SOC only
ocv_std = 0.04   # 96 - 12 % SOC only 
Vref_mean = 3.28 - 0.015
Vref_std = 0.04

def denorm_Y(Y_norm):
    return Y_norm * Y_std + Y_mean

def calc_rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))

# Load checkpoint
checkpoint_path = 'best_model_batch_rmse1.83mV_6input_euler.pth'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f"Loading checkpoint from: {checkpoint_path}")
ode_wrapper_test = BatteryODEWrapper(device=device)
checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)

if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
    ode_wrapper_test.load_state_dict(checkpoint['model_state_dict'], strict=False)
    training_info = checkpoint.get('training_info', {})
    print(f"✓ Checkpoint loaded successfully!")
    if training_info:
        print(f"  - Best RMSE: {training_info.get('best_rmse', 'N/A'):.2f}mV")
        print(f"  - Best epoch: {training_info.get('best_epoch', 'N/A')}")
else:
    ode_wrapper_test.load_state_dict(checkpoint, strict=False)
    print(f"✓ Checkpoint loaded successfully! (legacy format)")

ode_wrapper_test.to(device)
ode_wrapper_test.eval()

# ----- 1. Run simulation (배치) on test_dict_list -----
# 배치 inference (run NeuralODE for each dict)
test_sim_results = []
for idx, d in enumerate(test_dict_list):
    # 시뮬레이션 준비
    t = np.array(d['time'])
    t_tensor = torch.tensor(t, dtype=torch.float32, device=device)
    x0 = torch.tensor([[d['Y'][0]]], dtype=torch.float32, device=device)  # normalized Y
    
    # 입력 셋팅
    ode_wrapper_test.set_inputs(d)

    # 시뮬레이션
    with torch.no_grad():
        sol = odeint(ode_wrapper_test, x0, t_tensor, method='euler')
        Y_pred = sol[:, 0, 0].cpu().numpy()  # normalized
    test_sim_results.append(Y_pred)
    
# 'Y_pred'를 test_dict_list 각 dict에 넣어줌
for idx, d in enumerate(test_dict_list):
    d['Y_pred'] = test_sim_results[idx]  # normalized

# ----- 2. 각 dict 사용한 rmse 값 프린트 -----
rmse_values = []
mask_soc_range = []

for idx, d in enumerate(test_dict_list):
    # Denormalize Y (Vcorr)
    Y_pred_denorm = denorm_Y(np.array(d['Y_pred']))
    Y_true_denorm = denorm_Y(np.array(d['Y']))  # ground truth

    rmse = calc_rmse(Y_true_denorm, Y_pred_denorm)
    rmse_values.append(rmse)
    
    # SOC 마스킹 (0.11~0.96)
    soc = np.array(d['SOC'])
    mask = (soc >= 0.11) & (soc <= 0.96)
    mask_soc_range.append(mask)

    print(f"Test Dict {idx}: RMSE = {rmse * 1e3:.3f} mV (all points), "
          f"RMSE_in_SOC[0.11, 0.96] = {calc_rmse(Y_true_denorm[mask], Y_pred_denorm[mask]) * 1e3:.3f} mV "
          f"[points: {mask.sum()}]")

# 3. soc [0.11, 0.96] 사이 값들의 최소, median, 최대 RMSE dict의 전압값 프린트

rmse_soc_range = [
    calc_rmse(denorm_Y(np.array(d['Y'])[mask_soc_range[idx]]), denorm_Y(np.array(d['Y_pred'])[mask_soc_range[idx]]))
    for idx, d in enumerate(test_dict_list)
]
rmse_soc_range = np.array(rmse_soc_range)

# min, median, max 찾기
args_sorted = np.argsort(rmse_soc_range)
idx_min = args_sorted[0]
idx_median = args_sorted[len(rmse_soc_range) // 2]
idx_max = args_sorted[-1]

highlight_indices = [("min", idx_min), ("median", idx_median), ("max", idx_max)]

for label, idx in highlight_indices:
    d = test_dict_list[idx]
    mask = mask_soc_range[idx]

    V_meas = np.array(d['V_meas'])[mask]
    V_spme = np.array(d['V_spme'])[mask]
    Y_pred_d = denorm_Y(np.array(d['Y_pred']))[mask]
    SOC = np.array(d['SOC'])[mask]
    time = np.array(d['time'])[mask]

    # Create subplot with secondary y-axis
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    
    # Left y-axis: Voltage
    fig.add_trace(
        go.Scatter(x=time, y=V_meas, name='V_meas', line=dict(color='blue', width=2)),
        secondary_y=False,
    )
    fig.add_trace(
        go.Scatter(x=time, y=V_spme + Y_pred_d, name='V_spme + Y_pred (denorm)', 
                  line=dict(color='red', width=2, dash='dash')),
        secondary_y=False,
    )
    
    # Right y-axis: SOC
    fig.add_trace(
        go.Scatter(x=time, y=SOC, name='SOC', line=dict(color='green', width=2, dash='dot')),
        secondary_y=True,
    )
    
    # Update axes labels
    fig.update_xaxes(title_text="Time (s)")
    fig.update_yaxes(title_text="Voltage (V)", secondary_y=False)
    fig.update_yaxes(title_text="SOC", secondary_y=True)
    
    # Update title
    fig.update_layout(
        title=f'Test Dict #{idx} ({label.upper()} RMSE in SOC[0.11,0.96]) | RMSE: {rmse_soc_range[idx]*1e3:.3f} mV',
        width=1000,
        height=500
    )
    
    fig.show()
# Out:
# Loading checkpoint from: best_model_batch_rmse1.83mV_6input_euler.pth
# ✓ Checkpoint loaded successfully!
#   - Best RMSE: 1.83mV
#   - Best epoch: 1000
# Test Dict 0: RMSE = 0.834 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.834 mV [points: 901]
# Test Dict 1: RMSE = 2.334 mV (all points), RMSE_in_SOC[0.11, 0.96] = 2.334 mV [points: 901]
# Test Dict 2: RMSE = 1.269 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.269 mV [points: 901]
# Test Dict 3: RMSE = 0.763 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.763 mV [points: 900]
# Test Dict 4: RMSE = 1.124 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.124 mV [points: 901]
# Test Dict 5: RMSE = 2.140 mV (all points), RMSE_in_SOC[0.11, 0.96] = 2.140 mV [points: 900]
# Test Dict 6: RMSE = 1.352 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.352 mV [points: 900]

# %%
# ===== Transfer Learning: Load checkpoint and continue training =====
import torch
from battery_ode_wrapper import BatteryODEWrapper, train_battery_neural_ode_batch

# Load checkpoint
checkpoint_path = 'best_model_batch_rmse1.61mV_driving_6input.pth'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print("="*60)
print(f"Loading checkpoint for transfer learning: {checkpoint_path}")
print("="*60)

checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)

# Create model and load weights
ode_wrapper_pretrained = BatteryODEWrapper(device=device)

if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
    ode_wrapper_pretrained.load_state_dict(checkpoint['model_state_dict'], strict=False)
    training_info = checkpoint.get('training_info', {})
    print(f"✓ Checkpoint loaded successfully!")
    if training_info:
        print(f"  Previous training info:")
        print(f"  - Best RMSE: {training_info.get('best_rmse', 'N/A'):.2f}mV")
        print(f"  - Best epoch: {training_info.get('best_epoch', 'N/A')}")
        print(f"  - Total epochs: {training_info.get('total_epochs', 'N/A')}")
        print(f"  - Alpha: {training_info.get('alpha', 'N/A')}, Beta: {training_info.get('beta', 'N/A')}, Gamma: {training_info.get('gamma', 'N/A')}")
        print(f"  - Initial LR: {training_info.get('initial_lr', 'N/A')}")
        print(f"  - Method: {training_info.get('method', 'N/A')}")
else:
    ode_wrapper_pretrained.load_state_dict(checkpoint, strict=False)
    print(f"✓ Checkpoint loaded successfully! (legacy format)")

ode_wrapper_pretrained.to(device)
ode_wrapper_pretrained.eval()

print("\n" + "="*60)
print("Starting transfer learning (continued training)...")
print("="*60)

# Continue training with existing training_dict_list
# Adjust these parameters as needed
num_epochs_continued = 50  # Additional epochs to train
lr_continued = 1e-4  # Learning rate (can be lower for fine-tuning)
training_batch_size = None  # Use all profiles, or set a number

ode_wrapper_continued, history_continued = train_battery_neural_ode_batch(
    data_list=training_dict_list,
    num_epochs=num_epochs_continued,
    lr=lr_continued,
    device=device,
    verbose=True,
    training_batch_size=training_batch_size,
    ode_wrapper=ode_wrapper_pretrained,  # Pass the pretrained model
    method='euler'
)

print("\n" + "="*60)
print("Transfer learning completed!")
print("="*60)
# Out:
# ============================================================
# Loading checkpoint for transfer learning: best_model_batch_rmse1.61mV_driving_6input.pth
# ============================================================
# ✓ Checkpoint loaded successfully!
#   Previous training info:
#   - Best RMSE: 1.61mV
#   - Best epoch: 1343
#   - Total epochs: 3000
#   - Alpha: 1, Beta: 0, Gamma: 0
#   - Initial LR: 0.0005
#   - Method: euler
#
# ============================================================
# Starting transfer learning (continued training)...
# ============================================================
#
# ============================================================
# Batch Training: 204 total profiles
# Training batch size: 204 profiles per epoch
# ============================================================
# Profile lengths: [1203, 1202, 1202, 1203, 1201, 1203, 1204, 1204, 1202, 1201, 1203, 1202, 1200, 1202, 1201, 1201, 1204, 1202, 1200, 1202, 1202, 1204, 1200, 1204, 1201, 1201, 1202, 1201, 1202, 1204, 1203, 1202, 1203, 1204, 1201, 1201, 1201, 1201, 1200, 1200, 1204, 1202, 1200, 1203, 1201, 1201, 1201, 1200, 1204, 1204, 1203, 1200, 1201, 1200, 1201, 1202, 1201, 1201, 1201, 1202, 1201, 1202, 1202, 1201, 1202, 1203, 1201, 1204, 1202, 1200, 1203, 1201, 1201, 1202, 1202, 1202, 1200, 1202, 1201, 1201, 1203, 1201, 1201, 1202, 1202, 1201, 1203, 1204, 1201, 1203, 1202, 1202, 1202, 1201, 1201, 1201, 1202, 1201, 1201, 1202, 1200, 1200, 1202, 1202, 1201, 1202, 1201, 1204, 1201, 1202, 1200, 1201, 1204, 1201, 1203, 1201, 1201, 1203, 1201, 1202, 1201, 1202, 1202, 1200, 1202, 1201, 1204, 1202, 1202, 1202, 1201, 1201, 1200, 1204, 1200, 1204, 1200, 1200, 1201, 1202, 1202, 1201, 1201, 1204, 1203, 1201, 1201, 1201, 1201, 1202, 1202, 1201, 1204, 1201, 1201, 1203, 1204, 1200, 1201, 1203, 1201, 1202, 1202, 1200, 1201, 1197, 1202, 1202, 1202, 1204, 1201, 1203, 1202, 1203, 1201, 1201, 1201, 1201, 1204, 1202, 1202, 1203, 1201, 1200, 1202, 1201, 1204, 1201, 1202, 1201, 1201, 1202, 1200, 1201, 1201, 1201, 1202, 1200, 1201, 1204, 1096, 1202, 1200, 1204]
# Time durations: ['1199.1s', '1199.0s', '1199.0s', '1199.1s', '1200.0s', '1199.1s', '1199.1s', '1199.1s', '1199.0s', '1200.0s', '1199.1s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1199.0s', '1199.1s', '1200.0s', '1199.0s', '1199.0s', '1200.0s', '1199.0s', '1199.1s', '1199.1s', '1199.0s', '1199.1s', '1199.1s', '1199.0s', '1199.0s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1199.1s', '1199.0s', '1199.1s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1199.1s', '1199.1s', '1199.0s', '1199.0s', '1199.0s', '1200.0s', '1199.0s', '1200.0s', '1200.0s', '1199.0s', '1199.0s', '1200.0s', '1199.1s', '1199.0s', '1200.0s', '1199.0s', '1199.1s', '1200.0s', '1199.1s', '1199.0s', '1199.0s', '1199.1s', '1199.0s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1200.0s', '1200.0s', '1199.1s', '1199.0s', '1200.0s', '1199.0s', '1199.0s', '1200.0s', '1199.1s', '1199.1s', '1199.0s', '1199.1s', '1199.0s', '1199.0s', '1199.0s', '1200.0s', '1199.0s', '1200.0s', '1199.1s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1199.0s', '1200.0s', '1199.0s', '1200.0s', '1199.1s', '1200.0s', '1199.0s', '1199.0s', '1200.0s', '1199.1s', '1200.0s', '1199.1s', '1199.0s', '1200.0s', '1199.1s', '1199.0s', '1199.1s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1200.0s', '1199.1s', '1199.1s', '1199.1s', '1199.0s', '1200.0s', '1200.0s', '1199.0s', '1199.1s', '1199.0s', '1199.1s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1200.0s', '1200.0s', '1199.1s', '1199.1s', '1200.0s', '1199.0s', '1200.0s', '1200.0s', '1199.0s', '1199.1s', '1199.0s', '1199.1s', '1200.0s', '1200.0s', '1199.1s', '1199.1s', '1199.0s', '1200.0s', '1199.1s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1199.1s', '1200.0s', '1199.1s', '1199.1s', '1199.1s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1199.0s', '1199.0s', '1199.1s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1200.0s', '1199.0s', '1200.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.0s', '1199.1s', '1200.0s', '1199.0s', '1199.0s', '1199.0s']
# Common time vector: [0, 1200.0] with 1204 points
# 🔄 Using provided ODE wrapper for continued training
# ✓ Batch inputs set: 204 profiles, 1204 time steps
#
# ============================================================
# Neural Network Architecture
# ============================================================
# Sequential(
#   (0): Linear(in_features=6, out_features=32, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=32, out_features=32, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=32, out_features=32, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=32, out_features=16, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=16, out_features=1, bias=True)
# )
# ============================================================
#
# ============================================================
# Training Settings
# ============================================================
# Total profiles: 204
# Training batch size: 204
# Common time points: 1204
# Max epochs: 50
# Initial LR: 0.0001
# Device: cuda
# Patience: 10
# Alpha: 1.00, Beta: 0.00, Gamma: 0.00
# GPU: N/A
# Grad clip max: 50
# Method: euler
# Verbose: True
# ============================================================
# Starting batch training...
# Targets shape: torch.Size([204, 1204])
# Target range: -5.645 ~ 41.992
# ✅ Best RMSE: 1.88mV at Epoch 1
# Epoch   1/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.88mV | loss_V: 0.2210 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 4.53 → 4.53
# ✅ Best RMSE: 1.86mV at Epoch 2
# Epoch   2/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.86mV | loss_V: 0.2154 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 3.01 → 3.01
# ✅ Best RMSE: 1.84mV at Epoch 3
# Epoch   3/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2120 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.77 → 1.77
# ✅ Best RMSE: 1.84mV at Epoch 4
# Epoch   4/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2106 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.10 → 1.10
# ✅ Best RMSE: 1.83mV at Epoch 5
# Epoch   5/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2104 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.18 → 1.18
# Epoch   6/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2107 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.46 → 1.46
# Epoch   7/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2111 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.65 → 1.65
# Epoch   8/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2113 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.70 → 1.70
# Epoch   9/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2112 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.65 → 1.65
# Epoch  10/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2110 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.55 → 1.55
# Epoch  11/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.84mV | loss_V: 0.2107 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.42 → 1.42
# ✅ Best RMSE: 1.83mV at Epoch 12
# Epoch  12/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2103 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.31 → 1.31
# ✅ Best RMSE: 1.83mV at Epoch 13
# Epoch  13/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2100 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.22 → 1.22
# ✅ Best RMSE: 1.83mV at Epoch 14
# Epoch  14/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2097 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.13 → 1.13
# ✅ Best RMSE: 1.83mV at Epoch 15
# Epoch  15/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2094 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 1.03 → 1.03
# ✅ Best RMSE: 1.83mV at Epoch 16
# Epoch  16/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2092 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 0.91 → 0.91
# ✅ Best RMSE: 1.83mV at Epoch 17
# Epoch  17/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2090 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 0.76 → 0.76
# ✅ Best RMSE: 1.83mV at Epoch 18
# Epoch  18/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2088 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 0.63 → 0.63
# ✅ Best RMSE: 1.83mV at Epoch 19
# Epoch  19/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2087 | loss_dVdt: 1.84e-01 | Steps: 1203 | Grad: 0.56 → 0.56
# ✅ Best RMSE: 1.83mV at Epoch 20
# Epoch  20/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2087 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.60 → 0.60
# ✅ Best RMSE: 1.83mV at Epoch 21
# Epoch  21/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2087 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.72 → 0.72
# Epoch  22/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2087 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.84 → 0.84
# ✅ Best RMSE: 1.83mV at Epoch 23
# Epoch  23/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2087 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.92 → 0.92
# ✅ Best RMSE: 1.83mV at Epoch 24
# Epoch  24/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2086 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.94 → 0.94
# ✅ Best RMSE: 1.83mV at Epoch 25
# Epoch  25/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2085 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.89 → 0.89
# ✅ Best RMSE: 1.83mV at Epoch 26
# Epoch  26/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.83mV | loss_V: 0.2083 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.78 → 0.78
# ✅ Best RMSE: 1.82mV at Epoch 27
# Epoch  27/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2081 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.63 → 0.63
# ✅ Best RMSE: 1.82mV at Epoch 28
# Epoch  28/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2079 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.44 → 0.44
# ✅ Best RMSE: 1.82mV at Epoch 29
# Epoch  29/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2078 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.26 → 0.26
# ✅ Best RMSE: 1.82mV at Epoch 30
# Epoch  30/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2077 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.19 → 0.19
# ✅ Best RMSE: 1.82mV at Epoch 31
# Epoch  31/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2076 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.28 → 0.28
# ✅ Best RMSE: 1.82mV at Epoch 32
# Epoch  32/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2076 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.40 → 0.40
# ✅ Best RMSE: 1.82mV at Epoch 33
# Epoch  33/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2076 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.48 → 0.48
# ✅ Best RMSE: 1.82mV at Epoch 34
# Epoch  34/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2075 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.53 → 0.53
# ✅ Best RMSE: 1.82mV at Epoch 35
# Epoch  35/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2074 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.52 → 0.52
# ✅ Best RMSE: 1.82mV at Epoch 36
# Epoch  36/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2073 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.47 → 0.47
# ✅ Best RMSE: 1.82mV at Epoch 37
# Epoch  37/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2072 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.40 → 0.40
# ✅ Best RMSE: 1.82mV at Epoch 38
# Epoch  38/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2071 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.31 → 0.31
# ✅ Best RMSE: 1.82mV at Epoch 39
# Epoch  39/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2070 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.23 → 0.23
# ✅ Best RMSE: 1.82mV at Epoch 40
# Epoch  40/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2069 | loss_dVdt: 1.85e-01 | Steps: 1203 | Grad: 0.20 → 0.20
# ✅ Best RMSE: 1.82mV at Epoch 41
# Epoch  41/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2068 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.22 → 0.22
# ✅ Best RMSE: 1.82mV at Epoch 42
# Epoch  42/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2067 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.27 → 0.27
# ✅ Best RMSE: 1.82mV at Epoch 43
# Epoch  43/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2066 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.31 → 0.31
# ✅ Best RMSE: 1.82mV at Epoch 44
# Epoch  44/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2066 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.33 → 0.33
# ✅ Best RMSE: 1.82mV at Epoch 45
# Epoch  45/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2065 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.33 → 0.33
# ✅ Best RMSE: 1.82mV at Epoch 46
# Epoch  46/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2064 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.31 → 0.31
# ✅ Best RMSE: 1.82mV at Epoch 47
# Epoch  47/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2063 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.28 → 0.28
# ✅ Best RMSE: 1.82mV at Epoch 48
# Epoch  48/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2062 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.24 → 0.24
# ✅ Best RMSE: 1.82mV at Epoch 49
# Epoch  49/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2062 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.21 → 0.21
# ✅ Best RMSE: 1.82mV at Epoch 50
# Epoch  50/50 | Method: euler  | LR: 1.00e-04 | RMSE: 1.82mV | loss_V: 0.2061 | loss_dVdt: 1.86e-01 | Steps: 1203 | Grad: 0.18 → 0.18
#
# ============================================================
# Training Complete!
# Loaded best model from epoch 50/50
# Best RMSE: 1.82mV
# Best model saved to: best_model_batch_rmse1.82mV.pth
# Total training time: 00:01:49 (109.7 seconds)
# ============================================================
#
#
# ============================================================
# Transfer learning completed!
# ============================================================

# %%
# ===== Load checkpoint and run simulation with best_model_batch_rmse1.70mV.pth =====
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchdiffeq import odeint
from battery_ode_wrapper import BatteryODEWrapper
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Normalization params (from utils.py lines 265-275)
csn_bulk_norm = 30555
current_norm = 0.1
temperature_norm = 10
temperature_mean = 298.15
Y_mean = -0.015
Y_std = 0.004
ocv_mean = 3.28  # 96 - 12 % SOC only
ocv_std = 0.04   # 96 - 12 % SOC only 
Vref_mean = 3.28 - 0.015
Vref_std = 0.04

def denorm_Y(Y_norm):
    return Y_norm * Y_std + Y_mean

def calc_rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))

# Load checkpoint
checkpoint_path = 'best_model_batch_rmse1.82mV.pth'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f"Loading checkpoint from: {checkpoint_path}")
ode_wrapper_test = BatteryODEWrapper(device=device)
checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)

if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
    ode_wrapper_test.load_state_dict(checkpoint['model_state_dict'], strict=False)
    training_info = checkpoint.get('training_info', {})
    print(f"✓ Checkpoint loaded successfully!")
    if training_info:
        print(f"  - Best RMSE: {training_info.get('best_rmse', 'N/A'):.2f}mV")
        print(f"  - Best epoch: {training_info.get('best_epoch', 'N/A')}")
else:
    ode_wrapper_test.load_state_dict(checkpoint, strict=False)
    print(f"✓ Checkpoint loaded successfully! (legacy format)")

ode_wrapper_test.to(device)
ode_wrapper_test.eval()

# ----- 1. Run simulation (배치) on test_dict_list -----
# 배치 inference (run NeuralODE for each dict)
test_sim_results = []
for idx, d in enumerate(test_dict_list):
    # 시뮬레이션 준비
    t = np.array(d['time'])
    t_tensor = torch.tensor(t, dtype=torch.float32, device=device)
    x0 = torch.tensor([[d['Y'][0]]], dtype=torch.float32, device=device)  # normalized Y
    
    # 입력 셋팅
    ode_wrapper_test.set_inputs(d)

    # 시뮬레이션
    with torch.no_grad():
        sol = odeint(ode_wrapper_test, x0, t_tensor, method='euler')
        Y_pred = sol[:, 0, 0].cpu().numpy()  # normalized
    test_sim_results.append(Y_pred)
    
# 'Y_pred'를 test_dict_list 각 dict에 넣어줌
for idx, d in enumerate(test_dict_list):
    d['Y_pred'] = test_sim_results[idx]  # normalized

# ----- 2. 각 dict 사용한 rmse 값 프린트 -----
rmse_values = []
mask_soc_range = []

for idx, d in enumerate(test_dict_list):
    # Denormalize Y (Vcorr)
    Y_pred_denorm = denorm_Y(np.array(d['Y_pred']))
    Y_true_denorm = denorm_Y(np.array(d['Y']))  # ground truth

    rmse = calc_rmse(Y_true_denorm, Y_pred_denorm)
    rmse_values.append(rmse)
    
    # SOC 마스킹 (0.11~0.96)
    soc = np.array(d['SOC'])
    mask = (soc >= 0.11) & (soc <= 0.96)
    mask_soc_range.append(mask)

    print(f"Test Dict {idx}: RMSE = {rmse * 1e3:.3f} mV (all points), "
          f"RMSE_in_SOC[0.11, 0.96] = {calc_rmse(Y_true_denorm[mask], Y_pred_denorm[mask]) * 1e3:.3f} mV "
          f"[points: {mask.sum()}]")

# 3. soc [0.11, 0.96] 사이 값들의 최소, median, 최대 RMSE dict의 전압값 프린트

rmse_soc_range = [
    calc_rmse(denorm_Y(np.array(d['Y'])[mask_soc_range[idx]]), denorm_Y(np.array(d['Y_pred'])[mask_soc_range[idx]]))
    for idx, d in enumerate(test_dict_list)
]
rmse_soc_range = np.array(rmse_soc_range)

# min, median, max 찾기
args_sorted = np.argsort(rmse_soc_range)
idx_min = args_sorted[0]
idx_median = args_sorted[len(rmse_soc_range) // 2]
idx_max = args_sorted[-1]

highlight_indices = [("min", idx_min), ("median", idx_median), ("max", idx_max)]

for label, idx in highlight_indices:
    d = test_dict_list[idx]
    mask = mask_soc_range[idx]

    V_meas = np.array(d['V_meas'])[mask]
    V_spme = np.array(d['V_spme'])[mask]
    Y_pred_d = denorm_Y(np.array(d['Y_pred']))[mask]
    SOC = np.array(d['SOC'])[mask]
    time = np.array(d['time'])[mask]

    # Create subplot with secondary y-axis
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    
    # Left y-axis: Voltage
    fig.add_trace(
        go.Scatter(x=time, y=V_meas, name='V_meas', line=dict(color='blue', width=2)),
        secondary_y=False,
    )
    fig.add_trace(
        go.Scatter(x=time, y=V_spme + Y_pred_d, name='V_spme + Y_pred (denorm)', 
                  line=dict(color='red', width=2, dash='dash')),
        secondary_y=False,
    )
    
    # Right y-axis: SOC
    fig.add_trace(
        go.Scatter(x=time, y=SOC, name='SOC', line=dict(color='green', width=2, dash='dot')),
        secondary_y=True,
    )
    
    # Update axes labels
    fig.update_xaxes(title_text="Time (s)")
    fig.update_yaxes(title_text="Voltage (V)", secondary_y=False)
    fig.update_yaxes(title_text="SOC", secondary_y=True)
    
    # Update title
    fig.update_layout(
        title=f'Test Dict #{idx} ({label.upper()} RMSE in SOC[0.11,0.96]) | RMSE: {rmse_soc_range[idx]*1e3:.3f} mV',
        width=1000,
        height=500
    )
    
    fig.show()
# Out:
# Loading checkpoint from: best_model_batch_rmse1.82mV.pth
# ✓ Checkpoint loaded successfully!
#   - Best RMSE: 1.82mV
#   - Best epoch: 50
# Test Dict 0: RMSE = 2.720 mV (all points), RMSE_in_SOC[0.11, 0.96] = 2.720 mV [points: 1201]
# Test Dict 1: RMSE = 0.532 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.532 mV [points: 1201]
# Test Dict 2: RMSE = 1.010 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.010 mV [points: 1202]
# Test Dict 3: RMSE = 0.612 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.612 mV [points: 1201]
# Test Dict 4: RMSE = 0.745 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.745 mV [points: 1202]
# Test Dict 5: RMSE = 2.434 mV (all points), RMSE_in_SOC[0.11, 0.96] = 2.434 mV [points: 1204]
# Test Dict 6: RMSE = 0.961 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.961 mV [points: 1202]
# Test Dict 7: RMSE = 9.448 mV (all points), RMSE_in_SOC[0.11, 0.96] = 9.448 mV [points: 1203]
# Test Dict 8: RMSE = 0.839 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.839 mV [points: 1203]
# Test Dict 9: RMSE = 1.482 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.482 mV [points: 1201]
# Test Dict 10: RMSE = 1.034 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.034 mV [points: 1204]
# Test Dict 11: RMSE = 1.203 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.203 mV [points: 1201]
# Test Dict 12: RMSE = 1.204 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.204 mV [points: 1202]
# Test Dict 13: RMSE = 1.240 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.240 mV [points: 1201]
# Test Dict 14: RMSE = 0.923 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.923 mV [points: 1201]
# Test Dict 15: RMSE = 1.032 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.032 mV [points: 1200]
# Test Dict 16: RMSE = 0.603 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.603 mV [points: 1202]
# Test Dict 17: RMSE = 0.904 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.904 mV [points: 1202]
# Test Dict 18: RMSE = 1.327 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.327 mV [points: 1202]
# Test Dict 19: RMSE = 1.389 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.389 mV [points: 1204]
# Test Dict 20: RMSE = 0.816 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.816 mV [points: 1203]
# Test Dict 21: RMSE = 0.965 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.965 mV [points: 1202]
# Test Dict 22: RMSE = 0.719 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.719 mV [points: 1202]
# Test Dict 23: RMSE = 1.218 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.218 mV [points: 1203]
# Test Dict 24: RMSE = 0.456 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.456 mV [points: 1201]
# Test Dict 25: RMSE = 1.285 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.285 mV [points: 1200]
# Test Dict 26: RMSE = 0.749 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.749 mV [points: 1204]
# Test Dict 27: RMSE = 0.788 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.788 mV [points: 1202]
# Test Dict 28: RMSE = 1.179 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.179 mV [points: 1202]
# Test Dict 29: RMSE = 0.757 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.757 mV [points: 1202]
# Test Dict 30: RMSE = 1.019 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.019 mV [points: 1204]
# Test Dict 31: RMSE = 0.406 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.406 mV [points: 1201]
# Test Dict 32: RMSE = 0.962 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.962 mV [points: 1203]
# Test Dict 33: RMSE = 0.924 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.924 mV [points: 1201]
# Test Dict 34: RMSE = 0.715 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.715 mV [points: 1175]
# Test Dict 35: RMSE = 1.403 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.403 mV [points: 1200]
# Test Dict 36: RMSE = 0.843 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.843 mV [points: 1201]
# Test Dict 37: RMSE = 1.449 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.449 mV [points: 1204]
# Test Dict 38: RMSE = 0.803 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.803 mV [points: 1200]
# Test Dict 39: RMSE = 1.025 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.025 mV [points: 1202]
# Test Dict 40: RMSE = 1.621 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.621 mV [points: 1204]
# Test Dict 41: RMSE = 0.876 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.876 mV [points: 1202]
# Test Dict 42: RMSE = 4.340 mV (all points), RMSE_in_SOC[0.11, 0.96] = 4.340 mV [points: 1200]
# Test Dict 43: RMSE = 0.671 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.671 mV [points: 1202]
# Test Dict 44: RMSE = 0.746 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.746 mV [points: 1203]
# Test Dict 45: RMSE = 5.191 mV (all points), RMSE_in_SOC[0.11, 0.96] = 5.191 mV [points: 1201]
# Test Dict 46: RMSE = 0.757 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.757 mV [points: 1202]
# Test Dict 47: RMSE = 1.524 mV (all points), RMSE_in_SOC[0.11, 0.96] = 1.524 mV [points: 1202]
# Test Dict 48: RMSE = 0.635 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.635 mV [points: 1201]
# Test Dict 49: RMSE = 0.465 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.465 mV [points: 1203]
# Test Dict 50: RMSE = 0.829 mV (all points), RMSE_in_SOC[0.11, 0.96] = 0.829 mV [points: 1201]
