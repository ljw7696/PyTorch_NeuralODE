# %% [markdown]
# ### Import Libraries

# %%
# ===== Auto Reload =====
# %load_ext autoreload
# %autoreload 2

# ===== Standard Libraries =====
import numpy as np
import matplotlib.pyplot as plt
import scipy
import random
import os
import re


# ===== PyTorch =====
import torch
import torch.nn as nn
from torchdiffeq import odeint

# torchdiffeq 버전 확인
import torchdiffeq
print(f"torchdiffeq version: {torchdiffeq.__version__}")
print("")

# ===== Check Installation =====
print("="*50)
print("Environment Check")
print("="*50)
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA device: {torch.cuda.get_device_name(0)}")
print(f"CUDA available: {torch.cuda.is_available()}")
print("="*50)
print("")


# ===== Your Custom Module =====
# Import from battery_benchmark_wrapper
import sys
from pathlib import Path

project_root = Path(r"C:\Users\ljw76\Documents\Python\PyTorch_NeuralODE")
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from neuralODE.utils import *
from battery_benchmark_wrapper import*

print("="*50)
print("✓ All modules loaded!")
print("="*50)
# Out:
# torchdiffeq version: 0.2.5
#
# ==================================================
# Environment Check
# ==================================================
# PyTorch version: 2.5.1
# CUDA device: NVIDIA RTX 3500 Ada Generation Laptop GPU
# CUDA available: True
# ==================================================
#
# ==================================================
# ✓ All modules loaded!
# ==================================================

# %% [markdown]
# ### Data Import

# %%
# MATLAB 데이터 디렉토리 경로
data_dir = r"C:\Users\ljw76\Documents\MATLAB\LFP_SAFT\data\learning_data2"

# ===== 온도 필터 설정 =====
target_temps = [25]  # 원하는 온도 리스트 (예: [25, 35] 또는 [] 이면 모든 온도)

# 디렉토리 내 모든 .mat 파일 목록 가져오기
mat_files = [f for f in os.listdir(data_dir) if f.endswith('.mat')]
print(f"Found {len(mat_files)} .mat files:")
for file in mat_files:
    print(f"  - {file}")

# 모든 파일 로드
print(f"\nLoading files with temperature filter: {target_temps if target_temps else 'All'}")
all_loaded_data = {}

for i, file in enumerate(mat_files):
    file_path = os.path.join(data_dir, file)
    print(f"Loading {i+1}/{len(mat_files)}: {file}")
    
    try:
        mat_data = scipy.io.loadmat(file_path)
        
        # 온도 추출 (파일명에서, 대문자 C만 찾기)
        temp_match = re.search(r'_(\d+)C_', file)
        file_temp = int(temp_match.group(1)) if temp_match else None
        
        # 온도 필터링
        if target_temps and (file_temp is None or file_temp not in target_temps):
            print(f"  ⚠ Skipped (temp: {file_temp}°C)")
            continue
        
        # 파일명에서 확장자 제거하여 키로 사용
        file_key = file.replace('.mat', '')
        
        # 메타데이터 키 제외한 실제 데이터만 저장
        data_keys = [key for key in mat_data.keys() if not key.startswith('__')]
        all_loaded_data[file_key] = {}
        
        for key in data_keys:
            all_loaded_data[file_key][key] = mat_data[key]
        
        print(f"  ✓ Loaded (temp: {file_temp}°C) - {len(data_keys)} data keys: {data_keys}")
        
    except Exception as e:
        print(f"  ✗ Failed to load {file}: {e}")

print(f"\nAll files loaded!")
print(f"Successfully loaded {len(all_loaded_data)} files:")
for file_key, data_dict in all_loaded_data.items():
    print(f"  {file_key}: {list(data_dict.keys())}")

# 첫 번째 파일의 데이터 구조 상세 확인
if all_loaded_data:
    first_file_key = list(all_loaded_data.keys())[0]
    first_data_key = list(all_loaded_data[first_file_key].keys())[0]
    sample_data = all_loaded_data[first_file_key][first_data_key]

    print(f"\nSample data structure from {first_file_key}[{first_data_key}]:")
    print(f"  Shape: {sample_data.shape}")
    print(f"  Type: {type(sample_data)}")
    if hasattr(sample_data, 'dtype'):
        print(f"  Dtype: {sample_data.dtype}")
        if hasattr(sample_data.dtype, 'names') and sample_data.dtype.names:
            print(f"  Field names: {sample_data.dtype.names}")
# Out:
# Found 152 .mat files:
#   - gitt_restonly_25C_SOC_10.mat
#   - gitt_restonly_25C_SOC_100.mat
#   - gitt_restonly_25C_SOC_11.mat
#   - gitt_restonly_25C_SOC_12.mat
#   - gitt_restonly_25C_SOC_13.mat
#   - gitt_restonly_25C_SOC_14.mat
#   - gitt_restonly_25C_SOC_15.mat
#   - gitt_restonly_25C_SOC_16.mat
#   - gitt_restonly_25C_SOC_17.mat
#   - gitt_restonly_25C_SOC_18.mat
#   - gitt_restonly_25C_SOC_19.mat
#   - gitt_restonly_25C_SOC_2.mat
#   - gitt_restonly_25C_SOC_20.mat
#   - gitt_restonly_25C_SOC_21.mat
#   - gitt_restonly_25C_SOC_22.mat
#   - gitt_restonly_25C_SOC_23.mat
#   - gitt_restonly_25C_SOC_25.mat
#   - gitt_restonly_25C_SOC_26.mat
#   - gitt_restonly_25C_SOC_27.mat
#   - gitt_restonly_25C_SOC_28.mat
#   - gitt_restonly_25C_SOC_29.mat
#   - gitt_restonly_25C_SOC_3.mat
#   - gitt_restonly_25C_SOC_30.mat
#   - gitt_restonly_25C_SOC_31.mat
#   - gitt_restonly_25C_SOC_32.mat
#   - gitt_restonly_25C_SOC_33.mat
#   - gitt_restonly_25C_SOC_34.mat
#   - gitt_restonly_25C_SOC_35.mat
#   - gitt_restonly_25C_SOC_36.mat
#   - gitt_restonly_25C_SOC_37.mat
#   - gitt_restonly_25C_SOC_38.mat
#   - gitt_restonly_25C_SOC_39.mat
#   - gitt_restonly_25C_SOC_4.mat
#   - gitt_restonly_25C_SOC_40.mat
#   - gitt_restonly_25C_SOC_41.mat
#   - gitt_restonly_25C_SOC_42.mat
#   - gitt_restonly_25C_SOC_43.mat
#   - gitt_restonly_25C_SOC_44.mat
#   - gitt_restonly_25C_SOC_45.mat
#   - gitt_restonly_25C_SOC_46.mat
#   - gitt_restonly_25C_SOC_47.mat
#   - gitt_restonly_25C_SOC_48.mat
#   - gitt_restonly_25C_SOC_49.mat
#   - gitt_restonly_25C_SOC_5.mat
#   - gitt_restonly_25C_SOC_50.mat
#   - gitt_restonly_25C_SOC_51.mat
#   - gitt_restonly_25C_SOC_52.mat
#   - gitt_restonly_25C_SOC_53.mat
#   - gitt_restonly_25C_SOC_55.mat
#   - gitt_restonly_25C_SOC_56.mat
#   - gitt_restonly_25C_SOC_57.mat
#   - gitt_restonly_25C_SOC_58.mat
#   - gitt_restonly_25C_SOC_59.mat
#   - gitt_restonly_25C_SOC_6.mat
#   - gitt_restonly_25C_SOC_60.mat
mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
# Loading 150/152: udds7_1c_norest_35C_struct.mat
#   ⚠ Skipped (temp: 35°C)
# Loading 151/152: udds7_1c_norest_45C_struct.mat
#   ⚠ Skipped (temp: 45°C)
# Loading 152/152: udds8_1c_norest_25C_struct.mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
#
# All files loaded!
# Successfully loaded 145 files:
#   gitt_restonly_25C_SOC_10: ['spme_struct']
#   gitt_restonly_25C_SOC_100: ['spme_struct']
#   gitt_restonly_25C_SOC_11: ['spme_struct']
#   gitt_restonly_25C_SOC_12: ['spme_struct']
#   gitt_restonly_25C_SOC_13: ['spme_struct']
#   gitt_restonly_25C_SOC_14: ['spme_struct']
#   gitt_restonly_25C_SOC_15: ['spme_struct']
#   gitt_restonly_25C_SOC_16: ['spme_struct']
#   gitt_restonly_25C_SOC_17: ['spme_struct']
#   gitt_restonly_25C_SOC_18: ['spme_struct']
#   gitt_restonly_25C_SOC_19: ['spme_struct']
#   gitt_restonly_25C_SOC_2: ['spme_struct']
#   gitt_restonly_25C_SOC_20: ['spme_struct']
#   gitt_restonly_25C_SOC_21: ['spme_struct']
#   gitt_restonly_25C_SOC_22: ['spme_struct']
#   gitt_restonly_25C_SOC_23: ['spme_struct']
#   gitt_restonly_25C_SOC_25: ['spme_struct']
#   gitt_restonly_25C_SOC_26: ['spme_struct']
#   gitt_restonly_25C_SOC_27: ['spme_struct']
#   gitt_restonly_25C_SOC_28: ['spme_struct']
#   gitt_restonly_25C_SOC_29: ['spme_struct']
#   gitt_restonly_25C_SOC_3: ['spme_struct']
#   gitt_restonly_25C_SOC_30: ['spme_struct']
#   gitt_restonly_25C_SOC_31: ['spme_struct']
#   gitt_restonly_25C_SOC_32: ['spme_struct']
#   gitt_restonly_25C_SOC_33: ['spme_struct']
#   gitt_restonly_25C_SOC_34: ['spme_struct']
#   gitt_restonly_25C_SOC_35: ['spme_struct']
#   gitt_restonly_25C_SOC_36: ['spme_struct']
#   gitt_restonly_25C_SOC_37: ['spme_struct']
#   gitt_restonly_25C_SOC_38: ['spme_struct']
#   gitt_restonly_25C_SOC_39: ['spme_struct']
#   gitt_restonly_25C_SOC_4: ['spme_struct']
#   gitt_restonly_25C_SOC_40: ['spme_struct']
#   gitt_restonly_25C_SOC_41: ['spme_struct']
#   gitt_restonly_25C_SOC_42: ['spme_struct']
#   gitt_restonly_25C_SOC_43: ['spme_struct']
#   gitt_restonly_25C_SOC_44: ['spme_struct']
#   gitt_restonly_25C_SOC_45: ['spme_struct']
#   gitt_restonly_25C_SOC_46: ['spme_struct']
#   gitt_restonly_25C_SOC_47: ['spme_struct']
#   gitt_restonly_25C_SOC_48: ['spme_struct']
#   gitt_restonly_25C_SOC_49: ['spme_struct']
#   gitt_restonly_25C_SOC_5: ['spme_struct']
#   gitt_restonly_25C_SOC_50: ['spme_struct']
#   gitt_restonly_25C_SOC_51: ['spme_struct']
#   gitt_restonly_25C_SOC_52: ['spme_struct']
#   gitt_restonly_25C_SOC_53: ['spme_struct']
#   gitt_restonly_25C_SOC_55: ['spme_struct']
#   gitt_restonly_25C_SOC_56: ['spme_struct']
#   gitt_restonly_25C_SOC_57: ['spme_struct']
#   gitt_restonly_25C_SOC_58: ['spme_struct']
#   gitt_restonly_25C_SOC_59: ['spme_struct']
#   gitt_restonly_25C_SOC_6: ['spme_struct']
#   gitt_restonly_25C_SOC_60: ['spme_struct']
#   gitt_restonly_25C_SOC_61: ['spme_struct']
#   gitt_restonly_25C_SOC_62: ['spme_struct']
#   gitt_restonly_25C_SOC_63: ['spme_struct']
#   gitt_restonly_25C_SOC_64: ['spme_struct']
#   gitt_restonly_25C_SOC_65: ['spme_struct']
#   gitt_restonly_25C_SOC_66: ['spme_struct']
#   gitt_restonly_25C_SOC_67: ['spme_struct']
#   gitt_restonly_25C_SOC_68: ['spme_struct']
#   gitt_restonly_25C_SOC_69: ['spme_struct']
#   gitt_restonly_25C_SOC_7: ['spme_struct']
#   gitt_restonly_25C_SOC_70: ['spme_struct']
#   gitt_restonly_25C_SOC_71: ['spme_struct']
#   gitt_restonly_25C_SOC_72: ['spme_struct']
#   gitt_restonly_25C_SOC_73: ['spme_struct']
#   gitt_restonly_25C_SOC_74: ['spme_struct']
#   gitt_restonly_25C_SOC_75: ['spme_struct']
#   gitt_restonly_25C_SOC_76: ['spme_struct']
#   gitt_restonly_25C_SOC_77: ['spme_struct']
#   gitt_restonly_25C_SOC_78: ['spme_struct']
#   gitt_restonly_25C_SOC_79: ['spme_struct']
#   gitt_restonly_25C_SOC_8: ['spme_struct']
#   gitt_restonly_25C_SOC_80: ['spme_struct']
#   gitt_restonly_25C_SOC_81: ['spme_struct']
#   gitt_restonly_25C_SOC_82: ['spme_struct']
#   gitt_restonly_25C_SOC_83: ['spme_struct']
#   gitt_restonly_25C_SOC_84: ['spme_struct']
#   gitt_restonly_25C_SOC_86: ['spme_struct']
#   gitt_restonly_25C_SOC_87: ['spme_struct']
#   gitt_restonly_25C_SOC_88: ['spme_struct']
#   gitt_restonly_25C_SOC_89: ['spme_struct']
#   gitt_restonly_25C_SOC_9: ['spme_struct']
#   gitt_restonly_25C_SOC_90: ['spme_struct']
#   gitt_restonly_25C_SOC_91: ['spme_struct']
#   gitt_restonly_25C_SOC_92: ['spme_struct']
#   gitt_restonly_25C_SOC_93: ['spme_struct']
#   gitt_restonly_25C_SOC_94: ['spme_struct']
#   gitt_restonly_25C_SOC_95: ['spme_struct']
#   gitt_restonly_25C_SOC_96: ['spme_struct']
#   gitt_restonly_25C_SOC_97: ['spme_struct']
#   gitt_restonly_25C_SOC_98: ['spme_struct']
#   gitt_restonly_25C_SOC_99: ['spme_struct']
#   udds1_1c_norest_25C_struct: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_100: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_11: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_16: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_21: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_25: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_30: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_35: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_39: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_44: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_49: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_53: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_58: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_63: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_67: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_7: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_72: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_77: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_81: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_86: ['spme_struct']
#   udds2_1c_drivingonly_25C_SOC_91: ['spme_struct']
#   udds2_1c_norest_25C_struct: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_100: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_11: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_16: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_21: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_25: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_30: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_35: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_39: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_44: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_49: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_53: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_58: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_63: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_67: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_7: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_72: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_77: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_81: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_86: ['spme_struct']
#   udds2_1c_restonly_25C_SOC_91: ['spme_struct']
#   udds2_1c_rest_25C_struct: ['spme_struct']
#   udds3_1c_norest_25C_struct: ['spme_struct']
#   udds4_1c_norest_25C_struct: ['spme_struct']
#   udds5_1c_norest_25C_struct: ['spme_struct']
#   udds6_1c_norest_25C_struct: ['spme_struct']
#   udds7_1c_norest_25C_struct: ['spme_struct']
#   udds8_1c_norest_25C_struct: ['spme_struct']
#
# Sample data structure from gitt_restonly_25C_SOC_10[spme_struct]:
#   Shape: (1, 1)
#   Type: <class 'numpy.ndarray'>
#   Dtype: [('time', 'O'), ('current', 'O'), ('temperature', 'O'), ('Vout', 'O'), ('Ve', 'O'), ('Vcond', 'O'), ('eta_p', 'O'), ('eta_n', 'O'), ('Un', 'O'), ('Up', 'O'), ('ocp', 'O'), ('soc_n', 'O'), ('soc_p', 'O'), ('c_s_p_surf', 'O'), ('c_s_n_surf', 'O'), ('c_s_p_bulk', 'O'), ('c_s_n_bulk', 'O'), ('i0p', 'O'), ('k_cs', 'O'), ('alpha_cs', 'O'), ('tau_cs', 'O'), ('c_s_p_surf_tilde', 'O'), ('Dsn_eff', 'O'), ('Dsp_eff', 'O'), ('Vspme', 'O'), ('Vref', 'O')]
#   Field names: ('time', 'current', 'temperature', 'Vout', 'Ve', 'Vcond', 'eta_p', 'eta_n', 'Un', 'Up', 'ocp', 'soc_n', 'soc_p', 'c_s_p_surf', 'c_s_n_surf', 'c_s_p_bulk', 'c_s_n_bulk', 'i0p', 'k_cs', 'alpha_cs', 'tau_cs', 'c_s_p_surf_tilde', 'Dsn_eff', 'Dsp_eff', 'Vspme', 'Vref')

# %% [markdown]
# ### Convert Struct to Data Frame

# %%
# ===== Key 선택 =====
target_keys = ["time", "Vref", "Vspme", "current", "temperature", "c_s_n_bulk", "soc_n", "ocp"]

# ===== 모든 파일 처리 =====
extracted_data = {}  # Dictionary로 저장

excluded_target = []
excluded_data = {}
# extracted_data는 excluded_target에 들어있지 않은 것만, excluded_data는 target에 들어있는 것만 저장하도록 아래 for문 수정

print("="*60)
print("Converting all structs to DataFrames")
print("="*60)

for file_key, data_dict in all_loaded_data.items():
    print(f"\nProcessing: {file_key}")
    
    # struct 추출 (첫 번째 key)
    struct_key = list(data_dict.keys())[0]
    struct_data = data_dict[struct_key]
    
    # DataFrame 변환
    df = struct2df(struct_data, selected_keys=target_keys)

    # 저장: excluded_target 리스트에 있으면 excluded_data에, 아니면 extracted_data에
    if file_key in excluded_target:
        excluded_data[file_key] = df
        print(f"  ✓ DataFrame created (EXCLUDED): {df.shape}")
    else:
        extracted_data[file_key] = df
        print(f"  ✓ DataFrame created: {df.shape}")
    print(f"  Columns: {list(df.columns)}")

print("\n" + "="*60)
print(f"✓ Total {len(extracted_data)} DataFrames created!")
print(f"✓ Total {len(excluded_data)} EXCLUDED DataFrames created!")
print("="*60)

# 요약
for name, df in extracted_data.items():
    print(f"  {name}: {df.shape}")

for name, df in excluded_data.items():
    print(f"  (EXCLUDED) {name}: {df.shape}")
# extracted_data는 excluded_target에 들어있지 않은 것만 들어가게끔 for문에서 처리 (아래 for문 참고!)
# Out:
# ============================================================
# Converting all structs to DataFrames
# ============================================================
#
# Processing: gitt_restonly_25C_SOC_10
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_100
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_11
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3600, 1)       → 3600 points
#   ✓ Vref                : shape (3600, 1)       → 3600 points
#   ✓ Vspme               : shape (3600, 1)       → 3600 points
#   ✓ current             : shape (3600, 1)       → 3600 points
#   ✓ temperature         : shape (3600, 1)       → 3600 points
#   ✓ c_s_n_bulk          : shape (3600, 1)       → 3600 points
#   ✓ soc_n               : shape (3600, 1)       → 3600 points
#   ✓ ocp                 : shape (3600, 1)       → 3600 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3600 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3600, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_12
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_13
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_14
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_15
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_16
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_17
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_18
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_19
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_2
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_20
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_21
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_22
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_23
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_25
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_26
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_27
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3600, 1)       → 3600 points
#   ✓ Vref                : shape (3600, 1)       → 3600 points
#   ✓ Vspme               : shape (3600, 1)       → 3600 points
#   ✓ current             : shape (3600, 1)       → 3600 points
#   ✓ temperature         : shape (3600, 1)       → 3600 points
#   ✓ c_s_n_bulk          : shape (3600, 1)       → 3600 points
#   ✓ soc_n               : shape (3600, 1)       → 3600 points
#   ✓ ocp                 : shape (3600, 1)       → 3600 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3600 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3600, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_28
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_29
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_3
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_30
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_31
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_32
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_33
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_34
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (3601, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: gitt_restonly_25C_SOC_35
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (3601, 1)       → 3601 points
#   ✓ Vref                : shape (3601, 1)       → 3601 points
#   ✓ Vspme               : shape (3601, 1)       → 3601 points
#   ✓ current             : shape (3601, 1)       → 3601 points
#   ✓ temperature         : shape (3601, 1)       → 3601 points
#   ✓ c_s_n_bulk          : shape (3601, 1)       → 3601 points
#   ✓ soc_n               : shape (3601, 1)       → 3601 points
#   ✓ ocp                 : shape (3601, 1)       → 3601 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 3601 rows × 9 columns
# ...
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (42754, 1)      → 42754 points
#   ✓ Vref                : shape (42754, 1)      → 42754 points
#   ✓ Vspme               : shape (42754, 1)      → 42754 points
#   ✓ current             : shape (42754, 1)      → 42754 points
#   ✓ temperature         : shape (42754, 1)      → 42754 points
#   ✓ c_s_n_bulk          : shape (42754, 1)      → 42754 points
#   ✓ soc_n               : shape (42754, 1)      → 42754 points
#   ✓ ocp                 : shape (42754, 1)      → 42754 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 42754 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (42754, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds4_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (68411, 1)      → 68411 points
#   ✓ Vref                : shape (68411, 1)      → 68411 points
#   ✓ Vspme               : shape (68411, 1)      → 68411 points
#   ✓ current             : shape (68411, 1)      → 68411 points
#   ✓ temperature         : shape (68411, 1)      → 68411 points
#   ✓ c_s_n_bulk          : shape (68411, 1)      → 68411 points
#   ✓ soc_n               : shape (68411, 1)      → 68411 points
#   ✓ ocp                 : shape (68411, 1)      → 68411 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 68411 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (68411, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds5_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (77084, 1)      → 77084 points
#   ✓ Vref                : shape (77084, 1)      → 77084 points
#   ✓ Vspme               : shape (77084, 1)      → 77084 points
#   ✓ current             : shape (77084, 1)      → 77084 points
#   ✓ temperature         : shape (77084, 1)      → 77084 points
#   ✓ c_s_n_bulk          : shape (77084, 1)      → 77084 points
#   ✓ soc_n               : shape (77084, 1)      → 77084 points
#   ✓ ocp                 : shape (77084, 1)      → 77084 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 77084 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (77084, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds6_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (30309, 1)      → 30309 points
#   ✓ Vref                : shape (30309, 1)      → 30309 points
#   ✓ Vspme               : shape (30309, 1)      → 30309 points
#   ✓ current             : shape (30309, 1)      → 30309 points
#   ✓ temperature         : shape (30309, 1)      → 30309 points
#   ✓ c_s_n_bulk          : shape (30309, 1)      → 30309 points
#   ✓ soc_n               : shape (30309, 1)      → 30309 points
#   ✓ ocp                 : shape (30309, 1)      → 30309 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 30309 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (30309, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds7_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (33596, 1)      → 33596 points
#   ✓ Vref                : shape (33596, 1)      → 33596 points
#   ✓ Vspme               : shape (33596, 1)      → 33596 points
#   ✓ current             : shape (33596, 1)      → 33596 points
#   ✓ temperature         : shape (33596, 1)      → 33596 points
#   ✓ c_s_n_bulk          : shape (33596, 1)      → 33596 points
#   ✓ soc_n               : shape (33596, 1)      → 33596 points
#   ✓ ocp                 : shape (33596, 1)      → 33596 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 33596 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (33596, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# Processing: udds8_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#   8. ocp ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (30939, 1)      → 30939 points
#   ✓ Vref                : shape (30939, 1)      → 30939 points
#   ✓ Vspme               : shape (30939, 1)      → 30939 points
#   ✓ current             : shape (30939, 1)      → 30939 points
#   ✓ temperature         : shape (30939, 1)      → 30939 points
#   ✓ c_s_n_bulk          : shape (30939, 1)      → 30939 points
#   ✓ soc_n               : shape (30939, 1)      → 30939 points
#   ✓ ocp                 : shape (30939, 1)      → 30939 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 30939 rows × 9 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
#   ✓ DataFrame created: (30939, 9)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'ocp', 'Vcorr']
#
# ============================================================
# ✓ Total 145 DataFrames created!
# ✓ Total 0 EXCLUDED DataFrames created!
# ============================================================
#   gitt_restonly_25C_SOC_10: (3601, 9)
#   gitt_restonly_25C_SOC_100: (3601, 9)
#   gitt_restonly_25C_SOC_11: (3600, 9)
#   gitt_restonly_25C_SOC_12: (3601, 9)
#   gitt_restonly_25C_SOC_13: (3601, 9)
#   gitt_restonly_25C_SOC_14: (3601, 9)
#   gitt_restonly_25C_SOC_15: (3601, 9)
#   gitt_restonly_25C_SOC_16: (3601, 9)
#   gitt_restonly_25C_SOC_17: (3601, 9)
#   gitt_restonly_25C_SOC_18: (3601, 9)
#   gitt_restonly_25C_SOC_19: (3601, 9)
#   gitt_restonly_25C_SOC_2: (3601, 9)
#   gitt_restonly_25C_SOC_20: (3601, 9)
#   gitt_restonly_25C_SOC_21: (3601, 9)
#   gitt_restonly_25C_SOC_22: (3601, 9)
#   gitt_restonly_25C_SOC_23: (3601, 9)
#   gitt_restonly_25C_SOC_25: (3601, 9)
#   gitt_restonly_25C_SOC_26: (3601, 9)
#   gitt_restonly_25C_SOC_27: (3600, 9)
#   gitt_restonly_25C_SOC_28: (3601, 9)
#   gitt_restonly_25C_SOC_29: (3601, 9)
#   gitt_restonly_25C_SOC_3: (3601, 9)
#   gitt_restonly_25C_SOC_30: (3601, 9)
#   gitt_restonly_25C_SOC_31: (3601, 9)
#   gitt_restonly_25C_SOC_32: (3601, 9)
#   gitt_restonly_25C_SOC_33: (3601, 9)
#   gitt_restonly_25C_SOC_34: (3601, 9)
#   gitt_restonly_25C_SOC_35: (3601, 9)
#   gitt_restonly_25C_SOC_36: (3600, 9)
#   gitt_restonly_25C_SOC_37: (3601, 9)
#   gitt_restonly_25C_SOC_38: (3601, 9)
#   gitt_restonly_25C_SOC_39: (3601, 9)
#   gitt_restonly_25C_SOC_4: (3601, 9)
#   gitt_restonly_25C_SOC_40: (3601, 9)
#   gitt_restonly_25C_SOC_41: (3601, 9)
#   gitt_restonly_25C_SOC_42: (3601, 9)
#   gitt_restonly_25C_SOC_43: (3601, 9)
#   gitt_restonly_25C_SOC_44: (3601, 9)
#   gitt_restonly_25C_SOC_45: (3601, 9)
#   gitt_restonly_25C_SOC_46: (3601, 9)
#   gitt_restonly_25C_SOC_47: (3601, 9)
#   gitt_restonly_25C_SOC_48: (3601, 9)
#   gitt_restonly_25C_SOC_49: (3601, 9)
#   gitt_restonly_25C_SOC_5: (3601, 9)
#   gitt_restonly_25C_SOC_50: (3600, 9)
#   gitt_restonly_25C_SOC_51: (3601, 9)
#   gitt_restonly_25C_SOC_52: (3601, 9)
#   gitt_restonly_25C_SOC_53: (3601, 9)
#   gitt_restonly_25C_SOC_55: (3601, 9)
#   gitt_restonly_25C_SOC_56: (3601, 9)
#   gitt_restonly_25C_SOC_57: (3601, 9)
#   gitt_restonly_25C_SOC_58: (3601, 9)
#   gitt_restonly_25C_SOC_59: (3601, 9)
#   gitt_restonly_25C_SOC_6: (3601, 9)
#   gitt_restonly_25C_SOC_60: (3601, 9)
#   gitt_restonly_25C_SOC_61: (3601, 9)
#   gitt_restonly_25C_SOC_62: (3601, 9)
#   gitt_restonly_25C_SOC_63: (3601, 9)
#   gitt_restonly_25C_SOC_64: (3601, 9)
#   gitt_restonly_25C_SOC_65: (3600, 9)
#   gitt_restonly_25C_SOC_66: (3601, 9)
#   gitt_restonly_25C_SOC_67: (3601, 9)
#   gitt_restonly_25C_SOC_68: (3601, 9)
#   gitt_restonly_25C_SOC_69: (3601, 9)
#   gitt_restonly_25C_SOC_7: (3601, 9)
#   gitt_restonly_25C_SOC_70: (3601, 9)
#   gitt_restonly_25C_SOC_71: (3601, 9)
#   gitt_restonly_25C_SOC_72: (3601, 9)
#   gitt_restonly_25C_SOC_73: (3601, 9)
#   gitt_restonly_25C_SOC_74: (3601, 9)
#   gitt_restonly_25C_SOC_75: (3601, 9)
#   gitt_restonly_25C_SOC_76: (3600, 9)
#   gitt_restonly_25C_SOC_77: (3601, 9)
#   gitt_restonly_25C_SOC_78: (3601, 9)
#   gitt_restonly_25C_SOC_79: (3601, 9)
#   gitt_restonly_25C_SOC_8: (3601, 9)
#   gitt_restonly_25C_SOC_80: (3601, 9)
#   gitt_restonly_25C_SOC_81: (3601, 9)
#   gitt_restonly_25C_SOC_82: (3601, 9)
#   gitt_restonly_25C_SOC_83: (3601, 9)
#   gitt_restonly_25C_SOC_84: (3601, 9)
#   gitt_restonly_25C_SOC_86: (3601, 9)
#   gitt_restonly_25C_SOC_87: (3601, 9)
#   gitt_restonly_25C_SOC_88: (3601, 9)
#   gitt_restonly_25C_SOC_89: (3601, 9)
#   gitt_restonly_25C_SOC_9: (3601, 9)
#   gitt_restonly_25C_SOC_90: (3601, 9)
#   gitt_restonly_25C_SOC_91: (3601, 9)
#   gitt_restonly_25C_SOC_92: (3601, 9)
#   gitt_restonly_25C_SOC_93: (3601, 9)
#   gitt_restonly_25C_SOC_94: (3601, 9)
#   gitt_restonly_25C_SOC_95: (3601, 9)
#   gitt_restonly_25C_SOC_96: (3601, 9)
#   gitt_restonly_25C_SOC_97: (3601, 9)
#   gitt_restonly_25C_SOC_98: (3601, 9)
#   gitt_restonly_25C_SOC_99: (3601, 9)
#   udds1_1c_norest_25C_struct: (41150, 9)
#   udds2_1c_drivingonly_25C_SOC_100: (721, 9)
#   udds2_1c_drivingonly_25C_SOC_11: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_16: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_21: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_25: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_30: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_35: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_39: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_44: (1800, 9)
#   udds2_1c_drivingonly_25C_SOC_49: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_53: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_58: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_63: (1800, 9)
#   udds2_1c_drivingonly_25C_SOC_67: (1800, 9)
#   udds2_1c_drivingonly_25C_SOC_7: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_72: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_77: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_81: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_86: (1801, 9)
#   udds2_1c_drivingonly_25C_SOC_91: (1801, 9)
#   udds2_1c_norest_25C_struct: (36681, 9)
#   udds2_1c_restonly_25C_SOC_100: (10801, 9)
#   udds2_1c_restonly_25C_SOC_11: (10800, 9)
#   udds2_1c_restonly_25C_SOC_16: (10800, 9)
#   udds2_1c_restonly_25C_SOC_21: (10800, 9)
#   udds2_1c_restonly_25C_SOC_25: (10800, 9)
#   udds2_1c_restonly_25C_SOC_30: (10801, 9)
#   udds2_1c_restonly_25C_SOC_35: (10801, 9)
#   udds2_1c_restonly_25C_SOC_39: (10800, 9)
#   udds2_1c_restonly_25C_SOC_44: (10800, 9)
#   udds2_1c_restonly_25C_SOC_49: (10800, 9)
#   udds2_1c_restonly_25C_SOC_53: (10800, 9)
#   udds2_1c_restonly_25C_SOC_58: (10800, 9)
#   udds2_1c_restonly_25C_SOC_63: (10801, 9)
#   udds2_1c_restonly_25C_SOC_67: (10801, 9)
#   udds2_1c_restonly_25C_SOC_7: (10800, 9)
#   udds2_1c_restonly_25C_SOC_72: (10801, 9)
#   udds2_1c_restonly_25C_SOC_77: (10801, 9)
#   udds2_1c_restonly_25C_SOC_81: (10801, 9)
#   udds2_1c_restonly_25C_SOC_86: (10801, 9)
#   udds2_1c_restonly_25C_SOC_91: (10801, 9)
#   udds2_1c_rest_25C_struct: (273245, 9)
#   udds3_1c_norest_25C_struct: (42754, 9)
#   udds4_1c_norest_25C_struct: (68411, 9)
#   udds5_1c_norest_25C_struct: (77084, 9)
#   udds6_1c_norest_25C_struct: (30309, 9)
#   udds7_1c_norest_25C_struct: (33596, 9)
#   udds8_1c_norest_25C_struct: (30939, 9)

# %% [markdown]
# ### Data Pre-Processing

# %%
# 'soc_n' 값이 0.96 ~ 0.12 (96% ~ 12%) 사이인 데이터만 target_data에 저장
# target_data를 리스트(list)로 저장 (DataFrame만 담김, key는 저장하지 않음)
drivingonly_keywords = ['drivingonly']
norest_keywords = ['norest']


################## Driving Only Training ##################
drivingonly_list = extract_data(extracted_data, drivingonly_keywords, soc_lb=0.0, soc_ub=1.0)
norest_list_temp = extract_data(extracted_data, norest_keywords, soc_lb=0.0, soc_ub=1.0)

drivingonly_list = remove_duplicates(drivingonly_list)

norest_list_temp = remove_duplicates(norest_list_temp)
norest_list = norest_list_temp[:6] + norest_list_temp[7:]
norest_final_test = [norest_list_temp[6]]

norest_list_split = split_df(norest_list, window_minutes=20, time_col='time', random_seed=42)

drivingonly_dict_list = df2dict(drivingonly_list)
norest_dict_list = df2dict(norest_list_split)
norest_dict_final_test = df2dict(norest_final_test)


norest_dict_training, norest_dict_test = split_train_test(norest_dict_list, 0.8)
drivingonly_dict_training, drivingonly_dict_test = split_train_test(drivingonly_dict_list, 0.8)


driving_dict_training = drivingonly_dict_training + norest_dict_training
driving_dict_test = drivingonly_dict_test + norest_dict_test + norest_dict_final_test



################## Rest Only Training ##################
rest_keywords = ['restonly']

rest_list = extract_data(extracted_data, rest_keywords, soc_lb=0.0, soc_ub=1.0)

rest_list = remove_duplicates(rest_list)

rest_list_smooth = smooth_Vcorr(rest_list, 51) # de-noise data after downsampling

rest_list_split = split_df(rest_list_smooth, window_minutes=20, time_col='time', random_seed=42)

rest_dict_list = df2dict(rest_list_split)

rest_dict_training, rest_dict_test = split_train_test(rest_dict_list, 0.8)




################## Joint Training ##################
combined_dict_training = drivingonly_dict_training + norest_dict_training + rest_dict_training
combined_dict_test = drivingonly_dict_test + norest_dict_test + norest_dict_final_test + rest_dict_test
# Out:
# Key: gitt_restonly_25C_SOC_10, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_100, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_11, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_12, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_13, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_14, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_15, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_16, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_17, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_18, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_19, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_2, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_20, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_21, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_22, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_23, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_25, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_26, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_27, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_28, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_29, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_3, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_30, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_31, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_32, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_33, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_34, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_35, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_36, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_37, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_38, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_39, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_4, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_40, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_41, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_42, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_43, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_44, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_45, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_46, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_47, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_48, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_49, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_5, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_50, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_51, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_52, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_53, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_55, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_56, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_57, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_58, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_59, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_6, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_60, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_61, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_62, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_63, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_64, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_65, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_66, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_67, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_68, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_69, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_7, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_70, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_71, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_72, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_73, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_74, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_75, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_76, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_77, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_78, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_79, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_8, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_80, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_81, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_82, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_83, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_84, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_86, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_87, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_88, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_89, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_9, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_90, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_91, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_92, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_93, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_94, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_95, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_96, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_97, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_98, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_99, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds1_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_100, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 721
# Key: udds2_1c_drivingonly_25C_SOC_11, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_16, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_21, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_25, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_30, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_35, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_39, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_44, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1800
# Key: udds2_1c_drivingonly_25C_SOC_49, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_53, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_58, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_63, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1800
# Key: udds2_1c_drivingonly_25C_SOC_67, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1800
# Key: udds2_1c_drivingonly_25C_SOC_7, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_72, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_77, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_81, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_86, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_drivingonly_25C_SOC_91, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 1801
# Key: udds2_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_100, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_11, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_16, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_21, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_25, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_30, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_35, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_39, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_44, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_49, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_53, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_58, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_63, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_67, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_7, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_72, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_77, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_81, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_86, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_91, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_rest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds3_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds4_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds5_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds6_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds7_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds8_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# 최종 target_list length: 20
# Key: gitt_restonly_25C_SOC_10, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_100, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_11, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_12, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_13, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_14, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_15, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_16, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_17, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_18, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_19, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_2, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_20, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_21, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_22, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_23, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_25, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_26, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_27, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_28, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_29, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_3, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_30, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_31, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_32, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_33, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_34, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_35, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_36, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_37, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_38, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_39, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_4, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_40, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_41, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_42, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_43, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_44, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_45, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_46, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_47, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_48, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_49, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_5, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_50, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_51, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_52, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_53, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_55, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_56, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_57, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_58, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_59, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_6, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_60, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_61, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_62, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_63, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_64, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_65, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_66, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_67, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_68, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_69, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_7, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_70, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_71, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_72, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_73, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_74, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_75, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_76, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_77, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_78, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_79, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_8, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_80, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_81, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_82, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_83, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_84, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_86, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_87, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_88, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_89, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_9, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_90, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_91, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_92, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_93, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_94, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_95, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_96, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_97, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_98, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: gitt_restonly_25C_SOC_99, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds1_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 41150
# Key: udds2_1c_drivingonly_25C_SOC_100, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_11, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_16, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_21, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_25, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_30, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_35, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_39, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_44, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_49, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_53, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_58, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_63, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_67, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_7, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_72, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_77, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_81, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_86, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_91, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 36582
# Key: udds2_1c_restonly_25C_SOC_100, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_11, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_16, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_21, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_25, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_30, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_35, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_39, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_44, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_49, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_53, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_58, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_63, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_67, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_7, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_72, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_77, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_81, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_86, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_91, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_rest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds3_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 40706
# Key: udds4_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 63753
# Key: udds5_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 72379
# Key: udds6_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 28721
# Key: udds7_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 33596
# Key: udds8_1c_norest_25C_struct, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 29181
# 최종 target_list length: 8
# ==================================================
# Starting 'remove_duplicates()'
# Original length of df : 20
# - df1: 721 -> 721 (removed 0 points)
# - df2: 1801 -> 1801 (removed 0 points)
# - df3: 1801 -> 1801 (removed 0 points)
# - df4: 1801 -> 1801 (removed 0 points)
# - df5: 1801 -> 1801 (removed 0 points)
# - df6: 1801 -> 1801 (removed 0 points)
# - df7: 1801 -> 1801 (removed 0 points)
# - df8: 1801 -> 1801 (removed 0 points)
# - df9: 1800 -> 1800 (removed 0 points)
# - df10: 1801 -> 1801 (removed 0 points)
# - df11: 1801 -> 1801 (removed 0 points)
# - df12: 1801 -> 1801 (removed 0 points)
# - df13: 1800 -> 1800 (removed 0 points)
# - df14: 1800 -> 1800 (removed 0 points)
# - df15: 1801 -> 1801 (removed 0 points)
# - df16: 1801 -> 1801 (removed 0 points)
# - df17: 1801 -> 1801 (removed 0 points)
# - df18: 1801 -> 1801 (removed 0 points)
# - df19: 1801 -> 1801 (removed 0 points)
# - df20: 1801 -> 1801 (removed 0 points)
# remove_duplicates() completed
# ==================================================
# ==================================================
# Starting 'remove_duplicates()'
# Original length of df : 8
# - df1: 41150 -> 41139 (removed 11 points)
# - df2: 36582 -> 36571 (removed 11 points)
# - df3: 40706 -> 40704 (removed 2 points)
# - df4: 63753 -> 63743 (removed 10 points)
# - df5: 72379 -> 72333 (removed 46 points)
# - df6: 28721 -> 28717 (removed 4 points)
# - df7: 33596 -> 33590 (removed 6 points)
# - df8: 29181 -> 29179 (removed 2 points)
# remove_duplicates() completed
# ==================================================
# ==================================================
# Starting 'split_df()'
# Number of df in the list : 7
# Total time in the list: 314334.38 sec
# window_minutes: 20 min
# Final number of df: 256
# split_df() completed
# ==================================================
# ==================================================
# Starting 'df2dict()'
# Total number of df in the list: 20
# Number of converted df: 20
# df2dict() completed
# ==================================================
# ==================================================
# Starting 'df2dict()'
# Total number of df in the list: 256
# Number of converted df: 256
# df2dict() completed
# ==================================================
# ==================================================
# Starting 'df2dict()'
# Total number of df in the list: 1
# Number of converted df: 1
# df2dict() completed
# ==================================================
# ==================================================
# Starting 'split_train_test()'
# Total length of dict: 256
# Number of train dict: 204 (79.7%)
# Number of test dict: 52 (20.3%)
# split_train_test() completed
# ==================================================
# ==================================================
# Starting 'split_train_test()'
# Total length of dict: 20
# Number of train dict: 16 (80.0%)
# Number of test dict: 4 (20.0%)
# split_train_test() completed
# ==================================================
# Key: gitt_restonly_25C_SOC_10, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_100, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_11, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3600
# Key: gitt_restonly_25C_SOC_12, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_13, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_14, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_15, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_16, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_17, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_18, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_19, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_2, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_20, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_21, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_22, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_23, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_25, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_26, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_27, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3600
# Key: gitt_restonly_25C_SOC_28, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_29, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_3, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_30, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_31, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_32, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_33, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_34, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_35, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_36, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3600
# Key: gitt_restonly_25C_SOC_37, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_38, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_39, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_4, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_40, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_41, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_42, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_43, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_44, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_45, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_46, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_47, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_48, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_49, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_5, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_50, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3600
# Key: gitt_restonly_25C_SOC_51, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_52, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_53, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_55, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_56, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_57, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_58, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_59, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_6, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_60, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_61, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_62, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_63, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_64, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_65, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3600
# Key: gitt_restonly_25C_SOC_66, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_67, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_68, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_69, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_7, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_70, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_71, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_72, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_73, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_74, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_75, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_76, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3600
# Key: gitt_restonly_25C_SOC_77, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_78, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_79, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_8, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_80, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_81, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_82, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_83, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_84, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_86, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_87, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_88, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_89, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_9, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_90, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_91, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_92, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_93, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_94, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_95, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_96, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_97, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_98, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: gitt_restonly_25C_SOC_99, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 3601
# Key: udds1_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_100, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_11, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_16, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_21, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_25, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_30, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_35, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_39, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_44, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_49, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_53, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_58, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_63, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_67, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_7, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_72, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_77, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_81, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_86, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_drivingonly_25C_SOC_91, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds2_1c_restonly_25C_SOC_100, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_11, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_16, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_21, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_25, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_30, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_35, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_39, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_44, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_49, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_53, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_58, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_63, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_67, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_7, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10800
# Key: udds2_1c_restonly_25C_SOC_72, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_77, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_81, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_86, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_restonly_25C_SOC_91, keyword_match: True, type: <class 'pandas.core.frame.DataFrame'>
#   Added! Rows: 10801
# Key: udds2_1c_rest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds3_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds4_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds5_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds6_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds7_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# Key: udds8_1c_norest_25C_struct, keyword_match: False, type: <class 'pandas.core.frame.DataFrame'>
# 최종 target_list length: 116
# ==================================================
# Starting 'remove_duplicates()'
# Original length of df : 116
# - df1: 3601 -> 3601 (removed 0 points)
# - df2: 3601 -> 3601 (removed 0 points)
# - df3: 3600 -> 3600 (removed 0 points)
# - df4: 3601 -> 3601 (removed 0 points)
# - df5: 3601 -> 3601 (removed 0 points)
# - df6: 3601 -> 3601 (removed 0 points)
# - df7: 3601 -> 3601 (removed 0 points)
# - df8: 3601 -> 3601 (removed 0 points)
# - df9: 3601 -> 3601 (removed 0 points)
# - df10: 3601 -> 3601 (removed 0 points)
# - df11: 3601 -> 3601 (removed 0 points)
# - df12: 3601 -> 3601 (removed 0 points)
# - df13: 3601 -> 3601 (removed 0 points)
# - df14: 3601 -> 3600 (removed 1 points)
# - df15: 3601 -> 3601 (removed 0 points)
# - df16: 3601 -> 3601 (removed 0 points)
# - df80: 3601 -> 3601 (removed 0 points)
# - df81: 3601 -> 3601 (removed 0 points)
# - df82: 3601 -> 3600 (removed 1 points)
# - df83: 3601 -> 3601 (removed 0 points)
# - df84: 3601 -> 3601 (removed 0 points)
# - df85: 3601 -> 3600 (removed 1 points)
# - df86: 3601 -> 3601 (removed 0 points)
# - df87: 3601 -> 3601 (removed 0 points)
# - df88: 3601 -> 3601 (removed 0 points)
# - df89: 3601 -> 3601 (removed 0 points)
# - df90: 3601 -> 3601 (removed 0 points)
# - df91: 3601 -> 3601 (removed 0 points)
# - df92: 3601 -> 3601 (removed 0 points)
# - df93: 3601 -> 3601 (removed 0 points)
# - df94: 3601 -> 3601 (removed 0 points)
# - df95: 3601 -> 3601 (removed 0 points)
# - df96: 3601 -> 3600 (removed 1 points)
# - df97: 10801 -> 10800 (removed 1 points)
# - df98: 10800 -> 10800 (removed 0 points)
# - df99: 10800 -> 10800 (removed 0 points)
# - df100: 10800 -> 10800 (removed 0 points)
# - df101: 10800 -> 10800 (removed 0 points)
# - df102: 10801 -> 10801 (removed 0 points)
# - df103: 10801 -> 10801 (removed 0 points)
# - df104: 10800 -> 10800 (removed 0 points)
# - df105: 10800 -> 10800 (removed 0 points)
# - df106: 10800 -> 10800 (removed 0 points)
# - df107: 10800 -> 10800 (removed 0 points)
# - df108: 10800 -> 10800 (removed 0 points)
# - df109: 10801 -> 10801 (removed 0 points)
# - df110: 10801 -> 10800 (removed 1 points)
# - df111: 10800 -> 10800 (removed 0 points)
# - df112: 10801 -> 10800 (removed 1 points)
# - df113: 10801 -> 10801 (removed 0 points)
# - df114: 10801 -> 10801 (removed 0 points)
# - df115: 10801 -> 10801 (removed 0 points)
# - df116: 10801 -> 10801 (removed 0 points)
# remove_duplicates() completed
# ==================================================
# ==================================================
# Starting 'smooth_Vcorr()'
# Original length of df : 116
# - df1: 3601 -> 3601 (smoothing done)
# - df2: 3601 -> 3601 (smoothing done)
# - df3: 3600 -> 3600 (smoothing done)
# - df4: 3601 -> 3601 (smoothing done)
# - df5: 3601 -> 3601 (smoothing done)
# - df6: 3601 -> 3601 (smoothing done)
# - df7: 3601 -> 3601 (smoothing done)
# - df8: 3601 -> 3601 (smoothing done)
# - df9: 3601 -> 3601 (smoothing done)
# - df10: 3601 -> 3601 (smoothing done)
# - df11: 3601 -> 3601 (smoothing done)
# - df12: 3601 -> 3601 (smoothing done)
# - df13: 3601 -> 3601 (smoothing done)
# - df14: 3600 -> 3600 (smoothing done)
# - df15: 3601 -> 3601 (smoothing done)
# - df16: 3601 -> 3601 (smoothing done)
# - df17: 3601 -> 3601 (smoothing done)
# - df18: 3601 -> 3601 (smoothing done)
# - df19: 3600 -> 3600 (smoothing done)
# - df20: 3601 -> 3601 (smoothing done)
# - df21: 3601 -> 3601 (smoothing done)
# - df22: 3601 -> 3601 (smoothing done)
# - df23: 3601 -> 3601 (smoothing done)
# - df24: 3601 -> 3601 (smoothing done)
# - df25: 3601 -> 3601 (smoothing done)
# - df93: 3601 -> 3601 (smoothing done)
# - df94: 3601 -> 3601 (smoothing done)
# - df95: 3601 -> 3601 (smoothing done)
# - df96: 3600 -> 3600 (smoothing done)
# - df97: 10800 -> 10800 (smoothing done)
# - df98: 10800 -> 10800 (smoothing done)
# - df99: 10800 -> 10800 (smoothing done)
# - df100: 10800 -> 10800 (smoothing done)
# - df101: 10800 -> 10800 (smoothing done)
# - df102: 10801 -> 10801 (smoothing done)
# - df103: 10801 -> 10801 (smoothing done)
# - df104: 10800 -> 10800 (smoothing done)
# - df105: 10800 -> 10800 (smoothing done)
# - df106: 10800 -> 10800 (smoothing done)
# - df107: 10800 -> 10800 (smoothing done)
# - df108: 10800 -> 10800 (smoothing done)
# - df109: 10801 -> 10801 (smoothing done)
# - df110: 10800 -> 10800 (smoothing done)
# - df111: 10800 -> 10800 (smoothing done)
# - df112: 10800 -> 10800 (smoothing done)
# - df113: 10801 -> 10801 (smoothing done)
# - df114: 10801 -> 10801 (smoothing done)
# - df115: 10801 -> 10801 (smoothing done)
# - df116: 10801 -> 10801 (smoothing done)
# smooth_Vcorr() completed
# ==================================================
# ==================================================
# Starting 'split_df()'
# Number of df in the list : 116
# Total time in the list: 561484.05 sec
# window_minutes: 20 min
# Final number of df: 468
# split_df() completed
# ==================================================
# ==================================================
# Starting 'df2dict()'
# Total number of df in the list: 468
# Number of converted df: 468
# df2dict() completed
# ==================================================
# ==================================================
# Starting 'split_train_test()'
# Total length of dict: 468
# Number of train dict: 374 (79.9%)
# Number of test dict: 94 (20.1%)
# split_train_test() completed
# ==================================================

# %% [markdown]
# ### DNN

# %%
from pathlib import Path
import sys
import torch
from torch.utils.data import DataLoader
from collections import deque
import copy

project_root = Path(r"C:\Users\ljw76\Documents\Python\PyTorch_NeuralODE")
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from Benchmarks.battery_benchmark_wrapper import DNNBenchmark, build_dnn_dataset

# Dataset (teacher forcing: k -> k+1)
dnn_dataset = build_dnn_dataset(combined_dict_training)  # 필요 시 combined_dict_training으로 교체
dnn_loader = DataLoader(dnn_dataset, batch_size=256, shuffle=True, drop_last=True)

# Model / optimizer / loss
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dnn_model = DNNBenchmark().to(device)
dnn_optimizer = torch.optim.AdamW(dnn_model.parameters(), lr=1e-3, eps=1e-8, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    dnn_optimizer,
    mode="min",
    factor=0.5,
    patience=10,
    min_lr=1e-10,
    threshold=1e-3,
    threshold_mode="rel",
)
criterion = torch.nn.MSELoss()

num_epochs = 1000
best_rmse = float("inf")
best_epoch = -1
best_lr = dnn_optimizer.param_groups[0]["lr"]
best_state_dict = None
rmse_hist = deque(maxlen=20)

for epoch in range(num_epochs):
    dnn_model.train()
    running_loss = 0.0
    voltage_sse = 0.0
    sample_count = 0
    grad_norm_before = 0.0
    grad_norm_after = 0.0

    for xb, yb, v_spme_next, v_meas_next in dnn_loader:
        xb = xb.to(device)
        yb = yb.to(device)
        v_spme_next = v_spme_next.to(device)
        v_meas_next = v_meas_next.to(device)

        preds = dnn_model(xb)
        loss = criterion(preds, yb)
        dnn_optimizer.zero_grad()
        loss.backward()

        grad_before = 0.0
        for p in dnn_model.parameters():
            if p.grad is not None:
                grad_before += p.grad.data.norm(2).item() ** 2
        grad_norm_before += grad_before ** 0.5

        torch.nn.utils.clip_grad_norm_(dnn_model.parameters(), max_norm=50.0)

        grad_after = 0.0
        for p in dnn_model.parameters():
            if p.grad is not None:
                grad_after += p.grad.data.norm(2).item() ** 2
        grad_norm_after += grad_after ** 0.5

        dnn_optimizer.step()

        running_loss += loss.item() * xb.size(0)
        voltage_sse += torch.sum((v_spme_next + preds.detach() - v_meas_next) ** 2).item()
        sample_count += xb.size(0)

    epoch_loss = running_loss / len(dnn_loader.dataset)
    epoch_rmse = (voltage_sse / sample_count) ** 0.5
    scheduler.step(epoch_loss)
    avg_grad_before = grad_norm_before / len(dnn_loader)
    avg_grad_after = grad_norm_after / len(dnn_loader)

    rmse_hist.append(epoch_rmse * 1e3)

    if epoch_rmse < best_rmse:
        best_rmse = epoch_rmse
        best_epoch = epoch + 1
        best_lr = dnn_optimizer.param_groups[0]["lr"]
        best_state_dict = copy.deepcopy(dnn_model.state_dict())
        print(f"[DNN] ✅ Best RMSE improved to {best_rmse*1e3:.2f} mV at epoch {best_epoch}")

    if len(rmse_hist) == rmse_hist.maxlen and (max(rmse_hist) - min(rmse_hist)) <= 0.005:
        print("[DNN] Window range <= 0.005 mV → early stop")
        break

    print(
        f"[DNN] epoch {epoch+1}/{num_epochs}, "
        f"loss={epoch_loss:.3e}, "
        f"RMSE={epoch_rmse*1e3:.2f} mV, "
        f"LR={dnn_optimizer.param_groups[0]['lr']:.3e}, "
        f"Grad={avg_grad_before:.3e}->{avg_grad_after:.3e}"
    )

print(f"[DNN] Best RMSE = {best_rmse*1e3:.2f} mV at epoch {best_epoch}, best LR={best_lr:.3e}")
if best_state_dict is not None:
    torch.save(best_state_dict, project_root / "Benchmarks" / "dnn_best_state_dict.pth")
    print("[DNN] Saved best state dict.")
# Out:
# [DNN] ✅ Best RMSE improved to 2.73 mV at epoch 1
# [DNN] epoch 1/3000, loss=7.428e-06, RMSE=2.73 mV, LR=1.000e-03, Grad=1.239e-03->1.239e-03
# [DNN] ✅ Best RMSE improved to 1.64 mV at epoch 2
# [DNN] epoch 2/3000, loss=2.688e-06, RMSE=1.64 mV, LR=1.000e-03, Grad=9.697e-04->9.697e-04
# [DNN] ✅ Best RMSE improved to 1.60 mV at epoch 3
# [DNN] epoch 3/3000, loss=2.571e-06, RMSE=1.60 mV, LR=1.000e-03, Grad=8.187e-04->8.187e-04
# [DNN] ✅ Best RMSE improved to 1.58 mV at epoch 4
# [DNN] epoch 4/3000, loss=2.495e-06, RMSE=1.58 mV, LR=1.000e-03, Grad=7.764e-04->7.764e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 49
#      46 grad_norm_after = 0.0
#      48 for xb, yb, v_spme_next, v_meas_next in dnn_loader:
# ---> 49     xb = xb.to(device)
#      50     yb = yb.to(device)
#      51     v_spme_next = v_spme_next.to(device)
#
# KeyboardInterrupt:
