# %% [markdown]
# ### Import Libraries

# %%
# ===== Auto Reload =====
# %load_ext autoreload
# %autoreload 2

# ===== Standard Libraries =====
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import random

# ===== PyTorch =====
import torch
import torch.nn as nn
from torchdiffeq import odeint

# torchdiffeq 버전 확인
import torchdiffeq
print(f"torchdiffeq version: {torchdiffeq.__version__}")
print("")

# ===== Check Installation =====
print("="*50)
print("Environment Check")
print("="*50)
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA device: {torch.cuda.get_device_name(0)}")
print(f"CUDA available: {torch.cuda.is_available()}")
print("="*50)
print("")


# ===== Your Custom Module =====
# Import from battery_ode_wrapper
from battery_ode_wrapper import (
    train_battery_neural_ode,
    struct_to_dataframe as struct2df,
    smooth_Vcorr,
    compute_grad_norm
)
print("="*50)
print("✓ All modules loaded!")
print("="*50)
# Out:
# torchdiffeq version: 0.2.5
#
# ==================================================
# Environment Check
# ==================================================
# PyTorch version: 2.5.1
# CUDA device: NVIDIA RTX 3500 Ada Generation Laptop GPU
# CUDA available: True
# ==================================================
#
# ==================================================
# ✓ All modules loaded!
# ==================================================

# %% [markdown]
# ### Data Import

# %%
import scipy.io
import os
import numpy as np
import re

# MATLAB 데이터 디렉토리 경로
data_dir = r"C:\Users\ljw76\Documents\MATLAB\LFP_SAFT\data\learning_data"

# ===== 온도 필터 설정 =====
target_temps = [25]  # 원하는 온도 리스트 (예: [25, 35] 또는 [] 이면 모든 온도)

# 디렉토리 내 모든 .mat 파일 목록 가져오기
mat_files = [f for f in os.listdir(data_dir) if f.endswith('.mat')]
print(f"Found {len(mat_files)} .mat files:")
for file in mat_files:
    print(f"  - {file}")

# 모든 파일 로드
print(f"\nLoading files with temperature filter: {target_temps if target_temps else 'All'}")
all_loaded_data = {}

for i, file in enumerate(mat_files):
    file_path = os.path.join(data_dir, file)
    print(f"Loading {i+1}/{len(mat_files)}: {file}")
    
    try:
        mat_data = scipy.io.loadmat(file_path)
        
        # 온도 추출 (파일명에서, 대문자 C만 찾기)
        temp_match = re.search(r'_(\d+)C_', file)
        file_temp = int(temp_match.group(1)) if temp_match else None
        
        # 온도 필터링
        if target_temps and (file_temp is None or file_temp not in target_temps):
            print(f"  ⚠ Skipped (temp: {file_temp}°C)")
            continue
        
        # 파일명에서 확장자 제거하여 키로 사용
        file_key = file.replace('.mat', '')
        
        # 메타데이터 키 제외한 실제 데이터만 저장
        data_keys = [key for key in mat_data.keys() if not key.startswith('__')]
        all_loaded_data[file_key] = {}
        
        for key in data_keys:
            all_loaded_data[file_key][key] = mat_data[key]
        
        print(f"  ✓ Loaded (temp: {file_temp}°C) - {len(data_keys)} data keys: {data_keys}")
        
    except Exception as e:
        print(f"  ✗ Failed to load {file}: {e}")

print(f"\nAll files loaded!")
print(f"Successfully loaded {len(all_loaded_data)} files:")
for file_key, data_dict in all_loaded_data.items():
    print(f"  {file_key}: {list(data_dict.keys())}")

# 첫 번째 파일의 데이터 구조 상세 확인
if all_loaded_data:
    first_file_key = list(all_loaded_data.keys())[0]
    first_data_key = list(all_loaded_data[first_file_key].keys())[0]
    sample_data = all_loaded_data[first_file_key][first_data_key]

    print(f"\nSample data structure from {first_file_key}[{first_data_key}]:")
    print(f"  Shape: {sample_data.shape}")
    print(f"  Type: {type(sample_data)}")
    if hasattr(sample_data, 'dtype'):
        print(f"  Dtype: {sample_data.dtype}")
        if hasattr(sample_data.dtype, 'names') and sample_data.dtype.names:
            print(f"  Field names: {sample_data.dtype.names}")
# Out:
# Found 10 .mat files:
#   - udds1_1c_norest_25C_struct.mat
#   - udds2_1c_norest_15C_struct.mat
#   - udds2_1c_norest_25C_struct.mat
#   - udds2_1c_norest_35C_struct.mat
#   - udds2_1c_norest_45C_struct.mat
#   - udds2_1c_rest_25C_struct.mat
#   - udds7_1c_norest_15C_struct.mat
#   - udds7_1c_norest_25C_struct.mat
#   - udds7_1c_norest_35C_struct.mat
#   - udds7_1c_norest_45C_struct.mat
#
# Loading files with temperature filter: [25]
# Loading 1/10: udds1_1c_norest_25C_struct.mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
# Loading 2/10: udds2_1c_norest_15C_struct.mat
#   ⚠ Skipped (temp: 15°C)
# Loading 3/10: udds2_1c_norest_25C_struct.mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
# Loading 4/10: udds2_1c_norest_35C_struct.mat
#   ⚠ Skipped (temp: 35°C)
# Loading 5/10: udds2_1c_norest_45C_struct.mat
#   ⚠ Skipped (temp: 45°C)
# Loading 6/10: udds2_1c_rest_25C_struct.mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
# Loading 7/10: udds7_1c_norest_15C_struct.mat
#   ⚠ Skipped (temp: 15°C)
# Loading 8/10: udds7_1c_norest_25C_struct.mat
#   ✓ Loaded (temp: 25°C) - 1 data keys: ['spme_struct']
# Loading 9/10: udds7_1c_norest_35C_struct.mat
#   ⚠ Skipped (temp: 35°C)
# Loading 10/10: udds7_1c_norest_45C_struct.mat
#   ⚠ Skipped (temp: 45°C)
#
# All files loaded!
# Successfully loaded 4 files:
#   udds1_1c_norest_25C_struct: ['spme_struct']
#   udds2_1c_norest_25C_struct: ['spme_struct']
#   udds2_1c_rest_25C_struct: ['spme_struct']
#   udds7_1c_norest_25C_struct: ['spme_struct']
#
# Sample data structure from udds1_1c_norest_25C_struct[spme_struct]:
#   Shape: (1, 1)
#   Type: <class 'numpy.ndarray'>
#   Dtype: [('time', 'O'), ('current', 'O'), ('temperature', 'O'), ('Vout', 'O'), ('Ve', 'O'), ('Vcond', 'O'), ('eta_p', 'O'), ('eta_n', 'O'), ('Un', 'O'), ('Up', 'O'), ('ocp', 'O'), ('soc_n', 'O'), ('soc_p', 'O'), ('c_s_p_surf', 'O'), ('c_s_n_surf', 'O'), ('c_s_p_bulk', 'O'), ('c_s_n_bulk', 'O'), ('i0p', 'O'), ('k_cs', 'O'), ('alpha_cs', 'O'), ('tau_cs', 'O'), ('c_s_p_surf_tilde', 'O'), ('Dsn_eff', 'O'), ('Dsp_eff', 'O'), ('Vspme', 'O'), ('Vref', 'O')]
#   Field names: ('time', 'current', 'temperature', 'Vout', 'Ve', 'Vcond', 'eta_p', 'eta_n', 'Un', 'Up', 'ocp', 'soc_n', 'soc_p', 'c_s_p_surf', 'c_s_n_surf', 'c_s_p_bulk', 'c_s_n_bulk', 'i0p', 'k_cs', 'alpha_cs', 'tau_cs', 'c_s_p_surf_tilde', 'Dsn_eff', 'Dsp_eff', 'Vspme', 'Vref')

# %% [markdown]
# ### Convert Struct to DataFrame

# %%
# ===== Key 선택 =====
target_keys = ["time", "Vref", "Vspme", "current", "temperature", "c_s_n_bulk", "soc_n"]

# ===== 모든 파일 처리 =====
extracted_data = {}  # Dictionary로 저장

print("="*60)
print("Converting all structs to DataFrames")
print("="*60)

for file_key, data_dict in all_loaded_data.items():
    print(f"\nProcessing: {file_key}")
    
    # struct 추출 (첫 번째 key)
    struct_key = list(data_dict.keys())[0]
    struct_data = data_dict[struct_key]
    
    # DataFrame 변환
    df = struct2df(struct_data, selected_keys=target_keys)

    # 저장
    extracted_data[file_key] = df
    
    print(f"  ✓ DataFrame created: {df.shape}")
    print(f"  Columns: {list(df.columns)}")

print("\n" + "="*60)
print(f"✓ Total {len(extracted_data)} DataFrames created!")
print("="*60)

# 요약
for name, df in extracted_data.items():
    print(f"  {name}: {df.shape}")
# Out:
# ============================================================
# Converting all structs to DataFrames
# ============================================================
#
# Processing: udds1_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (41150, 1)      → 41150 points
#   ✓ Vref                : shape (41150, 1)      → 41150 points
#   ✓ Vspme               : shape (41150, 1)      → 41150 points
#   ✓ current             : shape (41150, 1)      → 41150 points
#   ✓ temperature         : shape (41150, 1)      → 41150 points
#   ✓ c_s_n_bulk          : shape (41150, 1)      → 41150 points
#   ✓ soc_n               : shape (41150, 1)      → 41150 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 41150 rows × 8 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
#   ✓ DataFrame created: (41150, 8)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
# Processing: udds2_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (36681, 1)      → 36681 points
#   ✓ Vref                : shape (36681, 1)      → 36681 points
#   ✓ Vspme               : shape (36681, 1)      → 36681 points
#   ✓ current             : shape (36681, 1)      → 36681 points
#   ✓ temperature         : shape (36681, 1)      → 36681 points
#   ✓ c_s_n_bulk          : shape (36681, 1)      → 36681 points
#   ✓ soc_n               : shape (36681, 1)      → 36681 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 36681 rows × 8 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
#   ✓ DataFrame created: (36681, 8)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
# Processing: udds2_1c_rest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (265491, 1)     → 265491 points
#   ✓ Vref                : shape (265491, 1)     → 265491 points
#   ✓ Vspme               : shape (265491, 1)     → 265491 points
#   ✓ current             : shape (265491, 1)     → 265491 points
#   ✓ temperature         : shape (265491, 1)     → 265491 points
#   ✓ c_s_n_bulk          : shape (265491, 1)     → 265491 points
#   ✓ soc_n               : shape (265491, 1)     → 265491 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 265491 rows × 8 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
#   ✓ DataFrame created: (265491, 8)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
# Processing: udds7_1c_norest_25C_struct
# ============================================================
# Available keys in MATLAB struct:
# ============================================================
#    1. time
#    2. current
#    3. temperature
#    4. Vout
#    5. Ve
#    6. Vcond
#    7. eta_p
#    8. eta_n
#    9. Un
#   10. Up
#   11. ocp
#   12. soc_n
#   13. soc_p
#   14. c_s_p_surf
#   15. c_s_n_surf
#   16. c_s_p_bulk
#   17. c_s_n_bulk
#   18. i0p
#   19. k_cs
#   20. alpha_cs
#   21. tau_cs
#   22. c_s_p_surf_tilde
#   23. Dsn_eff
#   24. Dsp_eff
#   25. Vspme
#   26. Vref
# ============================================================
# Total: 26 keys
#
# Selected keys:
#   1. time ✓
#   2. Vref ✓
#   3. Vspme ✓
#   4. current ✓
#   5. temperature ✓
#   6. c_s_n_bulk ✓
#   7. soc_n ✓
#
# Extracting data:
# ------------------------------------------------------------
#   ✓ time                : shape (33596, 1)      → 33596 points
#   ✓ Vref                : shape (33596, 1)      → 33596 points
#   ✓ Vspme               : shape (33596, 1)      → 33596 points
#   ✓ current             : shape (33596, 1)      → 33596 points
#   ✓ temperature         : shape (33596, 1)      → 33596 points
#   ✓ c_s_n_bulk          : shape (33596, 1)      → 33596 points
#   ✓ soc_n               : shape (33596, 1)      → 33596 points
# ------------------------------------------------------------
#
# ✓ Vcorr added: Vcorr = Vref - Vspme
#
# ✓ DataFrame created successfully!
#   Shape: 33596 rows × 8 columns
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
#   ✓ DataFrame created: (33596, 8)
#   Columns: ['time', 'Vref', 'Vspme', 'current', 'temperature', 'c_s_n_bulk', 'soc_n', 'Vcorr']
#
# ============================================================
# ✓ Total 4 DataFrames created!
# ============================================================
#   udds1_1c_norest_25C_struct: (41150, 8)
#   udds2_1c_norest_25C_struct: (36681, 8)
#   udds2_1c_rest_25C_struct: (265491, 8)
#   udds7_1c_norest_25C_struct: (33596, 8)

# %%
import matplotlib.pyplot as plt

df = extracted_data['udds2_1c_rest_25C_struct']

fig, ax1 = plt.subplots(figsize=(12,6))

# Left y-axis: Vout (Vref) and Vspme
ax1.plot(df['time'], df['Vref'], label='Vout (Vref)', color='C0')
ax1.plot(df['time'], df['Vspme'], label='Vspme', color='C1')
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Voltage (V)')
ax1.set_ylim([2.5, 3.6])
ax1.set_title('Vout (Vref) and Vspme vs Time, with Vcorr')
ax1.grid(True)

# Right y-axis: Vcorr = Vout - Vspme
ax2 = ax1.twinx()
Vcorr = df['Vref'] - df['Vspme']
ax2.plot(df['time'], Vcorr, label='Vcorr = Vout - Vspme', color='C2')
ax2.set_ylabel('Vcorr (V)')
# Optionally, you may want to set Vcorr y-limits, e.g.:
# ax2.set_ylim([Vcorr.min(), Vcorr.max()])

# Legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assume df_sampled is already defined just as in the next cell (sampled first 10% of data)
df_vis = df

fig, axs = plt.subplots(4, 1, figsize=(14, 18), sharex=True)

# 1. csn_bulk
axs[0].plot(df_vis["time"], df_vis["c_s_n_bulk"], color="blue")
axs[0].set_ylabel("csn_bulk")
axs[0].set_title("csn_bulk vs Time")
axs[0].grid(True)

# 2. I (Current)
axs[1].plot(df_vis["time"], df_vis["current"], color="red")
axs[1].set_ylabel("Current (A)")
axs[1].set_title("Current vs Time")
axs[1].grid(True)

# 3. Temperature (T)
axs[2].plot(df_vis["time"], df_vis["temperature"], color="orange")
axs[2].set_ylabel("Temperature (°C)")
axs[2].set_title("Temperature vs Time")
axs[2].grid(True)

# 4. Vout, Vspme (left) and Vcorr (right)
ax4 = axs[3]
ax4.plot(df_vis["time"], df_vis["Vref"], label="Vout (Vref)", color="C0")
ax4.plot(df_vis["time"], df_vis["Vspme"], label="Vspme", color="C1")
ax4.set_ylabel("Voltage (V)")
ax4.set_title("Vout, Vspme, and Vcorr (Vout - Vspme) vs Time")
ax4.set_ylim([2.5, 3.6])  # Set voltage axis limits as requested
ax4.grid(True)

ax4r = ax4.twinx()
Vcorr = df_vis["Vref"] - df_vis["Vspme"]
ax4r.plot(df_vis["time"], Vcorr, label="Vcorr = Vout - Vspme", color="C2")
ax4r.set_ylabel("Vcorr (V)")

# Combine legends from both y-axes
lines1, labels1 = ax4.get_legend_handles_labels()
lines2, labels2 = ax4r.get_legend_handles_labels()
ax4.legend(lines1 + lines2, labels1 + labels2, loc="upper right")

axs[3].set_xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %%
# Import the NEW clean implementation
from battery_ode_wrapper import train_battery_neural_ode



# Use 10-20% of data for validation
# df = extracted_data['udds2_1c_rest_25C_struct']
df = extracted_data['udds2_1c_norest_25C_struct']
total_length = len(df)
# start_idx = int(0.43 * total_length)  # Rest
# end_idx = int(0.47 * total_length)    # Rest
start_idx = int(0.4 * total_length)  # pulse 1
end_idx = int(0.45 * total_length)    # pulse 1
# start_idx = int(0.55 * total_length)  # pulse 2
# end_idx = int(0.65 * total_length)    # pulse 2
df_sampled = df.iloc[start_idx:end_idx].reset_index(drop=True)

df_sorted = df_sampled.sort_values('time').reset_index(drop=True)




# =============================
# ===== Remove Duplicates =====
# =============================
print("\n==== [diff 기반 수동 중복 제거] ====")

# 원본 데이터
df_original = df_sorted.copy()
time_float = df_original['time'].astype(np.float32).values
diff = np.diff(time_float)

# 문제 인덱스 찾기
problem_idx = np.where(diff <= 0)[0]
print(f"감지된 문제 인덱스: {len(problem_idx)}개")

# 각 문제를 분석하고 제거할 인덱스 결정
indices_to_remove = []
for idx in problem_idx:
    t0 = time_float[idx]
    t1 = time_float[idx+1]
    diff_val = t1 - t0
    
    if abs(diff_val) < 1e-10:  # 중복
        print(f"  중복 발견: idx={idx} (t={t0}) --> idx={idx+1} (t={t1})")
        indices_to_remove.append(idx + 1)  # 두 번째 인덱스 제거
    else:  # 내림차순
        print(f"  내림차순 발견: idx={idx} (t={t0}) --> idx={idx+1} (t={t1})")
        indices_to_remove.append(idx + 1)  # 두 번째 인덱스 제거

# 중복 제거
indices_to_remove = sorted(set(indices_to_remove))  # 중복 제거 및 정렬
print(f"\n제거할 인덱스: {indices_to_remove}")

# 실제 제거
df_clean_manual = df_original.drop(index=indices_to_remove).reset_index(drop=True)

print(f"원본 데이터: {len(df_original)}개")
print(f"제거 후 데이터: {len(df_clean_manual)}개")
print(f"제거된 데이터: {len(df_original) - len(df_clean_manual)}개")

# 검증
time_clean = df_clean_manual['time'].astype(np.float32).values
diff_clean = np.diff(time_clean)
problem_idx_clean = np.where(diff_clean <= 0)[0]

if len(problem_idx_clean) == 0:
    print("✓ 모든 중복이 제거되었습니다!")
    print("✓ 시간이 strictly increasing입니다.")
else:
    print(f"⚠ 아직 {len(problem_idx_clean)}개의 문제가 남아있습니다.")
    for idx in problem_idx_clean:
        t0 = time_clean[idx]
        t1 = time_clean[idx+1]
        diff_val = t1 - t0
        print(f"  idx={idx}: t={t0} --> idx={idx+1}: t={t1} (diff={diff_val:.8f})")

# 최종 데이터로 설정
df_clean = df_clean_manual
print(f"\n✓ 최종 선택: diff 기반 수동 제거 방법 사용")

# 최종 검증
time_clean = df_clean['time'].astype(np.float32).values
diff_clean = np.diff(time_clean)
problem_idx_clean = np.where(diff_clean <= 0)[0]

if len(problem_idx_clean) == 0:
    print("✓ 최종 데이터에서 모든 time이 strictly increasing입니다.")
else:
    print(f"⚠ 최종 데이터에서도 {len(problem_idx_clean)}개의 문제가 남아있습니다.")
    for idx in problem_idx_clean:
        t0 = time_clean[idx]
        t1 = time_clean[idx+1]
        diff_ = t1-t0
        print(f"  idx={idx}: t={t0} --> idx+1={idx+1}: t={t1} (diff={diff_:.8f})")

# 중복 제거된 데이터로 모든 변수 업데이트
print("\n==== [데이터 업데이트] ====")
df_sorted = df_clean  # 중복 제거된 데이터로 교체
# =============================
# ===== Remove Duplicates =====
# =============================





# # ========================
# # ===== Downsampling =====
# # ========================
# print("\n==== [Downsampling] ====")

# downsample_interval = 10  # N초마다 sampling

# time = df_sorted['time'].values
# selected = [0]  # 첫 point

# for i in range(len(time) - 1):
#     if time[i] >= time[selected[-1]] + downsample_interval:
#         selected.append(i)

# if selected[-1] != len(time) - 1:
#     selected.append(len(time) - 1)

# df_sorted = df_sorted.iloc[selected].reset_index(drop=True)
# print(f"원본 {len(time)} → 다운샘플링 {len(df_sorted)} points ({len(df_sorted)/len(time)*100:.1f}%)")
# # ========================
# # ===== Downsampling =====
# # ========================





# =========================
# ======= Smoothing =======
# =========================
Y_raw = df_sorted['Vref'].values - df_sorted['Vspme'].values
Y = smooth_Vcorr(Y_raw, 100)


Y = Y_raw
# =========================
# ======= Smoothing =======
# =========================



Ymean = Y.mean()
Ystd = Y.std()

Vspme_mean = df_sorted['Vspme'].mean()
Vspme_std = df_sorted['Vspme'].std()


# data_dict 업데이트
data_dict = {
    'time': df_sorted['time'].astype(np.float32),
    'SOC': df_sorted['soc_n'].astype(np.float32),
    'csn_bulk': df_sorted['c_s_n_bulk'].astype(np.float32)/30555, # normalize by max csn_bulk
    'I': df_sorted['current'].astype(np.float32)/0.25, 
    'T': (df_sorted['temperature'].astype(np.float32) - 298.15) / 10,
    # 'X': X,
    'Y': (Y -Ymean) / Ystd,
    'Y_mean': Ymean,
    'Y_std': Ystd,
    'V_spme': ( df_sorted['Vspme'].astype(np.float32) - Vspme_mean) / Vspme_std,
    'V_spme_mean': Vspme_mean,
    'V_spme_std': Vspme_std,
    'V_meas': df_sorted['Vref'].astype(np.float32)
}

print(Ymean)
print(Ystd)

print(f"✓ 업데이트된 데이터:")
print(f"  - 데이터 포인트 수: {len(df_sorted)}")
print(f"  - 시간 범위: {df_sorted['time'].min():.2f} - {df_sorted['time'].max():.2f} 초")
print(f"  - Vcorr 범위: {Y.min():.3f} - {Y.max():.3f} V")
print(f"  - Y shape: {Y.shape}")
print(f"  - Y mean: {Ymean:.3f}")
print(f"  - Y std: {Ystd:.3f}")


df_sorted['current'].astype(np.float32).std()




plt.figure()
plt.plot(df_sorted['Vref'].values, label='Vref')
plt.plot(df_sorted['Vspme'].values, label='Vspme')
plt.legend()
plt.show()
# Out:
# ==== [diff 기반 수동 중복 제거] ====
# 감지된 문제 인덱스: 2개
#   중복 발견: idx=728 (t=20880.302734375) --> idx=729 (t=20880.302734375)
#   중복 발견: idx=2470 (t=22620.326171875) --> idx=2471 (t=22620.326171875)
#
# 제거할 인덱스: [np.int64(729), np.int64(2471)]
# 원본 데이터: 3668개
# 제거 후 데이터: 3666개
# 제거된 데이터: 2개
# ✓ 모든 중복이 제거되었습니다!
# ✓ 시간이 strictly increasing입니다.
#
# ✓ 최종 선택: diff 기반 수동 제거 방법 사용
# ✓ 최종 데이터에서 모든 time이 strictly increasing입니다.
#
# ==== [데이터 업데이트] ====
# Warning: window_size must be odd. Using 101 instead.
# -0.013982862834035555
# 0.003708464415417279
# ✓ 업데이트된 데이터:
#   - 데이터 포인트 수: 3666
#   - 시간 범위: 20152.30 - 23815.35 초
#   - Vcorr 범위: -0.025 - -0.007 V
#   - Y shape: (3666,)
#   - Y mean: -0.014
#   - Y std: 0.004

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots


# Create subplots with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Raw Vcorr
fig.add_trace(
    go.Scatter(
        x=data_dict["time"],
        y=Y_raw,
        mode='lines',
        name='Vcorr_raw',
        line=dict(color='red', width=1),
        opacity=0.7
    ),
    secondary_y=False
)

# Smooth Vcorr
fig.add_trace(
    go.Scatter(
        x=data_dict["time"],
        y=Y,
        mode='lines',
        name='Vcorr_smooth',
        line=dict(color='blue', width=2),
        opacity=0.7
    ),
    secondary_y=False
)

# Current on secondary y-axis
fig.add_trace(
    go.Scatter(
        x=data_dict["time"],
        y=data_dict["I"] * 0.25,  # De-normalize if needed
        mode='lines',
        name='Current',
        line=dict(color='gray', width=1.5, dash='dash'),
        opacity=0.5
    ),
    secondary_y=True
)

# Update layout
fig.update_xaxes(title_text='Time (s)')
fig.update_yaxes(title_text='Vcorr (V)', secondary_y=False)
fig.update_yaxes(title_text='Current (A)', secondary_y=True)

fig.update_layout(
    title='Vcorr_smooth vs Vcorr_raw with Current',
    hovermode='x unified',
    width=1000,
    height=500
)

fig.show()


# ===== Diff plot with current =====
fig2 = make_subplots(specs=[[{"secondary_y": True}]])

# dVcorr/dt
time_diff = data_dict["time"][1:]  # time for diff
fig2.add_trace(
    go.Scatter(
        x=time_diff,
        y=np.diff(Y),
        mode='lines',
        name='dVcorr/dt',
        line=dict(color='blue', width=1),
    ),
    secondary_y=False
)

# Current on secondary y-axis
fig2.add_trace(
    go.Scatter(
        x=data_dict["time"],
        y=data_dict["I"] * 0.25,  # De-normalize if needed
        mode='lines',
        name='Current',
        line=dict(color='gray', width=1.5, dash='dash'),
        opacity=0.5
    ),
    secondary_y=True
)

# Update layout
fig2.update_xaxes(title_text='Time (s)')
fig2.update_yaxes(title_text='dVcorr/dt (V/s)', secondary_y=False)
fig2.update_yaxes(title_text='Current (A)', secondary_y=True)

fig2.update_layout(
    title='dVcorr/dt with Current',
    hovermode='x unified',
    width=1000,
    height=500
)

fig2.show()




plt.figure()
plt.plot(np.diff(Y))

# %%
print(data_dict["csn_bulk"].mean())  
print(data_dict["I"][data_dict["I"]>0].mean())  
print(data_dict["I"][data_dict["I"]<0].mean())
print(data_dict["T"].mean())  

print(data_dict["V_spme"])

print(f"Vspme raw range: {df_sorted['Vspme'].min():.3f} ~ {df_sorted['Vspme'].max():.3f}")
print(f"Vspme mean: {df_sorted['Vspme'].mean():.6f}")
print(f"Vspme std: {df_sorted['Vspme'].std():.6f}")

print(f"Vcorr raw range: {Y.min():.3f} ~ {Y.max():.3f}")
print(f"Vcorr mean: {Ymean:.6f}")
print(f"Vcorr std: {Ystd:.6f}")
# Out:
# 0.33547628
# 0.7616219
# -0.56762457
# 0.05082546
# 0       1.073037
# 1       0.459972
# 2       0.222718
# 3       0.204838
# 4       0.404316
#           ...
# 3661   -0.951099
# 3662   -0.947630
# 3663   -0.947630
# 3664   -0.947504
# 3665   -0.944035
# Name: Vspme, Length: 3666, dtype: float32
# Vspme raw range: 3.250 ~ 3.297
# Vspme mean: 3.279165
# Vspme std: 0.007561
# Vcorr raw range: -0.025 ~ -0.007
# Vcorr mean: -0.013983
# Vcorr std: 0.003708

# %%
# # Load pretrained model
# import torch
# from battery_ode_wrapper import BatteryODEWrapper

# device = 'cuda'  # or 'cpu'

# # Checkpoint 형식인지 확인하고 적절히 로드
# saved_data = torch.load("best_model_rmse0.64mV.pth", map_location=device)

# # Checkpoint 형식 (새 형식)인지 확인
# if isinstance(saved_data, dict) and 'model_state_dict' in saved_data:
#     # Checkpoint 형식: model_state_dict 추출
#     saved_state = saved_data['model_state_dict']
#     training_info = saved_data.get('training_info', {})
    
#     # 학습 정보 출력 (선택사항)
#     if training_info:
#         print(f"Previous training info:")
#         print(f"  - Best RMSE: {training_info.get('best_rmse', 'N/A'):.2f}mV")
#         print(f"  - Best epoch: {training_info.get('best_epoch', 'N/A')}")
#         print(f"  - alpha={training_info.get('alpha', 'N/A')}, "
#               f"beta={training_info.get('beta', 'N/A')}, "
#               f"gamma={training_info.get('gamma', 'N/A')}")
# else:
#     # Legacy 형식: 그냥 state_dict
#     saved_state = saved_data

# # 모델에 로드
# ode_wrapper_new.load_state_dict(saved_state)

# %%
# Call training function
device = 'cuda' if torch.cuda.is_available() else 'cpu'

num_epochs = 1000  # Increased from 100 to 300
# lr = 5e-4  # Rest
lr = 5e-4  # Pulse


seed = 42 # 42 : Vcorr_k, csn_k, I_k, T_k,
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.deterministic = True


ode_wrapper, history = train_battery_neural_ode(data_dict, num_epochs=num_epochs, lr=lr, device=device, verbose=True)
# Out:
# ==================================================
# Neural Network Architecture
# ==================================================
# Sequential(
#   (0): Linear(in_features=4, out_features=32, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=32, out_features=32, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=32, out_features=32, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=32, out_features=16, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=16, out_features=1, bias=True)
# )
# ==================================================
#
# ==================================================
# Training Settings
# ==================================================
# data_dict keys: dict_keys(['time', 'csn_bulk', 'I', 'T', 'Y', 'Y_mean', 'Y_std', 'V_spme', 'V_spme_mean', 'V_spme_std', 'V_meas'])
# max epochs: 1000
# initial lr: 0.0005
# device: cuda
# patience: 10
# alpha: 1.00
# beta: 0.00
# gamma: 0.00
# GPU: 71MB
# grad_clip_max: 50
# verbose: True
# ==================================================
# Starting battery Neural ODE training...
# Data points: 7334
# Vcorr range (normalized): -3.094 ~ 1.822
# ✅ Best RMSE: 1039.92mV at Epoch 1
# Epoch   1/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 1039.92mV | loss_V: 61337.48 | loss_dVdt: 7.83e-02 | loss_tv: 6.06e-02 | Steps: 7333 | Grad Norm before: 5503266.7331 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 557.92mV at Epoch 2
# Epoch   2/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 557.92mV | loss_V: 17655.05 | loss_dVdt: 7.60e-02 | loss_tv: 3.54e-02 | Steps: 7333 | Grad Norm before: 2023418.9422 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 485.18mV at Epoch 3
# Epoch   3/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 485.18mV | loss_V: 13351.79 | loss_dVdt: 7.53e-02 | loss_tv: 2.95e-02 | Steps: 7333 | Grad Norm before: 1798305.3869 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 169.49mV at Epoch 4
# Epoch   4/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 169.49mV | loss_V: 1629.33 | loss_dVdt: 7.46e-02 | loss_tv: 1.20e-02 | Steps: 7333 | Grad Norm before: 462410.1211 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 6.68mV at Epoch 5
# Epoch   5/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 6.68mV | loss_V: 2.53 | loss_dVdt: 7.47e-02 | loss_tv: 3.05e-03 | Steps: 7333 | Grad Norm before: 11511.0022 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 4.58mV at Epoch 6
# Epoch   6/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.58mV | loss_V: 1.19 | loss_dVdt: 7.47e-02 | loss_tv: 3.02e-03 | Steps: 7333 | Grad Norm before: 3918.9818 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 4.33mV at Epoch 7
# Epoch   7/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.33mV | loss_V: 1.06 | loss_dVdt: 7.47e-02 | loss_tv: 3.08e-03 | Steps: 7333 | Grad Norm before: 344.1415 | Grad Norm after: 50.0000 |
# Epoch   8/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.56mV | loss_V: 1.18 | loss_dVdt: 7.48e-02 | loss_tv: 3.23e-03 | Steps: 7333 | Grad Norm before: 2101.0929 | Grad Norm after: 50.0000 |
# Epoch   9/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.67mV | loss_V: 1.24 | loss_dVdt: 7.48e-02 | loss_tv: 3.26e-03 | Steps: 7333 | Grad Norm before: 2743.0367 | Grad Norm after: 50.0000 |
# Epoch  10/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.63mV | loss_V: 1.22 | loss_dVdt: 7.48e-02 | loss_tv: 3.20e-03 | Steps: 7333 | Grad Norm before: 2556.9567 | Grad Norm after: 50.0000 |
# Epoch  11/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.53mV | loss_V: 1.16 | loss_dVdt: 7.48e-02 | loss_tv: 3.06e-03 | Steps: 7333 | Grad Norm before: 1955.3503 | Grad Norm after: 50.0000 |
# Epoch  12/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.42mV | loss_V: 1.11 | loss_dVdt: 7.47e-02 | loss_tv: 2.87e-03 | Steps: 7333 | Grad Norm before: 1136.7833 | Grad Norm after: 50.0000 |
# Epoch  13/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.33mV | loss_V: 1.06 | loss_dVdt: 7.47e-02 | loss_tv: 2.62e-03 | Steps: 7333 | Grad Norm before: 202.0206 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 4.29mV at Epoch 14
# Epoch  14/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.29mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.32e-03 | Steps: 7333 | Grad Norm before: 804.8668 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 4.29mV at Epoch 15
# Epoch  15/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.29mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.12e-03 | Steps: 7333 | Grad Norm before: 1312.2737 | Grad Norm after: 50.0000 |
# Epoch  16/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.29mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.03e-03 | Steps: 7333 | Grad Norm before: 1462.9912 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 4.28mV at Epoch 17
# Epoch  17/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.28mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.02e-03 | Steps: 7333 | Grad Norm before: 1352.1418 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 4.28mV at Epoch 18
# Epoch  18/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.28mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.08e-03 | Steps: 7333 | Grad Norm before: 1045.7003 | Grad Norm after: 50.0000 |
# Epoch  19/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.28mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.21e-03 | Steps: 7333 | Grad Norm before: 590.4569 | Grad Norm after: 50.0000 |
# Epoch  20/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.31mV | loss_V: 1.05 | loss_dVdt: 7.47e-02 | loss_tv: 2.40e-03 | Steps: 7333 | Grad Norm before: 20.6629 | Grad Norm after: 20.6629 |
# Epoch  21/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.35mV | loss_V: 1.07 | loss_dVdt: 7.47e-02 | loss_tv: 2.58e-03 | Steps: 7333 | Grad Norm before: 505.5517 | Grad Norm after: 50.0000 |
# Epoch  22/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.37mV | loss_V: 1.08 | loss_dVdt: 7.47e-02 | loss_tv: 2.68e-03 | Steps: 7333 | Grad Norm before: 755.2988 | Grad Norm after: 50.0000 |
# Epoch  23/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.37mV | loss_V: 1.08 | loss_dVdt: 7.48e-02 | loss_tv: 2.69e-03 | Steps: 7333 | Grad Norm before: 781.0367 | Grad Norm after: 50.0000 |
# Epoch  24/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.36mV | loss_V: 1.08 | loss_dVdt: 7.47e-02 | loss_tv: 2.62e-03 | Steps: 7333 | Grad Norm before: 623.9053 | Grad Norm after: 50.0000 |
# Epoch  25/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.33mV | loss_V: 1.06 | loss_dVdt: 7.47e-02 | loss_tv: 2.49e-03 | Steps: 7333 | Grad Norm before: 317.3091 | Grad Norm after: 50.0000 |
# Epoch  26/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.30mV | loss_V: 1.05 | loss_dVdt: 7.47e-02 | loss_tv: 2.30e-03 | Steps: 7333 | Grad Norm before: 113.3498 | Grad Norm after: 50.0000 |
# Epoch  27/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.29mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.20e-03 | Steps: 7333 | Grad Norm before: 341.1430 | Grad Norm after: 50.0000 |
# Epoch  28/1000 | Method: euler  | LR: 5.00e-04 | RMSE: 4.28mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.18e-03 | Steps: 7333 | Grad Norm before: 388.8387 | Grad Norm after: 50.0000 |
# Epoch  29/1000 | Method: euler  | LR: 2.50e-04 | RMSE: 4.29mV | loss_V: 1.04 | loss_dVdt: 7.47e-02 | loss_tv: 2.23e-03 | Steps: 7333 | Grad Norm before: 283.1121 | Grad Norm after: 50.0000 |
# Epoch  30/1000 | Method: euler  | LR: 2.50e-04 | RMSE: 4.30mV | loss_V: 1.05 | loss_dVdt: 7.47e-02 | loss_tv: 2.35e-03 | Steps: 7333 | Grad Norm before: 47.5645 | Grad Norm after: 47.5645 |
# Epoch  31/1000 | Method: euler  | LR: 2.50e-04 | RMSE: 4.31mV | loss_V: 1.05 | loss_dVdt: 7.47e-02 | loss_tv: 2.44e-03 | Steps: 7333 | Grad Norm before: 110.7273 | Grad Norm after: 50.0000 |
# Epoch  32/1000 | Method: euler  | LR: 2.50e-04 | RMSE: 4.32mV | loss_V: 1.06 | loss_dVdt: 7.47e-02 | loss_tv: 2.47e-03 | Steps: 7333 | Grad Norm before: 169.8499 | Grad Norm after: 50.0000 |
# Epoch  33/1000 | Method: euler  | LR: 2.50e-04 | RMSE: 4.31mV | loss_V: 1.06 | loss_dVdt: 7.47e-02 | loss_tv: 2.46e-03 | Steps: 7333 | Grad Norm before: 144.8359 | Grad Norm after: 50.0000 |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 17
#      13 random.seed(seed)
#      14 torch.backends.cudnn.deterministic = True
# ---> 17 ode_wrapper, history = train_battery_neural_ode(data_dict, num_epochs=num_epochs, lr=lr, device=device, verbose=True)
#
# File c:\Users\ljw76\Documents\Python\PyTorch_NeuralODE\battery_ode_wrapper.py:85, in train_battery_neural_ode(data_dict, num_epochs, lr, device, verbose, pretrained_model_path)
#      75     time_data = inputs_dict['time']
#      77     self.inputs_interp = {
#      78         'I': interp1d(time_data, inputs_dict['I'], kind='linear', fill_value='extrapolate'),
#      79         'T': interp1d(time_data, inputs_dict['T'], kind='linear', fill_value='extrapolate'),
#      80         'csn_bulk': interp1d(time_data, inputs_dict['csn_bulk'], kind='linear', fill_value='extrapolate'),
#      81         'V_spme': interp1d(time_data, inputs_dict['V_spme'], kind='linear', fill_value='extrapolate'),
#      82     }
#      84     # # Reset prev_Vcorr when inputs change
# ---> 85     # self.prev_Vcorr = None
#      87 def forward(self, t, x):
#      88     """
#      89     ODE function called by odeint - mirrors MATLAB ode_wrapper_poly
#      90
#    (...)     99         dxdt: derivative [dVcorr/dt] (1x1 tensor)
#     100     """
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torchdiffeq\_impl\odeint.py:80, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      77 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      79 if event_fn is None:
# ---> 80     solution = solver.integrate(t)
#      81 else:
#      82     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torchdiffeq\_impl\solvers.py:114, in FixedGridODESolver.integrate(self, t)
#     112 dt = t1 - t0
#     113 self.func.callback_step(t0, y0, dt)
# --> 114 dy, f0 = self._step_func(self.func, t0, dt, t1, y0)
#     115 y1 = y0 + dy
#     117 while j < len(t) and t1 >= t[j]:
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torchdiffeq\_impl\fixed_grid.py:10, in Euler._step_func(self, func, t0, dt, t1, y0)
#       9 def _step_func(self, func, t0, dt, t1, y0):
# ---> 10     f0 = func(t0, y0, perturb=Perturb.NEXT if self.perturb else Perturb.NONE)
#      11     return dt * f0, f0
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torchdiffeq\_impl\misc.py:197, in _PerturbFunc.forward(self, t, y, perturb)
#     194 else:
#     195     # Do nothing.
#     196     pass
# --> 197 return self.base_func(t, y)
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ljw76\anaconda3\envs\PyTorch_NeuralODE\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\ljw76\Documents\Python\PyTorch_NeuralODE\battery_ode_wrapper.py:121, in BatteryODEWrapper.forward(self, t, x)
#     118 Vspme_k = float(self.inputs_interp['V_spme'](t_val))   # Vspme(k)
#     120 # Neural Network Input: X = [Vcorr(k), csn_bulk(k), I(k), T(k)]
# --> 121 nn_input = torch.tensor([[Vcorr_k, csn_k, I_k, T_k]], dtype=torch.float32, device=self.device)
#     123 # Neural Network Output: dVcorr/dt(k)
#     124 dVcorr_dt_k = self.net(nn_input)
#
# KeyboardInterrupt:

# %%
# Load pretrained model
import torch
from battery_ode_wrapper import BatteryODEWrapper


# Call training function
device = 'cuda' if torch.cuda.is_available() else 'cpu'

num_epochs = 500  # Increased from 100 to 300
lr = 5e-4  # continue training


# 1. 먼저 모델 로드 (위에서 설명한 방법)
saved_data = torch.load("best_model_rmse2.30mV_0.5gain_rk4.pth", map_location=device)
saved_state = saved_data['model_state_dict'] if isinstance(saved_data, dict) and 'model_state_dict' in saved_data else saved_data

ode_wrapper_new = BatteryODEWrapper(device).to(device)
ode_wrapper_new.load_state_dict(saved_state)

# 2. 모델을 파일로 다시 저장 (임시로)
temp_model_path = "best_model_rmse2.30mV_0.5gain_rk4.pth"
torch.save(saved_state, temp_model_path)  # state_dict만 저장

# 3. train_battery_neural_ode 호출 (pretrained_model_path 사용)
ode_wrapper, history = train_battery_neural_ode(
    data_dict, 
    num_epochs=num_epochs, 
    lr=lr, 
    device=device, 
    verbose=True,
    pretrained_model_path=temp_model_path  # ← 이렇게 사용
)
# Out:
# C:\Users\ljw76\AppData\Local\Temp\ipykernel_49860\2616457910.py:14: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# 🔄 Loading pretrained model from: best_model_rmse2.30mV_0.5gain_rk4.pth
# ✅ Pretrained model loaded successfully! (legacy format)
#
# ==================================================
# Neural Network Architecture
# ==================================================
# Sequential(
#   (0): Linear(in_features=4, out_features=32, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=32, out_features=32, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=32, out_features=32, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=32, out_features=16, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=16, out_features=1, bias=True)
# )
# ==================================================
#
# ==================================================
# Training Settings
# ==================================================
# data_dict keys: dict_keys(['time', 'csn_bulk', 'I', 'T', 'Y', 'Y_mean', 'Y_std', 'V_spme', 'V_spme_mean', 'V_spme_std', 'V_meas'])
# max epochs: 500
# initial lr: 0.0005
# device: cuda
# patience: 10
# alpha: 1.00
# beta: 0.00
# gamma: 0.00
# GPU: 76MB
# grad_clip_max: 50
# verbose: True
# ==================================================
# Starting battery Neural ODE training...
# Data points: 7334
# Vcorr range (normalized): -3.094 ~ 1.822
# ✅ Best RMSE: 2.60mV at Epoch 1
# Epoch   1/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.60mV | loss_V: 0.38 | loss_dVdt: 7.41e-02 | loss_tv: 7.45e-02 | Steps: 7333 | Grad Norm before: 2684.0367 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 2.54mV at Epoch 2
# Epoch   2/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.54mV | loss_V: 0.37 | loss_dVdt: 7.37e-02 | loss_tv: 7.18e-02 | Steps: 7333 | Grad Norm before: 1094.0090 | Grad Norm after: 50.0000 |
# Epoch   3/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.68mV | loss_V: 0.41 | loss_dVdt: 7.34e-02 | loss_tv: 6.91e-02 | Steps: 7333 | Grad Norm before: 411.8816 | Grad Norm after: 50.0000 |
# Epoch   4/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.70mV | loss_V: 0.41 | loss_dVdt: 7.32e-02 | loss_tv: 6.79e-02 | Steps: 7333 | Grad Norm before: 705.7853 | Grad Norm after: 50.0000 |
# Epoch   5/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.30e-02 | loss_tv: 6.75e-02 | Steps: 7333 | Grad Norm before: 492.1834 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 2.53mV at Epoch 6
# Epoch   6/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.53mV | loss_V: 0.36 | loss_dVdt: 7.29e-02 | loss_tv: 6.74e-02 | Steps: 7333 | Grad Norm before: 43.8596 | Grad Norm after: 43.8596 |
# ✅ Best RMSE: 2.45mV at Epoch 7
# Epoch   7/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.45mV | loss_V: 0.34 | loss_dVdt: 7.28e-02 | loss_tv: 6.74e-02 | Steps: 7333 | Grad Norm before: 485.7031 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 2.42mV at Epoch 8
# Epoch   8/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.42mV | loss_V: 0.33 | loss_dVdt: 7.27e-02 | loss_tv: 6.70e-02 | Steps: 7333 | Grad Norm before: 667.6537 | Grad Norm after: 50.0000 |
# ✅ Best RMSE: 2.41mV at Epoch 9
# Epoch   9/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.41mV | loss_V: 0.33 | loss_dVdt: 7.26e-02 | loss_tv: 6.62e-02 | Steps: 7333 | Grad Norm before: 627.3450 | Grad Norm after: 50.0000 |
# Epoch  10/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.41mV | loss_V: 0.33 | loss_dVdt: 7.24e-02 | loss_tv: 6.53e-02 | Steps: 7333 | Grad Norm before: 433.5195 | Grad Norm after: 50.0000 |
# Epoch  11/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.44mV | loss_V: 0.34 | loss_dVdt: 7.23e-02 | loss_tv: 6.41e-02 | Steps: 7333 | Grad Norm before: 132.1511 | Grad Norm after: 50.0000 |
# Epoch  12/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.49mV | loss_V: 0.35 | loss_dVdt: 7.21e-02 | loss_tv: 6.28e-02 | Steps: 7333 | Grad Norm before: 239.2458 | Grad Norm after: 50.0000 |
# Epoch  13/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.51mV | loss_V: 0.36 | loss_dVdt: 7.20e-02 | loss_tv: 6.18e-02 | Steps: 7333 | Grad Norm before: 397.2991 | Grad Norm after: 50.0000 |
# Epoch  14/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.51mV | loss_V: 0.36 | loss_dVdt: 7.19e-02 | loss_tv: 6.11e-02 | Steps: 7333 | Grad Norm before: 396.2997 | Grad Norm after: 50.0000 |
# Epoch  15/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.49mV | loss_V: 0.35 | loss_dVdt: 7.18e-02 | loss_tv: 6.07e-02 | Steps: 7333 | Grad Norm before: 272.3455 | Grad Norm after: 50.0000 |
# Epoch  16/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.46mV | loss_V: 0.34 | loss_dVdt: 7.18e-02 | loss_tv: 6.05e-02 | Steps: 7333 | Grad Norm before: 54.9005 | Grad Norm after: 50.0000 |
# Epoch  17/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.42mV | loss_V: 0.33 | loss_dVdt: 7.17e-02 | loss_tv: 6.03e-02 | Steps: 7333 | Grad Norm before: 246.2362 | Grad Norm after: 50.0000 |
# Epoch  18/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.41mV | loss_V: 0.33 | loss_dVdt: 7.16e-02 | loss_tv: 6.00e-02 | Steps: 7333 | Grad Norm before: 401.0366 | Grad Norm after: 50.0000 |
# Epoch  19/500 | Method: euler  | LR: 5.00e-04 | RMSE: 2.41mV | loss_V: 0.33 | loss_dVdt: 7.16e-02 | loss_tv: 5.94e-02 | Steps: 7333 | Grad Norm before: 440.1742 | Grad Norm after: 50.0000 |
# Epoch  20/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.42mV | loss_V: 0.33 | loss_dVdt: 7.15e-02 | loss_tv: 5.87e-02 | Steps: 7333 | Grad Norm before: 384.9728 | Grad Norm after: 50.0000 |
# Epoch  21/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.44mV | loss_V: 0.34 | loss_dVdt: 7.14e-02 | loss_tv: 5.79e-02 | Steps: 7333 | Grad Norm before: 252.7612 | Grad Norm after: 50.0000 |
# Epoch  22/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.46mV | loss_V: 0.34 | loss_dVdt: 7.13e-02 | loss_tv: 5.74e-02 | Steps: 7333 | Grad Norm before: 154.9976 | Grad Norm after: 50.0000 |
# Epoch  23/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.48mV | loss_V: 0.35 | loss_dVdt: 7.13e-02 | loss_tv: 5.68e-02 | Steps: 7333 | Grad Norm before: 34.2051 | Grad Norm after: 34.2051 |
# Epoch  24/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.51mV | loss_V: 0.36 | loss_dVdt: 7.12e-02 | loss_tv: 5.62e-02 | Steps: 7333 | Grad Norm before: 94.5125 | Grad Norm after: 50.0000 |
# Epoch  25/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.52mV | loss_V: 0.36 | loss_dVdt: 7.12e-02 | loss_tv: 5.57e-02 | Steps: 7333 | Grad Norm before: 154.6836 | Grad Norm after: 50.0000 |
# Epoch  26/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.53mV | loss_V: 0.36 | loss_dVdt: 7.12e-02 | loss_tv: 5.54e-02 | Steps: 7333 | Grad Norm before: 163.7600 | Grad Norm after: 50.0000 |
# Epoch  27/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.53mV | loss_V: 0.36 | loss_dVdt: 7.11e-02 | loss_tv: 5.52e-02 | Steps: 7333 | Grad Norm before: 129.0487 | Grad Norm after: 50.0000 |
# Epoch  28/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.52mV | loss_V: 0.36 | loss_dVdt: 7.11e-02 | loss_tv: 5.50e-02 | Steps: 7333 | Grad Norm before: 57.1838 | Grad Norm after: 50.0000 |
# Epoch  29/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.51mV | loss_V: 0.36 | loss_dVdt: 7.11e-02 | loss_tv: 5.49e-02 | Steps: 7333 | Grad Norm before: 54.4742 | Grad Norm after: 50.0000 |
# Epoch  30/500 | Method: euler  | LR: 2.50e-04 | RMSE: 2.51mV | loss_V: 0.36 | loss_dVdt: 7.10e-02 | loss_tv: 5.47e-02 | Steps: 7333 | Grad Norm before: 120.8469 | Grad Norm after: 50.0000 |
# Epoch  31/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.52mV | loss_V: 0.36 | loss_dVdt: 7.10e-02 | loss_tv: 5.44e-02 | Steps: 7333 | Grad Norm before: 147.9111 | Grad Norm after: 50.0000 |
# Epoch  32/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.53mV | loss_V: 0.36 | loss_dVdt: 7.10e-02 | loss_tv: 5.40e-02 | Steps: 7333 | Grad Norm before: 139.2765 | Grad Norm after: 50.0000 |
# Epoch  33/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.53mV | loss_V: 0.36 | loss_dVdt: 7.09e-02 | loss_tv: 5.38e-02 | Steps: 7333 | Grad Norm before: 119.4802 | Grad Norm after: 50.0000 |
# Epoch  34/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.54mV | loss_V: 0.37 | loss_dVdt: 7.09e-02 | loss_tv: 5.35e-02 | Steps: 7333 | Grad Norm before: 86.4621 | Grad Norm after: 50.0000 |
# Epoch  35/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.55mV | loss_V: 0.37 | loss_dVdt: 7.09e-02 | loss_tv: 5.32e-02 | Steps: 7333 | Grad Norm before: 43.4164 | Grad Norm after: 43.4164 |
# Epoch  36/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.56mV | loss_V: 0.37 | loss_dVdt: 7.09e-02 | loss_tv: 5.29e-02 | Steps: 7333 | Grad Norm before: 16.4706 | Grad Norm after: 16.4706 |
# Epoch  37/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.57mV | loss_V: 0.38 | loss_dVdt: 7.09e-02 | loss_tv: 5.26e-02 | Steps: 7333 | Grad Norm before: 47.1852 | Grad Norm after: 47.1852 |
# Epoch  38/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.58mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.24e-02 | Steps: 7333 | Grad Norm before: 59.5778 | Grad Norm after: 50.0000 |
# Epoch  39/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.58mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.22e-02 | Steps: 7333 | Grad Norm before: 51.1163 | Grad Norm after: 50.0000 |
# Epoch  40/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.58mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.21e-02 | Steps: 7333 | Grad Norm before: 25.5270 | Grad Norm after: 25.5270 |
# Epoch  41/500 | Method: euler  | LR: 1.25e-04 | RMSE: 2.59mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.19e-02 | Steps: 7333 | Grad Norm before: 19.9204 | Grad Norm after: 19.9204 |
# Epoch  42/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.59mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.18e-02 | Steps: 7333 | Grad Norm before: 47.4484 | Grad Norm after: 47.4484 |
# Epoch  43/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.59mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.16e-02 | Steps: 7333 | Grad Norm before: 63.2631 | Grad Norm after: 50.0000 |
# Epoch  44/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.59mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.15e-02 | Steps: 7333 | Grad Norm before: 63.9467 | Grad Norm after: 50.0000 |
# Epoch  45/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.60mV | loss_V: 0.38 | loss_dVdt: 7.08e-02 | loss_tv: 5.14e-02 | Steps: 7333 | Grad Norm before: 58.1411 | Grad Norm after: 50.0000 |
# Epoch  46/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.60mV | loss_V: 0.38 | loss_dVdt: 7.07e-02 | loss_tv: 5.12e-02 | Steps: 7333 | Grad Norm before: 46.8584 | Grad Norm after: 46.8584 |
# Epoch  47/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.60mV | loss_V: 0.38 | loss_dVdt: 7.07e-02 | loss_tv: 5.11e-02 | Steps: 7333 | Grad Norm before: 31.9482 | Grad Norm after: 31.9482 |
# Epoch  48/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.61mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.09e-02 | Steps: 7333 | Grad Norm before: 17.8357 | Grad Norm after: 17.8357 |
# Epoch  49/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.62mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.08e-02 | Steps: 7333 | Grad Norm before: 13.7859 | Grad Norm after: 13.7859 |
# Epoch  50/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.62mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.07e-02 | Steps: 7333 | Grad Norm before: 20.1481 | Grad Norm after: 20.1481 |
# Epoch  51/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.62mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.05e-02 | Steps: 7333 | Grad Norm before: 24.8742 | Grad Norm after: 24.8742 |
# Epoch  52/500 | Method: euler  | LR: 6.25e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.04e-02 | Steps: 7333 | Grad Norm before: 24.7287 | Grad Norm after: 24.7287 |
# Epoch  53/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.03e-02 | Steps: 7333 | Grad Norm before: 20.2197 | Grad Norm after: 20.2197 |
# Epoch  54/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.02e-02 | Steps: 7333 | Grad Norm before: 14.3395 | Grad Norm after: 14.3395 |
# Epoch  55/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.02e-02 | Steps: 7333 | Grad Norm before: 13.0207 | Grad Norm after: 13.0207 |
# Epoch  56/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.02e-02 | Steps: 7333 | Grad Norm before: 14.2231 | Grad Norm after: 14.2231 |
# Epoch  57/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.01e-02 | Steps: 7333 | Grad Norm before: 17.4429 | Grad Norm after: 17.4429 |
# Epoch  58/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.01e-02 | Steps: 7333 | Grad Norm before: 21.2559 | Grad Norm after: 21.2559 |
# Epoch  59/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.00e-02 | Steps: 7333 | Grad Norm before: 24.6381 | Grad Norm after: 24.6381 |
# Epoch  60/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.00e-02 | Steps: 7333 | Grad Norm before: 27.0273 | Grad Norm after: 27.0273 |
# Epoch  61/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.63mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 5.00e-02 | Steps: 7333 | Grad Norm before: 28.1748 | Grad Norm after: 28.1748 |
# Epoch  62/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.64mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 4.99e-02 | Steps: 7333 | Grad Norm before: 28.0443 | Grad Norm after: 28.0443 |
# Epoch  63/500 | Method: euler  | LR: 3.13e-05 | RMSE: 2.64mV | loss_V: 0.39 | loss_dVdt: 7.07e-02 | loss_tv: 4.98e-02 | Steps: 7333 | Grad Norm before: 26.7658 | Grad Norm after: 26.7658 |
# Epoch  64/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.64mV | loss_V: 0.40 | loss_dVdt: 7.07e-02 | loss_tv: 4.98e-02 | Steps: 7333 | Grad Norm before: 24.6067 | Grad Norm after: 24.6067 |
# Epoch  65/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.64mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.97e-02 | Steps: 7333 | Grad Norm before: 21.9141 | Grad Norm after: 21.9141 |
# Epoch  66/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.64mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.97e-02 | Steps: 7333 | Grad Norm before: 20.4778 | Grad Norm after: 20.4778 |
# Epoch  67/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.64mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.97e-02 | Steps: 7333 | Grad Norm before: 19.0270 | Grad Norm after: 19.0270 |
# Epoch  68/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.64mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.96e-02 | Steps: 7333 | Grad Norm before: 17.6580 | Grad Norm after: 17.6580 |
# Epoch  69/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.64mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.96e-02 | Steps: 7333 | Grad Norm before: 16.4468 | Grad Norm after: 16.4468 |
# Epoch  70/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.96e-02 | Steps: 7333 | Grad Norm before: 15.4424 | Grad Norm after: 15.4424 |
# Epoch  71/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.96e-02 | Steps: 7333 | Grad Norm before: 14.6634 | Grad Norm after: 14.6634 |
# Epoch  72/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.95e-02 | Steps: 7333 | Grad Norm before: 14.1029 | Grad Norm after: 14.1029 |
# Epoch  73/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.95e-02 | Steps: 7333 | Grad Norm before: 13.7297 | Grad Norm after: 13.7297 |
# Epoch  74/500 | Method: euler  | LR: 1.56e-05 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.95e-02 | Steps: 7333 | Grad Norm before: 13.5060 | Grad Norm after: 13.5060 |
# Epoch  75/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.95e-02 | Steps: 7333 | Grad Norm before: 13.3993 | Grad Norm after: 13.3993 |
# Epoch  76/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 13.3860 | Grad Norm after: 13.3860 |
# Epoch  77/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 13.4205 | Grad Norm after: 13.4205 |
# Epoch  78/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 13.4964 | Grad Norm after: 13.4964 |
# Epoch  79/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 13.6091 | Grad Norm after: 13.6091 |
# Epoch  80/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 13.7589 | Grad Norm after: 13.7589 |
# Epoch  81/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 13.9451 | Grad Norm after: 13.9451 |
# Epoch  82/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 14.1610 | Grad Norm after: 14.1610 |
# Epoch  83/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 14.4043 | Grad Norm after: 14.4043 |
# Epoch  84/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.94e-02 | Steps: 7333 | Grad Norm before: 14.6654 | Grad Norm after: 14.6654 |
# Epoch  85/500 | Method: euler  | LR: 7.81e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 14.9386 | Grad Norm after: 14.9386 |
# Epoch  86/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 15.2135 | Grad Norm after: 15.2135 |
# Epoch  87/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 15.4796 | Grad Norm after: 15.4796 |
# Epoch  88/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 15.6048 | Grad Norm after: 15.6048 |
# Epoch  89/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 15.7169 | Grad Norm after: 15.7169 |
# Epoch  90/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 15.8179 | Grad Norm after: 15.8179 |
# Epoch  91/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 15.9057 | Grad Norm after: 15.9057 |
# Epoch  92/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 15.9782 | Grad Norm after: 15.9782 |
# Epoch  93/500 | Method: euler  | LR: 3.91e-06 | RMSE: 2.65mV | loss_V: 0.40 | loss_dVdt: 7.06e-02 | loss_tv: 4.93e-02 | Steps: 7333 | Grad Norm before: 16.0367 | Grad Norm after: 16.0367 |
# Window range <= 0.01 mV → stop
#
# ==================================================
# Training Complete!
# Loaded best model from epoch 9/500
# Best RMSE: 2.41mV
# Best model saved to: best_model_rmse2.41mV.pth
#   - Model weights
#   - Training info (alpha=1, beta=0, gamma=0)
#   - Best RMSE: 2.41mV at epoch 9
# ==================================================

# %%
# Load pretrained model
import torch
from battery_ode_wrapper import BatteryODEWrapper


# Call training function
device = 'cuda' if torch.cuda.is_available() else 'cpu'

num_epochs = 500  # Increased from 100 to 300
lr = 5e-4  # continue training


# 1. 먼저 모델 로드 (위에서 설명한 방법)
saved_data = torch.load("best_model_rmse2.41mV_0.5gain_euler_continued.pth", map_location=device)
saved_state = saved_data['model_state_dict'] if isinstance(saved_data, dict) and 'model_state_dict' in saved_data else saved_data

ode_wrapper_new = BatteryODEWrapper(device).to(device)
ode_wrapper_new.load_state_dict(saved_state)

# 2. 모델을 파일로 다시 저장 (임시로)
temp_model_path = "best_model_rmse2.41mV_0.5gain_euler_continued.pth"
torch.save(saved_state, temp_model_path)  # state_dict만 저장
# Out:
# C:\Users\ljw76\AppData\Local\Temp\ipykernel_57068\1101217984.py:14: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
# 트레이닝 후
from battery_ode_wrapper import simulate_battery_ode
import matplotlib
matplotlib.use('module://matplotlib_inline.backend_inline')  # Reset backend

Vcorr_pred, Vcorr_target, Vtotal_pred, Vtotal_meas, time = simulate_battery_ode(
    ode_wrapper_new, data_dict, device=device, plot=True
)
# Out:
# ==================================================
# Simulation Results:
# ==================================================
# Vcorr RMSE: 2.41 mV
# Vtotal RMSE: 2.41 mV
# ==================================================
